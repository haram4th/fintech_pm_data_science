# %% [markdown]
# # 1. pandas
# ## pandas의 특징
# ### pandas의 특징
# * Numpy를 내부적으로 활용함(numpy의 특징을 그대로 가짐)
# * 데이터 분석에 특화된 데이터 구조 제공
# * 다양한 데이터 분석 함수 제공
# * 데이터베이스에 쉽게 연결 가능
# * json데이터나 table요소를 데이터프레임으로 손쉽게 변형 가능

# %%
# 설치
# !pip install pandas
# !conda install pandas

# %% [markdown]
# # 2. Pandas에서 다루는 데이터 타입
# ## 1) DataFrame: 2차원의 표형식 데이터  => key : [ value1, value2 ]
# ## 2) Series: 1차원의 벡터형식 데이터  => list, tuple, ndarray

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {'이름': ['홍길동', '장마철', '소나기', '더워요'],
     'Age' : [23, 55, 24, 16],
     '성별': ['male', 'female', 'female', 'male']}
)
display(df)
print(type(df))
print(df)
print(df.shape)
# Out:
#     이름  Age      성별
# 0  홍길동   23    male
# 1  장마철   55  female
# 2  소나기   24  female
# 3  더워요   16    male
# <class 'pandas.core.frame.DataFrame'>
#     이름  Age      성별
# 0  홍길동   23    male
# 1  장마철   55  female
# 2  소나기   24  female
# 3  더워요   16    male
# (4, 3)

# %%
display(df['이름'])
print(type(df['이름']))
print(df['이름'].shape)
print(df['이름'].ndim)
print()
display(df[['이름']])
print(type(df[['이름']]))
print(df[['이름']].shape)
print(df[['이름']].ndim)
# Out:
# 0    홍길동
# 1    장마철
# 2    소나기
# 3    더워요
# Name: 이름, dtype: object
# <class 'pandas.core.series.Series'>
# (4,)
# 1
#     이름
# 0  홍길동
# 1  장마철
# 2  소나기
# 3  더워요
# <class 'pandas.core.frame.DataFrame'>
# (4, 1)
# 2

# %% [markdown]
# ## 시리즈 만들기 pd.Series([리스트자료], name='컬럼명')
# * 이름을 가지고 있는 벡터

# %%
ages = pd.Series([22, 35, 58], name="Age")
ages
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
ages[1:]
# Out:
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
ages[::-1]
# Out:
# 2    58
# 1    35
# 0    22
# Name: Age, dtype: int64

# %%
ages.max()
# Out:
# np.int64(58)

# %%
ages.min()
# Out:
# np.int64(22)

# %%
ages.sum()
# Out:
# np.int64(115)

# %%
ages.mean()
# Out:
# np.float64(38.333333333333336)

# %%
ages.median()
# Out:
# np.float64(35.0)

# %%
ages.describe()
# Out:
# count     3.000000
# mean     38.333333
# std      18.230012
# min      22.000000
# 25%      28.500000
# 50%      35.000000
# 75%      46.500000
# max      58.000000
# Name: Age, dtype: float64

# %%
ages.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3 entries, 0 to 2
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 3 non-null      int64
# dtypes: int64(1)
# memory usage: 152.0 bytes

# %% [markdown]
# # 판다스에서 자료 불러오기, 저장하기
# * csv, tsv, excel, json, html
# * pd.read_확장자

# %%
# !pip install openpyxl

# %%
df1 = pd.read_excel("./data/Online Retail.xlsx")
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
df2_1 = pd.read_excel("./data/아파트(매매)_실거래가_20240806113828.xlsx")
df2_1.head(20)
# Out:
# C:\Users\5-29\miniforge3\envs\fintech\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다.           Unnamed: 1  \
# 0   □ 신고정보가 실시간 변경, 해제되어 제공시점에 따라 공개건수 및 내용이 상이할 수...                  NaN
# 1   □ 본 자료는 계약일 기준입니다. (※ 7월 계약, 8월 신고건 → 7월 거래건으로...                  NaN
# 2   □ 통계자료 활용시에는 수치가 왜곡될 수 있으니 참고자료로만 활용하시기  바라며, ...                  NaN
# 3                                                 NaN                  NaN
# 4   * 국토교통부 실거래가 공개시스템의 궁금하신 점이나 문의사항은 콜센터 1533-29...                  NaN
# 5                                                 NaN                  NaN
# 6                                              □ 검색조건                  NaN
# 7                      계약일자 : 2024-07-01 ~ 2024-07-31                  NaN
# 8                                             시도 : 전체                  NaN
# 9                                            단지명 : 전체                  NaN
# 10                                                NaN                  NaN
# 11                                                 NO                  시군구
# 12                                                  1     서울특별시 영등포구 당산동5가
# 13                                                  2  강원특별자치도 원주시 지정면 가곡리
# 14                                                  3    대구광역시 달성군 화원읍 구라리
# 15                                                  4         광주광역시 남구 진월동
# 16                                                  5         광주광역시 남구 진월동
# 17                                                  6      경기도 양평군 양평읍 양근리
# 18                                                  7       서울특별시 동대문구 장안동
# 19                                                  8    대구광역시 달성군 화원읍 천내리
#
#    Unnamed: 2 Unnamed: 3        Unnamed: 4         Unnamed: 5 Unnamed: 6  \
# 0         NaN        NaN               NaN                NaN        NaN
# 1         NaN        NaN               NaN                NaN        NaN
# 2         NaN        NaN               NaN                NaN        NaN
# 3         NaN        NaN               NaN                NaN        NaN
# 4         NaN        NaN               NaN                NaN        NaN
# 5         NaN        NaN               NaN                NaN        NaN
# 6         NaN        NaN               NaN                NaN        NaN
# 7         NaN        NaN  실거래 구분 : 아파트(매매)                NaN        NaN
# 8         NaN        NaN          시군구 : 전체                NaN        NaN
# 9         NaN        NaN           면적 : 전체                NaN        NaN
# 10        NaN        NaN               NaN                NaN        NaN
# 11         번지         본번                부번                단지명    전용면적(㎡)
# 12         42       0042              0000          당산삼성래미안4차   115.7800
# 13       1512       1512              0000  원주롯데캐슬골드파크1차(5단지)    84.9644
# 14       1650       1650              0000             대곡역래미안    84.5958
# 15      312-7       0312              0007                 광명    70.6250
# 16     331-93       0331              0093                 중흥    84.8400
# 17      140-5       0140              0005               양평현대    59.7000
# 18        587       0587              0000         동대문더퍼스트데시앙    59.8074
# 19      690-1       0690              0001        화원파크뷰우방아이유쉘    69.6413
#
#    Unnamed: 7 Unnamed: 8    Unnamed: 9  ... Unnamed: 11 Unnamed: 12  \
# 0         NaN        NaN           NaN  ...         NaN         NaN
# 1         NaN        NaN           NaN  ...         NaN         NaN
# 2         NaN        NaN           NaN  ...         NaN         NaN
# 3         NaN        NaN           NaN  ...         NaN         NaN
# 4         NaN        NaN           NaN  ...         NaN         NaN
# 5         NaN        NaN           NaN  ...         NaN         NaN
# 6         NaN        NaN           NaN  ...         NaN         NaN
# 7         NaN        NaN  주소구분 : 지번 주소  ...         NaN         NaN
# 8         NaN        NaN      읍면동 : 전체  ...         NaN         NaN
# 9         NaN        NaN     금액선택 : 전체  ...         NaN         NaN
# 10        NaN        NaN           NaN  ...         NaN         NaN
# 11       계약년월        계약일      거래금액(만원)  ...           층         매수자
# 12     202407         31       139,000  ...           4          개인
# 13     202407         31        38,900  ...          10          개인
# 14     202407         31        29,500  ...          11          개인
# 15     202407         31        16,900  ...           1          개인
# 16     202407         31        17,500  ...          13          개인
# 17     202407         31        22,500  ...          14          개인
# 18     202407         31        80,500  ...          10          개인
# 19     202407         31        38,000  ...          17          개인
#
#    Unnamed: 13 Unnamed: 14    Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 0          NaN         NaN            NaN         NaN         NaN         NaN
# 1          NaN         NaN            NaN         NaN         NaN         NaN
# 2          NaN         NaN            NaN         NaN         NaN         NaN
# 3          NaN         NaN            NaN         NaN         NaN         NaN
# 4          NaN         NaN            NaN         NaN         NaN         NaN
# 5          NaN         NaN            NaN         NaN         NaN         NaN
# 6          NaN         NaN            NaN         NaN         NaN         NaN
# 7          NaN         NaN            NaN         NaN         NaN         NaN
# 8          NaN         NaN            NaN         NaN         NaN         NaN
# 9          NaN         NaN            NaN         NaN         NaN         NaN
# 10         NaN         NaN            NaN         NaN         NaN         NaN
# 11         매도자        건축년도            도로명     해제사유발생일        거래유형      중개사소재지
# 12          개인        2003        당산로 214           -         직거래           -
# 13          개인        2019       신지정로 250    20240802        중개거래      강원 원주시
# 14          개인        2007     비슬로539길 35           -        중개거래      대구 달성군
# 15          개인        1998       광복마을길 63           -        중개거래       광주 남구
# 16          개인        1992  서문대로749번마길 30           -         직거래           -
# 17          개인        1996         관문길 60           -        중개거래      경기 양평군
# 18          개인        2019     장한로27가길 37           -        중개거래     서울 동대문구
# 19          개인        2022      명천로21길 55           -        중개거래      대구 달서구
#
#    Unnamed: 19 Unnamed: 20
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11        등기일자        주택유형
# 12           -         아파트
# 13           -         아파트
# 14           -         아파트
# 15           -         아파트
# 16    24.07.31         아파트
# 17           -         아파트
# 18           -         아파트
# 19           -         아파트
#
# [20 rows x 21 columns]

# %%
df2_2 = pd.read_excel("./data/아파트(매매)_실거래가_20240806113828.xlsx", header=12)
df2_2.head(13)
# Out:
# C:\Users\5-29\miniforge3\envs\fintech\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     NO                  시군구      번지    본번   부번                단지명   전용면적(㎡)  \
# 0    1     서울특별시 영등포구 당산동5가      42    42    0          당산삼성래미안4차  115.7800
# 1    2  강원특별자치도 원주시 지정면 가곡리    1512  1512    0  원주롯데캐슬골드파크1차(5단지)   84.9644
# 2    3    대구광역시 달성군 화원읍 구라리    1650  1650    0             대곡역래미안   84.5958
# 3    4         광주광역시 남구 진월동   312-7   312    7                 광명   70.6250
# 4    5         광주광역시 남구 진월동  331-93   331   93                 중흥   84.8400
# 5    6      경기도 양평군 양평읍 양근리   140-5   140    5               양평현대   59.7000
# 6    7       서울특별시 동대문구 장안동     587   587    0         동대문더퍼스트데시앙   59.8074
# 7    8    대구광역시 달성군 화원읍 천내리   690-1   690    1        화원파크뷰우방아이유쉘   69.6413
# 8    9  충청남도 천안시서북구 성거읍 신월리    2-26     2   26            천안삼환나우빌   84.9132
# 9   10      경기도 양평군 양평읍 창대리     844   844    0            한화포레나양평   59.8551
# 10  11       서울특별시 동대문구 용두동  39-446    39  446              용두아파트   47.5000
# 11  12       서울특별시 서대문구 대현동     144   144    0               신촌럭키   83.3800
# 12  13        서울특별시 중랑구 면목동   193-1   193    1               면목한신   58.4600
#
#       계약년월  계약일 거래금액(만원)  ...   층  매수자 매도자  건축년도            도로명   해제사유발생일  \
# 0   202407   31  139,000  ...   4   개인  개인  2003        당산로 214         -
# 1   202407   31   38,900  ...  10   개인  개인  2019       신지정로 250  20240802
# 2   202407   31   29,500  ...  11   개인  개인  2007     비슬로539길 35         -
# 3   202407   31   16,900  ...   1   개인  개인  1998       광복마을길 63         -
# 4   202407   31   17,500  ...  13   개인  개인  1992  서문대로749번마길 30         -
# 5   202407   31   22,500  ...  14   개인  개인  1996         관문길 60         -
# 6   202407   31   80,500  ...  10   개인  개인  2019     장한로27가길 37         -
# 7   202407   31   38,000  ...  17   개인  개인  2022      명천로21길 55         -
# 8   202407   31   22,800  ...   7   개인  개인  2005        봉주로 120         -
# 9   202407   31   31,500  ...  19   개인  개인  2023         남북로 53         -
# 10  202407   31   40,000  ...   1   개인  개인  1974     고산자로32길 44         -
# 11  202407   31   98,000  ...  11   개인  개인  1999    이화여대길 50-12         -
# 12  202407   31   54,500  ...   7   개인  개인  1988        중랑천로 20         -
#
#     거래유형     중개사소재지      등기일자 주택유형
# 0    직거래          -         -  아파트
# 1   중개거래     강원 원주시         -  아파트
# 2   중개거래     대구 달성군         -  아파트
# 3   중개거래      광주 남구         -  아파트
# 4    직거래          -  24.07.31  아파트
# 5   중개거래     경기 양평군         -  아파트
# 6   중개거래    서울 동대문구         -  아파트
# 7   중개거래     대구 달서구         -  아파트
# 8   중개거래  충남 천안시서북구         -  아파트
# 9   중개거래     경기 양평군         -  아파트
# 10  중개거래    서울 동대문구         -  아파트
# 11  중개거래    서울 서대문구         -  아파트
# 12  중개거래     서울 중랑구         -  아파트
#
# [13 rows x 21 columns]

# %%
# %%time
df2 = pd.read_excel("./data/아파트(매매)_실거래가_20240806113828.xlsx", header=12, index_col='NO')
df2.head(13)
# Out:
# CPU times: total: 30 s
# Wall time: 30.1 s
#                     시군구      번지    본번   부번                단지명   전용면적(㎡)  \
# NO
# 1      서울특별시 영등포구 당산동5가      42    42    0          당산삼성래미안4차  115.7800
# 2   강원특별자치도 원주시 지정면 가곡리    1512  1512    0  원주롯데캐슬골드파크1차(5단지)   84.9644
# 3     대구광역시 달성군 화원읍 구라리    1650  1650    0             대곡역래미안   84.5958
# 4          광주광역시 남구 진월동   312-7   312    7                 광명   70.6250
# 5          광주광역시 남구 진월동  331-93   331   93                 중흥   84.8400
# 6       경기도 양평군 양평읍 양근리   140-5   140    5               양평현대   59.7000
# 7        서울특별시 동대문구 장안동     587   587    0         동대문더퍼스트데시앙   59.8074
# 8     대구광역시 달성군 화원읍 천내리   690-1   690    1        화원파크뷰우방아이유쉘   69.6413
# 9   충청남도 천안시서북구 성거읍 신월리    2-26     2   26            천안삼환나우빌   84.9132
# 10      경기도 양평군 양평읍 창대리     844   844    0            한화포레나양평   59.8551
# 11       서울특별시 동대문구 용두동  39-446    39  446              용두아파트   47.5000
# 12       서울특별시 서대문구 대현동     144   144    0               신촌럭키   83.3800
# 13        서울특별시 중랑구 면목동   193-1   193    1               면목한신   58.4600
#
#       계약년월  계약일 거래금액(만원)    동   층 매수자 매도자  건축년도            도로명   해제사유발생일  \
# NO
# 1   202407   31  139,000    -   4  개인  개인  2003        당산로 214         -
# 2   202407   31   38,900    -  10  개인  개인  2019       신지정로 250  20240802
# 3   202407   31   29,500    -  11  개인  개인  2007     비슬로539길 35         -
# 4   202407   31   16,900    -   1  개인  개인  1998       광복마을길 63         -
# 5   202407   31   17,500  102  13  개인  개인  1992  서문대로749번마길 30         -
# 6   202407   31   22,500    -  14  개인  개인  1996         관문길 60         -
# 7   202407   31   80,500    -  10  개인  개인  2019     장한로27가길 37         -
# 8   202407   31   38,000    -  17  개인  개인  2022      명천로21길 55         -
# 9   202407   31   22,800    -   7  개인  개인  2005        봉주로 120         -
# 10  202407   31   31,500    -  19  개인  개인  2023         남북로 53         -
# 11  202407   31   40,000    -   1  개인  개인  1974     고산자로32길 44         -
# 12  202407   31   98,000    -  11  개인  개인  1999    이화여대길 50-12         -
# 13  202407   31   54,500    -   7  개인  개인  1988        중랑천로 20         -
#
#     거래유형     중개사소재지      등기일자 주택유형
# NO
# 1    직거래          -         -  아파트
# 2   중개거래     강원 원주시         -  아파트
# 3   중개거래     대구 달성군         -  아파트
# 4   중개거래      광주 남구         -  아파트
# 5    직거래          -  24.07.31  아파트
# 6   중개거래     경기 양평군         -  아파트
# 7   중개거래    서울 동대문구         -  아파트
# 8   중개거래     대구 달서구         -  아파트
# 9   중개거래  충남 천안시서북구         -  아파트
# 10  중개거래     경기 양평군         -  아파트
# 11  중개거래    서울 동대문구         -  아파트
# 12  중개거래    서울 서대문구         -  아파트
# 13  중개거래     서울 중랑구         -  아파트

# %% [markdown]
# CSV 파일 읽기 pd.read_csv(파일명, 옵션), tsv

# %%
# %%time
df3_1 = pd.read_csv("./data/아파트(매매)_실거래가_20240806113828.csv", header=12, index_col=0  )
df3_1
# Out:
# CPU times: total: 203 ms
# Wall time: 208 ms
#                        시군구      번지    본번  부번                단지명   전용면적(㎡)  \
# NO
# 1         서울특별시 영등포구 당산동5가      42    42   0          당산삼성래미안4차  115.7800
# 2      강원특별자치도 원주시 지정면 가곡리    1512  1512   0  원주롯데캐슬골드파크1차(5단지)   84.9644
# 3        대구광역시 달성군 화원읍 구라리    1650  1650   0             대곡역래미안   84.5958
# 4             광주광역시 남구 진월동   312-7   312   7                 광명   70.6250
# 5             광주광역시 남구 진월동  331-93   331  93                 중흥   84.8400
# ...                    ...     ...   ...  ..                ...       ...
# 37576        서울특별시 송파구 장지동     849   849   0          송파파인타운3단지   84.9800
# 37577        부산광역시 사상구 모라동     552   552   0               백양그린   41.3000
# 37578        광주광역시 광산구 비아동   152-5   152   5                 호반   59.8800
# 37579        부산광역시 사상구 모라동     552   552   0               백양그린   41.3000
# 37580         대구광역시 북구 읍내동  1366-2  1366   2               칠곡보성   84.9800
#
#          계약년월  계약일 거래금액(만원)    동   층 매수자 매도자  건축년도            도로명   해제사유발생일  \
# NO
# 1      202407   31  139,000    -   4  개인  개인  2003        당산로 214         -
# 2      202407   31   38,900    -  10  개인  개인  2019       신지정로 250  20240802
# 3      202407   31   29,500    -  11  개인  개인  2007     비슬로539길 35         -
# 4      202407   31   16,900    -   1  개인  개인  1998       광복마을길 63         -
# 5      202407   31   17,500  102  13  개인  개인  1992  서문대로749번마길 30         -
# ...       ...  ...      ...  ...  ..  ..  ..   ...            ...       ...
# 37576  202407    1  117,500    -  14  개인  개인  2008        충민로 152         -
# 37577  202407    1    7,000  206   8  개인  개인  1992    모라로110번길 88         -
# 37578  202407    1   15,400  102   5  개인  개인  1998        비아로 185         -
# 37579  202407    1    7,500  205  10  개인  개인  1992    모라로110번길 88         -
# 37580  202407    1   21,000    -   9  개인  개인  1992      구암로21길 26         -
#
#        거래유형  중개사소재지      등기일자 주택유형
# NO
# 1       직거래       -         -  아파트
# 2      중개거래  강원 원주시         -  아파트
# 3      중개거래  대구 달성군         -  아파트
# 4      중개거래   광주 남구         -  아파트
# 5       직거래       -  24.07.31  아파트
# ...     ...     ...       ...  ...
# 37576  중개거래  서울 송파구         -  아파트
# 37577  중개거래  부산 사상구  24.07.10  아파트
# 37578  중개거래  광주 광산구  24.07.26  아파트
# 37579  중개거래  부산 사상구  24.07.19  아파트
# 37580  중개거래   대구 북구         -  아파트
#
# [37580 rows x 20 columns]

# %%
df3 = pd.read_csv("./data/06고객이탈예측.csv", encoding="cp949")
df3
# Out:
#             회원ID      성별  고연령  배우자 피부양자  가입기간 전화서비스             2회선이상  \
# 0     7590-VHVEG  Female    0  Yes   No     1    No  No phone service
# 1     5575-GNVDE    Male    0   No   No    34   Yes                No
# 2     3668-QPYBK    Male    0   No   No     2   Yes                No
# 3     7795-CFOCW    Male    0   No   No    45    No  No phone service
# 4     9237-HQITU  Female    0   No   No     2   Yes                No
# ...          ...     ...  ...  ...  ...   ...   ...               ...
# 7038  6840-RESVB    Male    0  Yes  Yes    24   Yes               Yes
# 7039  2234-XADUH  Female    0  Yes  Yes    72   Yes               Yes
# 7040  4801-JZAZL  Female    0  Yes  Yes    11    No  No phone service
# 7041  8361-LTMKD    Male    1  Yes   No     4   Yes               Yes
# 7042  3186-AJIEK    Male    0   No   No    66   Yes                No
#
#            인터넷서비스 온라인보안  ... 기기보호서비스 기술지원 스트리밍TV 스트리밍Movies            약정옵션  \
# 0             DSL    No  ...      No   No     No         No  Month-to-month
# 1             DSL   Yes  ...     Yes   No     No         No        One year
# 2             DSL   Yes  ...      No   No     No         No  Month-to-month
# 3             DSL   Yes  ...     Yes  Yes     No         No        One year
# 4     Fiber optic    No  ...      No   No     No         No  Month-to-month
# ...           ...   ...  ...     ...  ...    ...        ...             ...
# 7038          DSL   Yes  ...     Yes  Yes    Yes        Yes        One year
# 7039  Fiber optic    No  ...     Yes   No    Yes        Yes        One year
# 7040          DSL   Yes  ...      No   No     No         No  Month-to-month
# 7041  Fiber optic    No  ...      No   No     No         No  Month-to-month
# 7042  Fiber optic   Yes  ...     Yes  Yes    Yes        Yes        Two year
#
#      온라인고지서                       지불수단     월요금     합산요금 이탈여부
# 0       Yes           Electronic check   29.85    29.85   No
# 1        No               Mailed check   56.95   1889.5   No
# 2       Yes               Mailed check   53.85   108.15  Yes
# 3        No  Bank transfer (automatic)   42.30  1840.75   No
# 4       Yes           Electronic check   70.70   151.65  Yes
# ...     ...                        ...     ...      ...  ...
# 7038    Yes               Mailed check   84.80   1990.5   No
# 7039    Yes    Credit card (automatic)  103.20   7362.9   No
# 7040    Yes           Electronic check   29.60   346.45   No
# 7041    Yes               Mailed check   74.40    306.6  Yes
# 7042    Yes  Bank transfer (automatic)  105.65   6844.5   No
#
# [7043 rows x 21 columns]

# %% [markdown]
# json 파일 읽기

# %%
df4 = pd.read_json("./data/서울특별시_관광지입장정보_2011_2016.json")
df4
# Out:
#     ForNum  NatNum  addrCd gungu      resNm  rnum   sido  yyyymm
# 0    44722   75991    1111   종로구        창덕궁     1  서울특별시  201112
# 1        0   11017    1111   종로구        운현궁     2  서울특별시  201112
# 2   132399  237330    1111   종로구        경복궁     3  서울특별시  201112
# 3     3133   21267    1111   종로구        창경궁     4  서울특별시  201112
# 4    18226   24223    1111   종로구         종묘     5  서울특별시  201112
# ..     ...     ...     ...   ...        ...   ...    ...     ...
# 62    5588   44232    1141  서대문구  서대문형무소역사관     8  서울특별시  201512
# 63       0   22587    1141  서대문구  서대문자연사박물관     9  서울특별시  201512
# 64   29520    8822    1144   마포구    트릭아이미술관    10  서울특별시  201512
# 65       3    1647    1165   서초구      헌릉ㆍ인릉    11  서울특별시  201512
# 66     492   14454    1168   강남구      선릉·정릉    12  서울특별시  201512
#
# [67 rows x 8 columns]

# %% [markdown]
# html 파일읽기 pd.read_html

# %%
df5 = pd.read_html("./data/corpList.htm")
df5[0]
# Out:
#     Unnamed: 0                             Unnamed: 1  \
# 0     한국제15호스팩                             금융 지원 서비스업
# 1       에스오에스랩  측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 2   미래에셋비전스팩6호                             금융 지원 서비스업
# 3   에이치엠씨제7호스팩                             금융 지원 서비스업
# 4        파라다이스                     유원지 및 기타 오락관련 서비스업
# 5       한중엔시에스      전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 6     KB제29호스팩                             금융 지원 서비스업
# 7   미래에셋비전스팩5호                             금융 지원 서비스업
# 8     씨어스테크놀로지                             의료용 기기 제조업
# 9     한국제14호스팩                             금융 지원 서비스업
# 10   디비금융스팩12호                                 기타 금융업
# 11        라메디텍                             의료용 기기 제조업
# 12       그리드위즈                 그외 기타 전문, 과학 및 기술 서비스업
# 13       다원넥스뷰                        사진장비 및 광학기기 제조업
# 14  미래에셋비전스팩4호                             금융 지원 서비스업
#
#                                            Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0                                              기업인수합병  2024-06-26        12월
# 1                                산업용 및 차량용 라이다(LiDAR)  2024-06-25        12월
# 2                                              기업인수합병  2024-06-24        12월
# 3                                                기타금융  2024-06-24        12월
# 4                                      카지노, 호텔, 복합리조트  2024-06-24        12월
# 5   수냉식 냉각시스템 ESS Parts, 공랭식 ESS Module Parts, EV ...  2024-06-24        12월
# 6                                              기업인수합병  2024-06-21        12월
# 7                                              기업인수합병  2024-06-19        12월
# 8                                심전도검사솔루션 입원환자모니터링솔루션  2024-06-19        12월
# 9                                              기업인수합병  2024-06-19        12월
# 10                                          기업인수 및 합병  2024-06-18        12월
# 11                                초소형 레이저 의료기기 및 미용기기  2024-06-17        12월
# 12                             수요관리 서비스, 전기차 충전기 모뎀 등  2024-06-14        12월
# 13                   LSMB(Laser Micro Bonding System)  2024-06-11        12월
# 14                                  기업인수목적회사(기타금융서비스)  2024-05-29        12월
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0          유한        NaN      서울특별시
# 1         정지성    홈페이지 보기      광주광역시
# 2         정명훈        NaN      서울특별시
# 3         강신명        NaN      서울특별시
# 4       최종환..    홈페이지 보기      서울특별시
# 5         김환식    홈페이지 보기       경상북도
# 6         서영화        NaN      서울특별시
# 7         김대호        NaN      서울특별시
# 8         이영신    홈페이지 보기        경기도
# 9         변성환        NaN      서울특별시
# 10        김창희        NaN      서울특별시
# 11        최종석        NaN      서울특별시
# 12        김구환    홈페이지 보기        경기도
# 13        남기중    홈페이지 보기        경기도
# 14        김정수        NaN      서울특별시

# %%
import os
import pandas as pd
from sqlalchemy import create_engine
import pymysql
from dotenv import load_dotenv
pymysql.install_as_MySQLdb()
load_dotenv(dotenv_path="../05data_scraping/.env_db")
# Out:
# True

# %%
# mysql에서 테이블 불러오기
engine = create_engine(f"{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('user')}:{os.getenv('pw')}@{os.getenv('host')}/{os.getenv('database')}")
conn = engine.connect()
data_07 = pd.read_sql('2024_07_stock_price_info', con=conn)
data_08 = pd.read_sql('2024_08_stock_price_info', con=conn)
conn.close()

# %%
data_07.head(2)
# Out:
#           수집일         회사명    종목코드    현재가   변동금액    변화율     전일     고가  \
# 0  2024-07-30       산일전기   062040  55500   5300  10.56  50200  61300
# 1  2024-07-30    에이치에스효성   487570  65700  16900 -20.46  82600  75900
#
#         거래량     시가     저가    거래대금
# 0  12682123  55200  50900  718098
# 1    372304  75400  64800   26079

# %%
data_08.head(2)
# Out:
#           수집일         회사명    종목코드    현재가  변동금액   변화율     전일     고가      거래량  \
# 0  2024-08-01       산일전기   062040  52100  1800  3.58  50300  57900  4183944
# 1  2024-08-01    에이치에스효성   487570  60100  3700 -5.80  63800  64200   137655
#
#       시가     저가    거래대금
# 0  54300  52100  231492
# 1  63500  59400    8439

# %%
df6 = pd.read_json("./data/서울특별시_관광지입장정보_2011_2016.json")
df6
# Out:
#     ForNum  NatNum  addrCd gungu      resNm  rnum   sido  yyyymm
# 0    44722   75991    1111   종로구        창덕궁     1  서울특별시  201112
# 1        0   11017    1111   종로구        운현궁     2  서울특별시  201112
# 2   132399  237330    1111   종로구        경복궁     3  서울특별시  201112
# 3     3133   21267    1111   종로구        창경궁     4  서울특별시  201112
# 4    18226   24223    1111   종로구         종묘     5  서울특별시  201112
# ..     ...     ...     ...   ...        ...   ...    ...     ...
# 62    5588   44232    1141  서대문구  서대문형무소역사관     8  서울특별시  201512
# 63       0   22587    1141  서대문구  서대문자연사박물관     9  서울특별시  201512
# 64   29520    8822    1144   마포구    트릭아이미술관    10  서울특별시  201512
# 65       3    1647    1165   서초구      헌릉ㆍ인릉    11  서울특별시  201512
# 66     492   14454    1168   강남구      선릉·정릉    12  서울특별시  201512
#
# [67 rows x 8 columns]

# %%
# mysql에서 테이블 불러오기
engine = create_engine(f"{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('user')}:{os.getenv('pw')}@{os.getenv('host')}/{os.getenv('database')}")
conn = engine.connect()
data_07 = pd.read_sql('2024_07_stock_price_info', con=conn)
data_08 = pd.read_sql('2024_08_stock_price_info', con=conn)
conn.close()

# %%
data_07.head(2)
# Out:
#           수집일         회사명    종목코드    현재가   변동금액    변화율     전일     고가  \
# 0  2024-07-30       산일전기   062040  55500   5300  10.56  50200  61300
# 1  2024-07-30    에이치에스효성   487570  65700  16900 -20.46  82600  75900
#
#         거래량     시가     저가    거래대금
# 0  12682123  55200  50900  718098
# 1    372304  75400  64800   26079

# %%
data_08.head(2)
# Out:
#           수집일         회사명    종목코드    현재가  변동금액   변화율     전일     고가      거래량  \
# 0  2024-08-01       산일전기   062040  52100  1800  3.58  50300  57900  4183944
# 1  2024-08-01    에이치에스효성   487570  60100  3700 -5.80  63800  64200   137655
#
#       시가     저가    거래대금
# 0  54300  52100  231492
# 1  63500  59400    8439

# %% [markdown]
# ## mysql titanic DB에서 passenger, surv, ticket 테이블 로드

# %%
# mysql에서 테이블 불러오기
engine = create_engine(f"{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('user')}:{os.getenv('pw')}@{os.getenv('host')}/titanic")
conn = engine.connect()
passenger = pd.read_sql('passenger', con=conn)
surv = pd.read_sql('surv', con=conn)
ticket = pd.read_sql('ticket', con=conn)
conn.close()

# %%
passenger
# Out:
#      PassengerId                                             Name     Sex  \
# 0            193  Andersen-Jensen, Miss. Carla Christine Nielsine  female
# 1            192                            Carbines, Mr. William    male
# 2            715                            Greenberg, Mr. Samuel    male
# 3            533                             Elias, Mr. Joseph Jr    male
# 4            133   Robins, Mrs. Alexander A (Grace Charity Laury)  female
# ..           ...                                              ...     ...
# 618          580                              Jussila, Mr. Eiriik    male
# 619          503                   O'Sullivan, Miss. Bridget Mary  female
# 620          538                              LeRoy, Miss. Bertha  female
# 621          197                              Mernagh, Mr. Robert    male
# 622          176                           Klasen, Mr. Klas Albin    male
#
#       Age  SibSp  Parch
# 0    19.0      1      0
# 1    19.0      0      0
# 2    52.0      0      0
# 3    17.0      1      1
# 4    47.0      1      0
# ..    ...    ...    ...
# 618  32.0      0      0
# 619   NaN      0      0
# 620  30.0      0      0
# 621   NaN      0      0
# 622  18.0      1      1
#
# [623 rows x 6 columns]

# %%
surv
# Out:
#      PassengerId  Survived
# 0            762         0
# 1            665         1
# 2            809         0
# 3            332         0
# 4             21         0
# ..           ...       ...
# 441          698         1
# 442          778         1
# 443          157         1
# 444          350         0
# 445          881         1
#
# [446 rows x 2 columns]

# %%
ticket
# Out:
#      PassengerId         Ticket  Pclass      Fare    Cabin Embarked
# 0            486           4133       3   25.4667     None        S
# 1            119       PC 17558       1  247.5208  B58 B60        C
# 2            836       PC 17756       1   83.1583      E49        C
# 3            528       PC 17483       1  221.7792      C95        S
# 4            396         350052       3    7.7958     None        S
# ..           ...            ...     ...       ...      ...      ...
# 440          692         349256       3   13.4167     None        C
# 441          585           3411       3    8.7125     None        C
# 442          265         382649       3    7.7500     None        Q
# 443          328          28551       2   13.0000        D        S
# 444          136  SC/PARIS 2133       2   15.0458     None        C
#
# [445 rows x 6 columns]

# %% [markdown]
# # 3개의 데이터프레임을 1개로 합치기
# * join()
# * merge()
# * concat()

# %%
test1 = pd.concat([passenger, ticket, surv], axis=1)
test1.head()
# Out:
#    PassengerId                                             Name     Sex   Age  \
# 0          193  Andersen-Jensen, Miss. Carla Christine Nielsine  female  19.0
# 1          192                            Carbines, Mr. William    male  19.0
# 2          715                            Greenberg, Mr. Samuel    male  52.0
# 3          533                             Elias, Mr. Joseph Jr    male  17.0
# 4          133   Robins, Mrs. Alexander A (Grace Charity Laury)  female  47.0
#
#    SibSp  Parch  PassengerId    Ticket  Pclass      Fare    Cabin Embarked  \
# 0      1      0        486.0      4133     3.0   25.4667     None        S
# 1      0      0        119.0  PC 17558     1.0  247.5208  B58 B60        C
# 2      0      0        836.0  PC 17756     1.0   83.1583      E49        C
# 3      1      1        528.0  PC 17483     1.0  221.7792      C95        S
# 4      1      0        396.0    350052     3.0    7.7958     None        S
#
#    PassengerId  Survived
# 0        762.0       0.0
# 1        665.0       1.0
# 2        809.0       0.0
# 3        332.0       0.0
# 4         21.0       0.0

# %%
test2 = pd.merge(passenger, ticket, how='outer', on='PassengerId')
test2.head()
# Out:
#    PassengerId                                               Name     Sex  \
# 0            1                            Braund, Mr. Owen Harris    male
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2            3                             Heikkinen, Miss. Laina  female
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4            5                           Allen, Mr. William Henry    male
#
#     Age  SibSp  Parch            Ticket  Pclass    Fare Cabin Embarked
# 0  22.0    1.0    0.0         A/5 21171     3.0   7.250  None        S
# 1  38.0    1.0    0.0               NaN     NaN     NaN   NaN      NaN
# 2  26.0    0.0    0.0  STON/O2. 3101282     3.0   7.925  None        S
# 3  35.0    1.0    0.0            113803     1.0  53.100  C123        S
# 4  35.0    0.0    0.0            373450     3.0   8.050  None        S

# %%
test2
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 746          885                                                NaN     NaN
# 747          886               Rice, Mrs. William (Margaret Norton)  female
# 748          887                              Montvila, Rev. Juozas    male
# 749          888                       Graham, Miss. Margaret Edith  female
# 750          891                                                NaN     NaN
#
#       Age  SibSp  Parch            Ticket  Pclass    Fare Cabin Embarked
# 0    22.0    1.0    0.0         A/5 21171     3.0   7.250  None        S
# 1    38.0    1.0    0.0               NaN     NaN     NaN   NaN      NaN
# 2    26.0    0.0    0.0  STON/O2. 3101282     3.0   7.925  None        S
# 3    35.0    1.0    0.0            113803     1.0  53.100  C123        S
# 4    35.0    0.0    0.0            373450     3.0   8.050  None        S
# ..    ...    ...    ...               ...     ...     ...   ...      ...
# 746   NaN    NaN    NaN   SOTON/OQ 392076     3.0   7.050  None        S
# 747  39.0    0.0    5.0            382652     3.0  29.125  None        Q
# 748  27.0    0.0    0.0            211536     2.0  13.000  None        S
# 749  19.0    0.0    0.0            112053     1.0  30.000   B42        S
# 750   NaN    NaN    NaN            370376     3.0   7.750  None        Q
#
# [751 rows x 11 columns]

# %%
test3 = pd.merge(left=test2, right=surv,  how='outer', on='PassengerId')
test3
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889                                                NaN     NaN
# 889          890                                                NaN     NaN
# 890          891                                                NaN     NaN
#
#       Age  SibSp  Parch            Ticket  Pclass    Fare Cabin Embarked  \
# 0    22.0    1.0    0.0         A/5 21171     3.0   7.250  None        S
# 1    38.0    1.0    0.0               NaN     NaN     NaN   NaN      NaN
# 2    26.0    0.0    0.0  STON/O2. 3101282     3.0   7.925  None        S
# 3    35.0    1.0    0.0            113803     1.0  53.100  C123        S
# 4    35.0    0.0    0.0            373450     3.0   8.050  None        S
# ..    ...    ...    ...               ...     ...     ...   ...      ...
# 886  27.0    0.0    0.0            211536     2.0  13.000  None        S
# 887  19.0    0.0    0.0            112053     1.0  30.000   B42        S
# 888   NaN    NaN    NaN               NaN     NaN     NaN   NaN      NaN
# 889   NaN    NaN    NaN               NaN     NaN     NaN   NaN      NaN
# 890   NaN    NaN    NaN            370376     3.0   7.750  None        Q
#
#      Survived
# 0         NaN
# 1         1.0
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 886       NaN
# 887       NaN
# 888       0.0
# 889       1.0
# 890       NaN
#
# [891 rows x 12 columns]

# %%
passenger
# Out:
#      PassengerId                                             Name     Sex  \
# 0            193  Andersen-Jensen, Miss. Carla Christine Nielsine  female
# 1            192                            Carbines, Mr. William    male
# 2            715                            Greenberg, Mr. Samuel    male
# 3            533                             Elias, Mr. Joseph Jr    male
# 4            133   Robins, Mrs. Alexander A (Grace Charity Laury)  female
# ..           ...                                              ...     ...
# 618          580                              Jussila, Mr. Eiriik    male
# 619          503                   O'Sullivan, Miss. Bridget Mary  female
# 620          538                              LeRoy, Miss. Bertha  female
# 621          197                              Mernagh, Mr. Robert    male
# 622          176                           Klasen, Mr. Klas Albin    male
#
#       Age  SibSp  Parch
# 0    19.0      1      0
# 1    19.0      0      0
# 2    52.0      0      0
# 3    17.0      1      1
# 4    47.0      1      0
# ..    ...    ...    ...
# 618  32.0      0      0
# 619   NaN      0      0
# 620  30.0      0      0
# 621   NaN      0      0
# 622  18.0      1      1
#
# [623 rows x 6 columns]

# %%
passenger = passenger.set_index('PassengerId')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 passenger = passenger.set_index('PassengerId')
#       2 passenger
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\frame.py:6122, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6119                 missing.append(col)
#    6121 if missing:
# -> 6122     raise KeyError(f"None of {missing} are in the columns")
#    6124 if inplace:
#    6125     frame = self
#
# KeyError: "None of ['PassengerId'] are in the columns"

# %%
passenger
# Out:
#                                                         Name     Sex   Age  \
# PassengerId
# 193          Andersen-Jensen, Miss. Carla Christine Nielsine  female  19.0
# 192                                    Carbines, Mr. William    male  19.0
# 715                                    Greenberg, Mr. Samuel    male  52.0
# 533                                     Elias, Mr. Joseph Jr    male  17.0
# 133           Robins, Mrs. Alexander A (Grace Charity Laury)  female  47.0
# ...                                                      ...     ...   ...
# 580                                      Jussila, Mr. Eiriik    male  32.0
# 503                           O'Sullivan, Miss. Bridget Mary  female   NaN
# 538                                      LeRoy, Miss. Bertha  female  30.0
# 197                                      Mernagh, Mr. Robert    male   NaN
# 176                                   Klasen, Mr. Klas Albin    male  18.0
#
#              SibSp  Parch
# PassengerId
# 193              1      0
# 192              0      0
# 715              0      0
# 533              1      1
# 133              1      0
# ...            ...    ...
# 580              0      0
# 503              0      0
# 538              0      0
# 197              0      0
# 176              1      1
#
# [623 rows x 5 columns]

# %%
ticket = ticket.set_index("PassengerId")
ticket
# Out:
#                     Ticket  Pclass      Fare    Cabin Embarked
# PassengerId
# 486                   4133       3   25.4667     None        S
# 119               PC 17558       1  247.5208  B58 B60        C
# 836               PC 17756       1   83.1583      E49        C
# 528               PC 17483       1  221.7792      C95        S
# 396                 350052       3    7.7958     None        S
# ...                    ...     ...       ...      ...      ...
# 692                 349256       3   13.4167     None        C
# 585                   3411       3    8.7125     None        C
# 265                 382649       3    7.7500     None        Q
# 328                  28551       2   13.0000        D        S
# 136          SC/PARIS 2133       2   15.0458     None        C
#
# [445 rows x 5 columns]

# %%
passenger.join(ticket)
# Out:
#                                                         Name     Sex   Age  \
# PassengerId
# 193          Andersen-Jensen, Miss. Carla Christine Nielsine  female  19.0
# 192                                    Carbines, Mr. William    male  19.0
# 715                                    Greenberg, Mr. Samuel    male  52.0
# 533                                     Elias, Mr. Joseph Jr    male  17.0
# 133           Robins, Mrs. Alexander A (Grace Charity Laury)  female  47.0
# ...                                                      ...     ...   ...
# 580                                      Jussila, Mr. Eiriik    male  32.0
# 503                           O'Sullivan, Miss. Bridget Mary  female   NaN
# 538                                      LeRoy, Miss. Bertha  female  30.0
# 197                                      Mernagh, Mr. Robert    male   NaN
# 176                                   Klasen, Mr. Klas Albin    male  18.0
#
#              SibSp  Parch             Ticket  Pclass     Fare Cabin Embarked
# PassengerId
# 193              1      0                NaN     NaN      NaN   NaN      NaN
# 192              0      0              28424     2.0  13.0000  None        S
# 715              0      0             250647     2.0  13.0000  None        S
# 533              1      1               2690     3.0   7.2292  None        C
# 133              1      0          A/5. 3337     3.0  14.5000  None        S
# ...            ...    ...                ...     ...      ...   ...      ...
# 580              0      0  STON/O 2. 3101286     3.0   7.9250  None        S
# 503              0      0             330909     3.0   7.6292  None        Q
# 538              0      0                NaN     NaN      NaN   NaN      NaN
# 197              0      0                NaN     NaN      NaN   NaN      NaN
# 176              1      1             350404     3.0   7.8542  None        S
#
# [623 rows x 10 columns]

# %%
data = pd.read_csv("https://raw.githubusercontent.com/haram4th/ablearn/main/Taitanic_train.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # 데이터프레임을 조회
# * 앞쪽 5개 행을 읽는 head()   head(행갯수)
# * 뒤쪽 5개 행을 읽는 tail()   tail(행갯수)

# %%
# head는 60을 넘어가면 자동 축약 출력
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
data.tail(1)
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 890          891         0       3  Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q

# %% [markdown]
# # 데이터의 타입(자료형)을 보고 싶을 때 .dtypes

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # 데이터프레임의 컬럼명, 결측치, 데이터타입을 같이 표시 .info()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 데이터프레임에서 숫자 데이터의 기초통계를 보는 함수 .describe()

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 판다스에서 일부 자료만 추출하기

# %% [markdown]
# ## 1) 데이터프레임에서 1개 컬럼만 가져오기

# %%
data.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
display(data['Name'])
print(type(data['Name']))
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object
# <class 'pandas.core.series.Series'>

# %%
display(data.Name)
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# ## 2) 2개 이상의 컬럼 가져오기

# %%
data[['Name', 'Sex']]
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]

# %%
data[['Name', 'Sex', 'Pclass']]
# Out:
#                                                   Name     Sex  Pclass
# 0                              Braund, Mr. Owen Harris    male       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female       1
# 2                               Heikkinen, Miss. Laina  female       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       1
# 4                             Allen, Mr. William Henry    male       3
# ..                                                 ...     ...     ...
# 886                              Montvila, Rev. Juozas    male       2
# 887                       Graham, Miss. Margaret Edith  female       1
# 888           Johnston, Miss. Catherine Helen "Carrie"  female       3
# 889                              Behr, Mr. Karl Howell    male       1
# 890                                Dooley, Mr. Patrick    male       3
#
# [891 rows x 3 columns]

# %% [markdown]
# ## 데이터프레임 컬럼 순서바꾸기

# %%
data = data[['PassengerId','Pclass','Ticket','Name','Sex','Age','SibSp','Parch','Fare','Cabin','Embarked','Survived']]
data
# Out:
#      PassengerId  Pclass            Ticket  \
# 0              1       3         A/5 21171
# 1              2       1          PC 17599
# 2              3       3  STON/O2. 3101282
# 3              4       1            113803
# 4              5       3            373450
# ..           ...     ...               ...
# 886          887       2            211536
# 887          888       1            112053
# 888          889       3        W./C. 6607
# 889          890       1            111369
# 890          891       3            370376
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch     Fare Cabin Embarked  Survived
# 0        0   7.2500   NaN        S         0
# 1        0  71.2833   C85        C         1
# 2        0   7.9250   NaN        S         1
# 3        0  53.1000  C123        S         1
# 4        0   8.0500   NaN        S         0
# ..     ...      ...   ...      ...       ...
# 886      0  13.0000   NaN        S         0
# 887      0  30.0000   B42        S         1
# 888      2  23.4500   NaN        S         0
# 889      0  30.0000  C148        C         1
# 890      0   7.7500   NaN        Q         0
#
# [891 rows x 12 columns]

# %% [markdown]
# ## 데이터프레임에서 일부 컬럼만 가져오기2
# * loc: 인덱스이름과 컬럼명으로 일부를 추출해서 가져옴
# * iloc: 슬라이싱을 이용해서 가져옴

# %%
data.loc[100:130,['Ticket','Name']]
# Out:
#                 Ticket                               Name
# 100             349245            Petranec, Miss. Matilda
# 101             349215   Petroff, Mr. Pastcho ("Pentcho")
# 102              35281          White, Mr. Richard Frasar
# 103               7540         Johansson, Mr. Gustaf Joel
# 104            3101276     Gustafsson, Mr. Anders Vilhelm
# 105             349207              Mionoff, Mr. Stoytcho
# 106             343120   Salkjelsvik, Miss. Anna Kristine
# 107             312991             Moss, Mr. Albert Johan
# 108             349249                    Rekic, Mr. Tido
# 109             371110                Moran, Miss. Bertha
# 110             110465     Porter, Mr. Walter Chamberlain
# 111               2665               Zabour, Miss. Hileni
# 112             324669             Barton, Mr. David John
# 113               4136            Jussila, Miss. Katriina
# 114               2627              Attalah, Miss. Malake
# 115  STON/O 2. 3101294              Pekoniemi, Mr. Edvard
# 116             370369               Connors, Mr. Patrick
# 117              11668    Turpin, Mr. William John Robert
# 118           PC 17558           Baxter, Mr. Quigg Edmond
# 119             347082  Andersson, Miss. Ellis Anna Maria
# 120       S.O.C. 14879        Hickman, Mr. Stanley George
# 121          A4. 54510         Moore, Mr. Leonard Charles
# 122             237736               Nasser, Mr. Nicholas
# 123              27267                Webber, Miss. Susan
# 124              35281        White, Mr. Percival Wayland
# 125               2651       Nicola-Yarred, Master. Elias
# 126             370372                McMahon, Mr. Martin
# 127            C 17369          Madsen, Mr. Fridtjof Arne
# 128               2668                  Peter, Miss. Anna
# 129             347061                 Ekstrom, Mr. Johan
# 130             349241               Drazenoic, Mr. Jozef

# %%
data.loc[:130,['Ticket','Name']]
# Out:
#                Ticket                                               Name
# 0           A/5 21171                            Braund, Mr. Owen Harris
# 1            PC 17599  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    STON/O2. 3101282                             Heikkinen, Miss. Laina
# 3              113803       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              373450                           Allen, Mr. William Henry
# ..                ...                                                ...
# 126            370372                                McMahon, Mr. Martin
# 127           C 17369                          Madsen, Mr. Fridtjof Arne
# 128              2668                                  Peter, Miss. Anna
# 129            347061                                 Ekstrom, Mr. Johan
# 130            349241                               Drazenoic, Mr. Jozef
#
# [131 rows x 2 columns]

# %%
data.loc[500:,['Ticket','Name']]
# Out:
#          Ticket                                      Name
# 500      315086                          Calic, Mr. Petar
# 501      364846                       Canavan, Miss. Mary
# 502      330909            O'Sullivan, Miss. Bridget Mary
# 503        4135            Laitinen, Miss. Kristina Sofia
# 504      110152                     Maioni, Miss. Roberta
# ..          ...                                       ...
# 886      211536                     Montvila, Rev. Juozas
# 887      112053              Graham, Miss. Margaret Edith
# 888  W./C. 6607  Johnston, Miss. Catherine Helen "Carrie"
# 889      111369                     Behr, Mr. Karl Howell
# 890      370376                       Dooley, Mr. Patrick
#
# [391 rows x 2 columns]

# %%
data.loc[500::2,['Ticket','Name']]
# Out:
#               Ticket                                           Name
# 500           315086                               Calic, Mr. Petar
# 502           330909                 O'Sullivan, Miss. Bridget Mary
# 504           110152                          Maioni, Miss. Roberta
# 506            26360  Quick, Mrs. Frederick Charles (Jane Richards)
# 508           C 4001                       Olsen, Mr. Henry Margido
# ..               ...                                            ...
# 882             7552                   Dahlberg, Miss. Gerda Ulrika
# 884  SOTON/OQ 392076                         Sutehall, Mr. Henry Jr
# 886           211536                          Montvila, Rev. Juozas
# 888       W./C. 6607       Johnston, Miss. Catherine Helen "Carrie"
# 890           370376                            Dooley, Mr. Patrick
#
# [196 rows x 2 columns]

# %%
data.iloc[10:20,4:8]
# Out:
#        Sex   Age  SibSp  Parch
# 10  female   4.0      1      1
# 11  female  58.0      0      0
# 12    male  20.0      0      0
# 13    male  39.0      1      5
# 14  female  14.0      0      0
# 15  female  55.0      0      0
# 16    male   2.0      4      1
# 17    male   NaN      0      0
# 18  female  31.0      1      0
# 19  female   NaN      0      0

# %%
data.iloc[:20,4:]
# Out:
#        Sex   Age  SibSp  Parch     Fare Cabin Embarked  Survived
# 0     male  22.0      1      0   7.2500   NaN        S         0
# 1   female  38.0      1      0  71.2833   C85        C         1
# 2   female  26.0      0      0   7.9250   NaN        S         1
# 3   female  35.0      1      0  53.1000  C123        S         1
# 4     male  35.0      0      0   8.0500   NaN        S         0
# 5     male   NaN      0      0   8.4583   NaN        Q         0
# 6     male  54.0      0      0  51.8625   E46        S         0
# 7     male   2.0      3      1  21.0750   NaN        S         0
# 8   female  27.0      0      2  11.1333   NaN        S         1
# 9   female  14.0      1      0  30.0708   NaN        C         1
# 10  female   4.0      1      1  16.7000    G6        S         1
# 11  female  58.0      0      0  26.5500  C103        S         1
# 12    male  20.0      0      0   8.0500   NaN        S         0
# 13    male  39.0      1      5  31.2750   NaN        S         0
# 14  female  14.0      0      0   7.8542   NaN        S         0
# 15  female  55.0      0      0  16.0000   NaN        S         1
# 16    male   2.0      4      1  29.1250   NaN        Q         0
# 17    male   NaN      0      0  13.0000   NaN        S         1
# 18  female  31.0      1      0  18.0000   NaN        S         0
# 19  female   NaN      0      0   7.2250   NaN        C         1

# %%
data.iloc[:20,:]
# Out:
#     PassengerId  Pclass            Ticket  \
# 0             1       3         A/5 21171
# 1             2       1          PC 17599
# 2             3       3  STON/O2. 3101282
# 3             4       1            113803
# 4             5       3            373450
# 5             6       3            330877
# 6             7       1             17463
# 7             8       3            349909
# 8             9       3            347742
# 9            10       2            237736
# 10           11       3           PP 9549
# 11           12       1            113783
# 12           13       3         A/5. 2151
# 13           14       3            347082
# 14           15       3            350406
# 15           16       2            248706
# 16           17       3            382652
# 17           18       2            244373
# 18           19       3            345763
# 19           20       3              2649
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch     Fare Cabin Embarked  Survived
# 0       0   7.2500   NaN        S         0
# 1       0  71.2833   C85        C         1
# 2       0   7.9250   NaN        S         1
# 3       0  53.1000  C123        S         1
# 4       0   8.0500   NaN        S         0
# 5       0   8.4583   NaN        Q         0
# 6       0  51.8625   E46        S         0
# 7       1  21.0750   NaN        S         0
# 8       2  11.1333   NaN        S         1
# 9       0  30.0708   NaN        C         1
# 10      1  16.7000    G6        S         1
# 11      0  26.5500  C103        S         1
# 12      0   8.0500   NaN        S         0
# 13      5  31.2750   NaN        S         0
# 14      0   7.8542   NaN        S         0
# 15      0  16.0000   NaN        S         1
# 16      1  29.1250   NaN        Q         0
# 17      0  13.0000   NaN        S         1
# 18      0  18.0000   NaN        S         0
# 19      0   7.2250   NaN        C         1

# %%
data.iloc[:20:2,::-1]
# Out:
#     Survived Embarked Cabin     Fare  Parch  SibSp   Age     Sex  \
# 0          0        S   NaN   7.2500      0      1  22.0    male
# 2          1        S   NaN   7.9250      0      0  26.0  female
# 4          0        S   NaN   8.0500      0      0  35.0    male
# 6          0        S   E46  51.8625      0      0  54.0    male
# 8          1        S   NaN  11.1333      2      0  27.0  female
# 10         1        S    G6  16.7000      1      1   4.0  female
# 12         0        S   NaN   8.0500      0      0  20.0    male
# 14         0        S   NaN   7.8542      0      0  14.0  female
# 16         0        Q   NaN  29.1250      1      4   2.0    male
# 18         0        S   NaN  18.0000      0      1  31.0  female
#
#                                                  Name            Ticket  \
# 0                             Braund, Mr. Owen Harris         A/5 21171
# 2                              Heikkinen, Miss. Laina  STON/O2. 3101282
# 4                            Allen, Mr. William Henry            373450
# 6                             McCarthy, Mr. Timothy J             17463
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            347742
# 10                    Sandstrom, Miss. Marguerite Rut           PP 9549
# 12                     Saundercock, Mr. William Henry         A/5. 2151
# 14               Vestrom, Miss. Hulda Amanda Adolfina            350406
# 16                               Rice, Master. Eugene            382652
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...            345763
#
#     Pclass  PassengerId
# 0        3            1
# 2        3            3
# 4        3            5
# 6        1            7
# 8        3            9
# 10       3           11
# 12       3           13
# 14       3           15
# 16       3           17
# 18       3           19

# %% [markdown]
# # 특정 컬럼에서 유일값 요소 출력하기 .unique()

# %%
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %% [markdown]
# # 특정 컬럼에서 유일값 개수 출력 .nunique()

# %%
# data['Name'].unique()

# %%
data['Name'].nunique()
# Out:
# 891

# %%
data['Embarked'].nunique()
# Out:
# 3

# %% [markdown]
# # 카테고리 컬럼에서 유일값 별 개수를 세는 함수 value_counts()

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
data['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # 데이터를 정렬하는 함수 sort_values(by="컬럼명")

# %%
data.sort_values(by="Age", ascending=False)
# Out:
#      PassengerId  Pclass      Ticket  \
# 630          631       1       27042
# 851          852       3      347060
# 493          494       1    PC 17609
# 96            97       1    PC 17754
# 116          117       3      370369
# ..           ...     ...         ...
# 859          860       3        2629
# 863          864       3    CA. 2343
# 868          869       3      345777
# 878          879       3      349217
# 888          889       3  W./C. 6607
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 630      Barkworth, Mr. Algernon Henry Wilson    male  80.0      0      0
# 851                       Svensson, Mr. Johan    male  74.0      0      0
# 493                   Artagaveytia, Mr. Ramon    male  71.0      0      0
# 96                  Goldschmidt, Mr. George B    male  71.0      0      0
# 116                      Connors, Mr. Patrick    male  70.5      0      0
# ..                                        ...     ...   ...    ...    ...
# 859                          Razi, Mr. Raihed    male   NaN      0      0
# 863         Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8      2
# 868               van Melkebeke, Mr. Philemon    male   NaN      0      0
# 878                        Laleff, Mr. Kristo    male   NaN      0      0
# 888  Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
#
#         Fare Cabin Embarked  Survived
# 630  30.0000   A23        S         1
# 851   7.7750   NaN        S         0
# 493  49.5042   NaN        C         0
# 96   34.6542    A5        C         0
# 116   7.7500   NaN        Q         0
# ..       ...   ...      ...       ...
# 859   7.2292   NaN        C         0
# 863  69.5500   NaN        S         0
# 868   9.5000   NaN        S         0
# 878   7.8958   NaN        S         0
# 888  23.4500   NaN        S         0
#
# [891 rows x 12 columns]

# %%
data.sort_values(by=["Age", "Name"], ascending=[False, True])
# Out:
#      PassengerId  Pclass    Ticket                                  Name  \
# 630          631       1     27042  Barkworth, Mr. Algernon Henry Wilson
# 851          852       3    347060                   Svensson, Mr. Johan
# 493          494       1  PC 17609               Artagaveytia, Mr. Ramon
# 96            97       1  PC 17754             Goldschmidt, Mr. George B
# 116          117       3    370369                  Connors, Mr. Patrick
# ..           ...     ...       ...                                   ...
# 55            56       1     19947                     Woolner, Mr. Hugh
# 354          355       3      2647                     Yousif, Mr. Wazli
# 495          496       3      2627                 Yousseff, Mr. Gerious
# 240          241       3      2665                 Zabour, Miss. Thamine
# 868          869       3    345777           van Melkebeke, Mr. Philemon
#
#         Sex   Age  SibSp  Parch     Fare Cabin Embarked  Survived
# 630    male  80.0      0      0  30.0000   A23        S         1
# 851    male  74.0      0      0   7.7750   NaN        S         0
# 493    male  71.0      0      0  49.5042   NaN        C         0
# 96     male  71.0      0      0  34.6542    A5        C         0
# 116    male  70.5      0      0   7.7500   NaN        Q         0
# ..      ...   ...    ...    ...      ...   ...      ...       ...
# 55     male   NaN      0      0  35.5000   C52        S         1
# 354    male   NaN      0      0   7.2250   NaN        C         0
# 495    male   NaN      0      0  14.4583   NaN        C         0
# 240  female   NaN      1      0  14.4542   NaN        C         0
# 868    male   NaN      0      0   9.5000   NaN        S         0
#
# [891 rows x 12 columns]

# %% [markdown]
# # 컬럼을 인덱스로 지정하기 set_index("컬럼명")

# %%
data.set_index("PassengerId")
# Out:
#              Pclass            Ticket  \
# PassengerId
# 1                 3         A/5 21171
# 2                 1          PC 17599
# 3                 3  STON/O2. 3101282
# 4                 1            113803
# 5                 3            373450
# ...             ...               ...
# 887               2            211536
# 888               1            112053
# 889               3        W./C. 6607
# 890               1            111369
# 891               3            370376
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch     Fare Cabin Embarked  Survived
# PassengerId
# 1                1      0   7.2500   NaN        S         0
# 2                1      0  71.2833   C85        C         1
# 3                0      0   7.9250   NaN        S         1
# 4                1      0  53.1000  C123        S         1
# 5                0      0   8.0500   NaN        S         0
# ...            ...    ...      ...   ...      ...       ...
# 887              0      0  13.0000   NaN        S         0
# 888              0      0  30.0000   B42        S         1
# 889              1      2  23.4500   NaN        S         0
# 890              0      0  30.0000  C148        C         1
# 891              0      0   7.7500   NaN        Q         0
#
# [891 rows x 11 columns]

# %%
data = data.set_index(["PassengerId","Name"])
data
# Out:
#                                                                 Pclass  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                  3
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# 3           Heikkinen, Miss. Laina                                   3
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)             1
# 5           Allen, Mr. William Henry                                 3
# ...                                                                ...
# 887         Montvila, Rev. Juozas                                    2
# 888         Graham, Miss. Margaret Edith                             1
# 889         Johnston, Miss. Catherine Helen "Carrie"                 3
# 890         Behr, Mr. Karl Howell                                    1
# 891         Dooley, Mr. Patrick                                      3
#
#                                                                           Ticket  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                    A/5 21171
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599
# 3           Heikkinen, Miss. Laina                              STON/O2. 3101282
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803
# 5           Allen, Mr. William Henry                                      373450
# ...                                                                          ...
# 887         Montvila, Rev. Juozas                                         211536
# 888         Graham, Miss. Margaret Edith                                  112053
# 889         Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607
# 890         Behr, Mr. Karl Howell                                         111369
# 891         Dooley, Mr. Patrick                                           370376
#
#                                                                    Sex   Age  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                               male  22.0
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0
# 3           Heikkinen, Miss. Laina                              female  26.0
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)        female  35.0
# 5           Allen, Mr. William Henry                              male  35.0
# ...                                                                ...   ...
# 887         Montvila, Rev. Juozas                                 male  27.0
# 888         Graham, Miss. Margaret Edith                        female  19.0
# 889         Johnston, Miss. Catherine Helen "Carrie"            female   NaN
# 890         Behr, Mr. Karl Howell                                 male  26.0
# 891         Dooley, Mr. Patrick                                   male  32.0
#
#                                                                 SibSp  Parch  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                 1      0
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# 3           Heikkinen, Miss. Laina                                  0      0
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)            1      0
# 5           Allen, Mr. William Henry                                0      0
# ...                                                               ...    ...
# 887         Montvila, Rev. Juozas                                   0      0
# 888         Graham, Miss. Margaret Edith                            0      0
# 889         Johnston, Miss. Catherine Helen "Carrie"                1      2
# 890         Behr, Mr. Karl Howell                                   0      0
# 891         Dooley, Mr. Patrick                                     0      0
#
#                                                                    Fare Cabin  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                              7.2500   NaN
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# 3           Heikkinen, Miss. Laina                               7.9250   NaN
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# 5           Allen, Mr. William Henry                             8.0500   NaN
# ...                                                                 ...   ...
# 887         Montvila, Rev. Juozas                               13.0000   NaN
# 888         Graham, Miss. Margaret Edith                        30.0000   B42
# 889         Johnston, Miss. Catherine Helen "Carrie"            23.4500   NaN
# 890         Behr, Mr. Karl Howell                               30.0000  C148
# 891         Dooley, Mr. Patrick                                  7.7500   NaN
#
#                                                                Embarked  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                   S
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...        C
# 3           Heikkinen, Miss. Laina                                    S
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)              S
# 5           Allen, Mr. William Henry                                  S
# ...                                                                 ...
# 887         Montvila, Rev. Juozas                                     S
# 888         Graham, Miss. Margaret Edith                              S
# 889         Johnston, Miss. Catherine Helen "Carrie"                  S
# 890         Behr, Mr. Karl Howell                                     C
# 891         Dooley, Mr. Patrick                                       Q
#
#                                                                 Survived
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                    0
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...         1
# 3           Heikkinen, Miss. Laina                                     1
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)               1
# 5           Allen, Mr. William Henry                                   0
# ...                                                                  ...
# 887         Montvila, Rev. Juozas                                      0
# 888         Graham, Miss. Margaret Edith                               1
# 889         Johnston, Miss. Catherine Helen "Carrie"                   0
# 890         Behr, Mr. Karl Howell                                      1
# 891         Dooley, Mr. Patrick                                        0
#
# [891 rows x 10 columns]

# %% [markdown]
# # 인덱스를 숫자로 초기화 reset_index(drop="원래인덱스를 유지? 삭제)

# %%
data.reset_index(drop=True)
# Out:
#      Pclass            Ticket     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0         3         A/5 21171    male  22.0      1      0   7.2500   NaN
# 1         1          PC 17599  female  38.0      1      0  71.2833   C85
# 2         3  STON/O2. 3101282  female  26.0      0      0   7.9250   NaN
# 3         1            113803  female  35.0      1      0  53.1000  C123
# 4         3            373450    male  35.0      0      0   8.0500   NaN
# ..      ...               ...     ...   ...    ...    ...      ...   ...
# 886       2            211536    male  27.0      0      0  13.0000   NaN
# 887       1            112053  female  19.0      0      0  30.0000   B42
# 888       3        W./C. 6607  female   NaN      1      2  23.4500   NaN
# 889       1            111369    male  26.0      0      0  30.0000  C148
# 890       3            370376    male  32.0      0      0   7.7500   NaN
#
#     Embarked  Survived
# 0          S         0
# 1          C         1
# 2          S         1
# 3          S         1
# 4          S         0
# ..       ...       ...
# 886        S         0
# 887        S         1
# 888        S         0
# 889        C         1
# 890        Q         0
#
# [891 rows x 10 columns]

# %%
data = data.reset_index()
data
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
#                Ticket     Sex   Age  SibSp  Parch     Fare Cabin Embarked  \
# 0           A/5 21171    male  22.0      1      0   7.2500   NaN        S
# 1            PC 17599  female  38.0      1      0  71.2833   C85        C
# 2    STON/O2. 3101282  female  26.0      0      0   7.9250   NaN        S
# 3              113803  female  35.0      1      0  53.1000  C123        S
# 4              373450    male  35.0      0      0   8.0500   NaN        S
# ..                ...     ...   ...    ...    ...      ...   ...      ...
# 886            211536    male  27.0      0      0  13.0000   NaN        S
# 887            112053  female  19.0      0      0  30.0000   B42        S
# 888        W./C. 6607  female   NaN      1      2  23.4500   NaN        S
# 889            111369    male  26.0      0      0  30.0000  C148        C
# 890            370376    male  32.0      0      0   7.7500   NaN        Q
#
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 12 columns]

# %% [markdown]
# # 컬럼이름 출력 .columns

# %%
col = data.columns
col
# Out:
# Index(['PassengerId', 'Name', 'Pclass', 'Ticket', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Fare', 'Cabin', 'Embarked', 'Survived'],
#       dtype='object')

# %% [markdown]
# # 컬럼 이름 변경하기
# * rename(columns={이름1 : 변경할 이름1})
# * columns = [컬럼이름]

# %%
data = data.rename(columns={"PassengerId" : "승객번호"})
data
# Out:
#      승객번호                                               Name  Pclass  \
# 0       1                            Braund, Mr. Owen Harris       3
# 1       2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2       3                             Heikkinen, Miss. Laina       3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4       5                           Allen, Mr. William Henry       3
# ..    ...                                                ...     ...
# 886   887                              Montvila, Rev. Juozas       2
# 887   888                       Graham, Miss. Margaret Edith       1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889   890                              Behr, Mr. Karl Howell       1
# 890   891                                Dooley, Mr. Patrick       3
#
#                Ticket     Sex   Age  SibSp  Parch     Fare Cabin Embarked  \
# 0           A/5 21171    male  22.0      1      0   7.2500   NaN        S
# 1            PC 17599  female  38.0      1      0  71.2833   C85        C
# 2    STON/O2. 3101282  female  26.0      0      0   7.9250   NaN        S
# 3              113803  female  35.0      1      0  53.1000  C123        S
# 4              373450    male  35.0      0      0   8.0500   NaN        S
# ..                ...     ...   ...    ...    ...      ...   ...      ...
# 886            211536    male  27.0      0      0  13.0000   NaN        S
# 887            112053  female  19.0      0      0  30.0000   B42        S
# 888        W./C. 6607  female   NaN      1      2  23.4500   NaN        S
# 889            111369    male  26.0      0      0  30.0000  C148        C
# 890            370376    male  32.0      0      0   7.7500   NaN        Q
#
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 12 columns]

# %%
data = data.rename(columns=dict(Name="이름", Pclass="선실등급"))
data
# Out:
#      승객번호                                                 이름  선실등급  \
# 0       1                            Braund, Mr. Owen Harris     3
# 1       2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 2       3                             Heikkinen, Miss. Laina     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 4       5                           Allen, Mr. William Henry     3
# ..    ...                                                ...   ...
# 886   887                              Montvila, Rev. Juozas     2
# 887   888                       Graham, Miss. Margaret Edith     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     3
# 889   890                              Behr, Mr. Karl Howell     1
# 890   891                                Dooley, Mr. Patrick     3
#
#                Ticket     Sex   Age  SibSp  Parch     Fare Cabin Embarked  \
# 0           A/5 21171    male  22.0      1      0   7.2500   NaN        S
# 1            PC 17599  female  38.0      1      0  71.2833   C85        C
# 2    STON/O2. 3101282  female  26.0      0      0   7.9250   NaN        S
# 3              113803  female  35.0      1      0  53.1000  C123        S
# 4              373450    male  35.0      0      0   8.0500   NaN        S
# ..                ...     ...   ...    ...    ...      ...   ...      ...
# 886            211536    male  27.0      0      0  13.0000   NaN        S
# 887            112053  female  19.0      0      0  30.0000   B42        S
# 888        W./C. 6607  female   NaN      1      2  23.4500   NaN        S
# 889            111369    male  26.0      0      0  30.0000  C148        C
# 890            370376    male  32.0      0      0   7.7500   NaN        Q
#
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 12 columns]

# %%
col
# Out:
# Index(['PassengerId', 'Name', 'Pclass', 'Ticket', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Fare', 'Cabin', 'Embarked', 'Survived'],
#       dtype='object')

# %%
data.columns = ['승객번호', '승객이름', '선실등급', '승차권번호', '성별', '나이', '형제자매수',
       '부모자식수', '승차권금액', '좌석번호', '정박지', '생존여부']

# %%
data
# Out:
#      승객번호                                               승객이름  선실등급  \
# 0       1                            Braund, Mr. Owen Harris     3
# 1       2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 2       3                             Heikkinen, Miss. Laina     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 4       5                           Allen, Mr. William Henry     3
# ..    ...                                                ...   ...
# 886   887                              Montvila, Rev. Juozas     2
# 887   888                       Graham, Miss. Margaret Edith     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     3
# 889   890                              Behr, Mr. Karl Howell     1
# 890   891                                Dooley, Mr. Patrick     3
#
#                 승차권번호      성별    나이  형제자매수  부모자식수    승차권금액  좌석번호 정박지  생존여부
# 0           A/5 21171    male  22.0      1      0   7.2500   NaN   S     0
# 1            PC 17599  female  38.0      1      0  71.2833   C85   C     1
# 2    STON/O2. 3101282  female  26.0      0      0   7.9250   NaN   S     1
# 3              113803  female  35.0      1      0  53.1000  C123   S     1
# 4              373450    male  35.0      0      0   8.0500   NaN   S     0
# ..                ...     ...   ...    ...    ...      ...   ...  ..   ...
# 886            211536    male  27.0      0      0  13.0000   NaN   S     0
# 887            112053  female  19.0      0      0  30.0000   B42   S     1
# 888        W./C. 6607  female   NaN      1      2  23.4500   NaN   S     0
# 889            111369    male  26.0      0      0  30.0000  C148   C     1
# 890            370376    male  32.0      0      0   7.7500   NaN   Q     0
#
# [891 rows x 12 columns]

# %%
data.columns
# Out:
# Index(['승객번호', '승객이름', '선실등급', '승차권번호', '성별', '나이', '형제자매수', '부모자식수', '승차권금액',
#        '좌석번호', '정박지', '생존여부'],
#       dtype='object')

# %% [markdown]
# # 컬럼 추가/삭제하기

# %%
data['가족수'] = data['형제자매수']

# %%
data
# Out:
#      승객번호                                               승객이름  선실등급  \
# 0       1                            Braund, Mr. Owen Harris     3
# 1       2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 2       3                             Heikkinen, Miss. Laina     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 4       5                           Allen, Mr. William Henry     3
# ..    ...                                                ...   ...
# 886   887                              Montvila, Rev. Juozas     2
# 887   888                       Graham, Miss. Margaret Edith     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     3
# 889   890                              Behr, Mr. Karl Howell     1
# 890   891                                Dooley, Mr. Patrick     3
#
#                 승차권번호      성별    나이  형제자매수  부모자식수    승차권금액  좌석번호 정박지  생존여부  \
# 0           A/5 21171    male  22.0      1      0   7.2500   NaN   S     0
# 1            PC 17599  female  38.0      1      0  71.2833   C85   C     1
# 2    STON/O2. 3101282  female  26.0      0      0   7.9250   NaN   S     1
# 3              113803  female  35.0      1      0  53.1000  C123   S     1
# 4              373450    male  35.0      0      0   8.0500   NaN   S     0
# ..                ...     ...   ...    ...    ...      ...   ...  ..   ...
# 886            211536    male  27.0      0      0  13.0000   NaN   S     0
# 887            112053  female  19.0      0      0  30.0000   B42   S     1
# 888        W./C. 6607  female   NaN      1      2  23.4500   NaN   S     0
# 889            111369    male  26.0      0      0  30.0000  C148   C     1
# 890            370376    male  32.0      0      0   7.7500   NaN   Q     0
#
#      가족수
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
# ..   ...
# 886    0
# 887    0
# 888    1
# 889    0
# 890    0
#
# [891 rows x 13 columns]

# %%
data['테스트'] = "테스트"

# %%
data
# Out:
#      승객번호                                               승객이름  선실등급  \
# 0       1                            Braund, Mr. Owen Harris     3
# 1       2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 2       3                             Heikkinen, Miss. Laina     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 4       5                           Allen, Mr. William Henry     3
# ..    ...                                                ...   ...
# 886   887                              Montvila, Rev. Juozas     2
# 887   888                       Graham, Miss. Margaret Edith     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     3
# 889   890                              Behr, Mr. Karl Howell     1
# 890   891                                Dooley, Mr. Patrick     3
#
#                 승차권번호      성별    나이  형제자매수  부모자식수    승차권금액  좌석번호 정박지  생존여부  \
# 0           A/5 21171    male  22.0      1      0   7.2500   NaN   S     0
# 1            PC 17599  female  38.0      1      0  71.2833   C85   C     1
# 2    STON/O2. 3101282  female  26.0      0      0   7.9250   NaN   S     1
# 3              113803  female  35.0      1      0  53.1000  C123   S     1
# 4              373450    male  35.0      0      0   8.0500   NaN   S     0
# ..                ...     ...   ...    ...    ...      ...   ...  ..   ...
# 886            211536    male  27.0      0      0  13.0000   NaN   S     0
# 887            112053  female  19.0      0      0  30.0000   B42   S     1
# 888        W./C. 6607  female   NaN      1      2  23.4500   NaN   S     0
# 889            111369    male  26.0      0      0  30.0000  C148   C     1
# 890            370376    male  32.0      0      0   7.7500   NaN   Q     0
#
#      가족수  테스트
# 0      1  테스트
# 1      1  테스트
# 2      0  테스트
# 3      1  테스트
# 4      0  테스트
# ..   ...  ...
# 886    0  테스트
# 887    0  테스트
# 888    1  테스트
# 889    0  테스트
# 890    0  테스트
#
# [891 rows x 14 columns]

# %% [markdown]
# ## 데이터프레임의 컬럼과 컬럼을 연산해서 새로운 컬럼 만들기

# %%
data.columns
# Out:
# Index(['승객번호', '승객이름', '선실등급', '승차권번호', '성별', '나이', '형제자매수', '부모자식수', '승차권금액',
#        '좌석번호', '정박지', '생존여부'],
#       dtype='object')

# %%
data['가족수'] = data['형제자매수'] + data['부모자식수']
data.head()
# Out:
#    승객번호                                               승객이름  선실등급  \
# 0     1                            Braund, Mr. Owen Harris     3
# 1     2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 2     3                             Heikkinen, Miss. Laina     3
# 3     4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 4     5                           Allen, Mr. William Henry     3
#
#               승차권번호      성별    나이  형제자매수  부모자식수    승차권금액  좌석번호 정박지  생존여부  가족수
# 0         A/5 21171    male  22.0      1      0   7.2500   NaN   S     0    1
# 1          PC 17599  female  38.0      1      0  71.2833   C85   C     1    1
# 2  STON/O2. 3101282  female  26.0      0      0   7.9250   NaN   S     1    0
# 3            113803  female  35.0      1      0  53.1000  C123   S     1    1
# 4            373450    male  35.0      0      0   8.0500   NaN   S     0    0

# %%
data['승차권'] = data['승차권번호'] + data['좌석번호']
data
# Out:
#      승객번호                                               승객이름  선실등급  \
# 0       1                            Braund, Mr. Owen Harris     3
# 1       2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 2       3                             Heikkinen, Miss. Laina     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 4       5                           Allen, Mr. William Henry     3
# ..    ...                                                ...   ...
# 886   887                              Montvila, Rev. Juozas     2
# 887   888                       Graham, Miss. Margaret Edith     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     3
# 889   890                              Behr, Mr. Karl Howell     1
# 890   891                                Dooley, Mr. Patrick     3
#
#                 승차권번호      성별    나이    승차권금액  좌석번호 정박지  생존여부  가족수          승차권
# 0           A/5 21171    male  22.0   7.2500   NaN   S     0    1          NaN
# 1            PC 17599  female  38.0  71.2833   C85   C     1    1  PC 17599C85
# 2    STON/O2. 3101282  female  26.0   7.9250   NaN   S     1    0          NaN
# 3              113803  female  35.0  53.1000  C123   S     1    1   113803C123
# 4              373450    male  35.0   8.0500   NaN   S     0    0          NaN
# ..                ...     ...   ...      ...   ...  ..   ...  ...          ...
# 886            211536    male  27.0  13.0000   NaN   S     0    0          NaN
# 887            112053  female  19.0  30.0000   B42   S     1    0    112053B42
# 888        W./C. 6607  female   NaN  23.4500   NaN   S     0    3          NaN
# 889            111369    male  26.0  30.0000  C148   C     1    0   111369C148
# 890            370376    male  32.0   7.7500   NaN   Q     0    0          NaN
#
# [891 rows x 12 columns]

# %% [markdown]
# ## 컬럼 삭제하기
# * del 변수명['컬럼명']
# * 변수명.drop("컬럼명", axis=1)   변수명.drop(["컬럼명1", "컬럼명2"], axis=1)

# %%
del data['테스트']

# %%
data
# Out:
#      승객번호                                               승객이름  선실등급  \
# 0       1                            Braund, Mr. Owen Harris     3
# 1       2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 2       3                             Heikkinen, Miss. Laina     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 4       5                           Allen, Mr. William Henry     3
# ..    ...                                                ...   ...
# 886   887                              Montvila, Rev. Juozas     2
# 887   888                       Graham, Miss. Margaret Edith     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     3
# 889   890                              Behr, Mr. Karl Howell     1
# 890   891                                Dooley, Mr. Patrick     3
#
#                 승차권번호      성별    나이  형제자매수  부모자식수    승차권금액  좌석번호 정박지  생존여부  \
# 0           A/5 21171    male  22.0      1      0   7.2500   NaN   S     0
# 1            PC 17599  female  38.0      1      0  71.2833   C85   C     1
# 2    STON/O2. 3101282  female  26.0      0      0   7.9250   NaN   S     1
# 3              113803  female  35.0      1      0  53.1000  C123   S     1
# 4              373450    male  35.0      0      0   8.0500   NaN   S     0
# ..                ...     ...   ...    ...    ...      ...   ...  ..   ...
# 886            211536    male  27.0      0      0  13.0000   NaN   S     0
# 887            112053  female  19.0      0      0  30.0000   B42   S     1
# 888        W./C. 6607  female   NaN      1      2  23.4500   NaN   S     0
# 889            111369    male  26.0      0      0  30.0000  C148   C     1
# 890            370376    male  32.0      0      0   7.7500   NaN   Q     0
#
#      가족수
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
# ..   ...
# 886    0
# 887    0
# 888    1
# 889    0
# 890    0
#
# [891 rows x 13 columns]

# %%
data.drop('가족수', axis=1, inplace=True)

# %%
data
# Out:
#      승객번호                                               승객이름  선실등급  \
# 0       1                            Braund, Mr. Owen Harris     3
# 1       2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 2       3                             Heikkinen, Miss. Laina     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 4       5                           Allen, Mr. William Henry     3
# ..    ...                                                ...   ...
# 886   887                              Montvila, Rev. Juozas     2
# 887   888                       Graham, Miss. Margaret Edith     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     3
# 889   890                              Behr, Mr. Karl Howell     1
# 890   891                                Dooley, Mr. Patrick     3
#
#                 승차권번호      성별    나이  형제자매수  부모자식수    승차권금액  좌석번호 정박지  생존여부
# 0           A/5 21171    male  22.0      1      0   7.2500   NaN   S     0
# 1            PC 17599  female  38.0      1      0  71.2833   C85   C     1
# 2    STON/O2. 3101282  female  26.0      0      0   7.9250   NaN   S     1
# 3              113803  female  35.0      1      0  53.1000  C123   S     1
# 4              373450    male  35.0      0      0   8.0500   NaN   S     0
# ..                ...     ...   ...    ...    ...      ...   ...  ..   ...
# 886            211536    male  27.0      0      0  13.0000   NaN   S     0
# 887            112053  female  19.0      0      0  30.0000   B42   S     1
# 888        W./C. 6607  female   NaN      1      2  23.4500   NaN   S     0
# 889            111369    male  26.0      0      0  30.0000  C148   C     1
# 890            370376    male  32.0      0      0   7.7500   NaN   Q     0
#
# [891 rows x 12 columns]

# %%
data = data.drop('승객번호', axis=1)

# %%
data = data.drop(['형제자매수', '부모자식수'], axis=1)
data
# Out:
#                                                   승객이름  선실등급  \
# 0                              Braund, Mr. Owen Harris     3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 2                               Heikkinen, Miss. Laina     3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 4                             Allen, Mr. William Henry     3
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas     2
# 887                       Graham, Miss. Margaret Edith     1
# 888           Johnston, Miss. Catherine Helen "Carrie"     3
# 889                              Behr, Mr. Karl Howell     1
# 890                                Dooley, Mr. Patrick     3
#
#                 승차권번호      성별    나이    승차권금액  좌석번호 정박지  생존여부  가족수
# 0           A/5 21171    male  22.0   7.2500   NaN   S     0    1
# 1            PC 17599  female  38.0  71.2833   C85   C     1    1
# 2    STON/O2. 3101282  female  26.0   7.9250   NaN   S     1    0
# 3              113803  female  35.0  53.1000  C123   S     1    1
# 4              373450    male  35.0   8.0500   NaN   S     0    0
# ..                ...     ...   ...      ...   ...  ..   ...  ...
# 886            211536    male  27.0  13.0000   NaN   S     0    0
# 887            112053  female  19.0  30.0000   B42   S     1    0
# 888        W./C. 6607  female   NaN  23.4500   NaN   S     0    3
# 889            111369    male  26.0  30.0000  C148   C     1    0
# 890            370376    male  32.0   7.7500   NaN   Q     0    0
#
# [891 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객이름    891 non-null    object
#  1   선실등급    891 non-null    int64
#  2   승차권번호   891 non-null    object
#  3   성별      891 non-null    object
#  4   나이      714 non-null    float64
#  5   승차권금액   891 non-null    float64
#  6   좌석번호    204 non-null    object
#  7   정박지     889 non-null    object
#  8   생존여부    891 non-null    int64
#  9   가족수     891 non-null    int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 69.7+ KB

# %% [markdown]
# # 데이터 타입 바꾸기

# %%
data['승객번호'] = data['승객번호'].astype('str')
data
# Out:
#     승객번호                                               승객이름  선실등급  \
# 0      1                            Braund, Mr. Owen Harris     3
# 1      2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 2      3                             Heikkinen, Miss. Laina     3
# 3      4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 4      5                           Allen, Mr. William Henry     3
# ..   ...                                                ...   ...
# 886  887                              Montvila, Rev. Juozas     2
# 887  888                       Graham, Miss. Margaret Edith     1
# 888  889           Johnston, Miss. Catherine Helen "Carrie"     3
# 889  890                              Behr, Mr. Karl Howell     1
# 890  891                                Dooley, Mr. Patrick     3
#
#                 승차권번호      성별    나이    승차권금액  좌석번호 정박지  생존여부  가족수          승차권
# 0           A/5 21171    male  22.0   7.2500   NaN   S     0    1          NaN
# 1            PC 17599  female  38.0  71.2833   C85   C     1    1  PC 17599C85
# 2    STON/O2. 3101282  female  26.0   7.9250   NaN   S     1    0          NaN
# 3              113803  female  35.0  53.1000  C123   S     1    1   113803C123
# 4              373450    male  35.0   8.0500   NaN   S     0    0          NaN
# ..                ...     ...   ...      ...   ...  ..   ...  ...          ...
# 886            211536    male  27.0  13.0000   NaN   S     0    0          NaN
# 887            112053  female  19.0  30.0000   B42   S     1    0    112053B42
# 888        W./C. 6607  female   NaN  23.4500   NaN   S     0    3          NaN
# 889            111369    male  26.0  30.0000  C148   C     1    0   111369C148
# 890            370376    male  32.0   7.7500   NaN   Q     0    0          NaN
#
# [891 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객번호    891 non-null    object
#  1   승객이름    891 non-null    object
#  2   선실등급    891 non-null    int64
#  3   승차권번호   891 non-null    object
#  4   성별      891 non-null    object
#  5   나이      714 non-null    float64
#  6   승차권금액   891 non-null    float64
#  7   좌석번호    204 non-null    object
#  8   정박지     889 non-null    object
#  9   생존여부    891 non-null    int64
#  10  가족수     891 non-null    int64
#  11  승차권     204 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 90.5+ KB

# %%
data['승객번호'] = data['승객번호'].astype('float32')

# %%
data['승객번호'] = data['승객번호'].apply(lambda x: str(x))

# %%
data['승객번호'].dtype
# Out:
# dtype('O')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객번호    891 non-null    object
#  1   승객이름    891 non-null    object
#  2   선실등급    891 non-null    int64
#  3   승차권번호   891 non-null    object
#  4   성별      891 non-null    object
#  5   나이      714 non-null    float64
#  6   승차권금액   891 non-null    float64
#  7   좌석번호    204 non-null    object
#  8   정박지     889 non-null    object
#  9   생존여부    891 non-null    int64
#  10  가족수     891 non-null    int64
#  11  승차권     204 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 90.5+ KB

# %%
data['승객번호'] = data['승객번호'].apply(lambda x: float(x))

# %%
data['승객번호'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 891 entries, 0 to 890
# Series name: 승객번호
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    float64
# dtypes: float64(1)
# memory usage: 13.9 KB

# %% [markdown]
# # 판다스 데이터 프레임에서 조건에 맞는 행만 가져오기
# * 데이터프레임[데이터프레임['컬럼명'] 조건식] => 조건식이 참인 것만 가져옴
# * 조건식 연산자 >, <, ==, !=, >=, <=, &(and), |(or)

# %%
data['나이'] > 35
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: 나이, Length: 891, dtype: bool

# %%
data[data['나이'] > 35]
# Out:
#                                                   승객이름  선실등급     승차권번호  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     1  PC 17599
# 6                              McCarthy, Mr. Timothy J     1     17463
# 11                            Bonnell, Miss. Elizabeth     1    113783
# 13                         Andersson, Mr. Anders Johan     3    347082
# 15                    Hewlett, Mrs. (Mary D Kingcome)      2    248706
# ..                                                 ...   ...       ...
# 865                           Bystrom, Mrs. (Karolina)     2    236852
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)     1     11751
# 873                        Vander Cruyssen, Mr. Victor     3    345765
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)     1     11767
# 885               Rice, Mrs. William (Margaret Norton)     3    382652
#
#          성별    나이    승차권금액  좌석번호 정박지  생존여부  가족수
# 1    female  38.0  71.2833   C85   C     1    1
# 6      male  54.0  51.8625   E46   S     0    0
# 11   female  58.0  26.5500  C103   S     1    0
# 13     male  39.0  31.2750   NaN   S     0    6
# 15   female  55.0  16.0000   NaN   S     1    0
# ..      ...   ...      ...   ...  ..   ...  ...
# 865  female  42.0  13.0000   NaN   S     1    0
# 871  female  47.0  52.5542   D35   S     1    2
# 873    male  47.0   9.0000   NaN   S     0    0
# 879  female  56.0  83.1583   C50   C     1    1
# 885  female  39.0  29.1250   NaN   Q     0    5
#
# [217 rows x 10 columns]

# %% [markdown]
# 성별이 여성이면서 나이가 35세 초과인 행 찾기 - 조건이 2개 and조건

# %%
(data['나이'] > 35) & (data['성별'] == 'female')
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
data[(data['나이'] > 35) & (data['성별'] == 'female')]
# Out:
#                                                   승객이름  선실등급     승차권번호  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     1  PC 17599
# 11                            Bonnell, Miss. Elizabeth     1    113783
# 15                    Hewlett, Mrs. (Mary D Kingcome)      2    248706
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...     3    347077
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)     3      7546
# ..                                                 ...   ...       ...
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...     1     17466
# 865                           Bystrom, Mrs. (Karolina)     2    236852
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)     1     11751
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)     1     11767
# 885               Rice, Mrs. William (Margaret Norton)     3    382652
#
#          성별    나이    승차권금액  좌석번호 정박지  생존여부  가족수
# 1    female  38.0  71.2833   C85   C     1    1
# 11   female  58.0  26.5500  C103   S     1    0
# 15   female  55.0  16.0000   NaN   S     1    0
# 25   female  38.0  31.3875   NaN   S     1    6
# 40   female  40.0   9.4750   NaN   S     0    1
# ..      ...   ...      ...   ...  ..   ...  ...
# 862  female  48.0  25.9292   D17   S     1    0
# 865  female  42.0  13.0000   NaN   S     1    0
# 871  female  47.0  52.5542   D35   S     1    2
# 879  female  56.0  83.1583   C50   C     1    1
# 885  female  39.0  29.1250   NaN   Q     0    5
#
# [73 rows x 10 columns]

# %% [markdown]
# 성별이 남성, 선실등급 1, 생존여부 1인 사람을 찾으세요.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객이름    891 non-null    object
#  1   선실등급    891 non-null    int64
#  2   승차권번호   891 non-null    object
#  3   성별      891 non-null    object
#  4   나이      714 non-null    float64
#  5   승차권금액   891 non-null    float64
#  6   좌석번호    204 non-null    object
#  7   정박지     889 non-null    object
#  8   생존여부    891 non-null    int64
#  9   가족수     891 non-null    int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 69.7+ KB

# %%
data[(data['성별'] == 'male') & (data['선실등급'] == 1) & (data['생존여부'] == 1)]
# Out:
#                                               승객이름  선실등급     승차권번호    성별  \
# 23                    Sloper, Mr. William Thompson     1    113788  male
# 55                               Woolner, Mr. Hugh     1     19947  male
# 97                 Greenfield, Mr. William Bertram     1  PC 17759  male
# 187  Romaine, Mr. Charles Hallace ("Mr C Rolmane")     1    111428  male
# 209                               Blank, Mr. Henry     1    112277  male
# 224                   Hoyt, Mr. Frederick Maxfield     1     19943  male
# 248                  Beckwith, Mr. Richard Leonard     1     11751  male
# 298                          Saalfeld, Mr. Adolphe     1     19988  male
# 305                 Allison, Master. Hudson Trevor     1    113781  male
# 370                    Harder, Mr. George Achilles     1     11765  male
# 390                     Carter, Mr. William Ernest     1    113760  male
# 430      Bjornstrom-Steffansson, Mr. Mauritz Hakan     1    110564  male
# 445                      Dodge, Master. Washington     1     33638  male
# 447                    Seward, Mr. Frederic Kimber     1    113794  male
# 449                 Peuchen, Major. Arthur Godfrey     1    113786  male
# 453                       Goldenberg, Mr. Samuel L     1     17453  male
# 460                            Anderson, Mr. Harry     1     19952  male
# 484                        Bishop, Mr. Dickinson H     1     11967  male
# 507  Bradley, Mr. George ("George Arthur Brayton")     1    111427  male
# 512                      McGough, Mr. James Robert     1  PC 17473  male
# 550                    Thayer, Mr. John Borland Jr     1     17421  male
# 572               Flynn, Mr. John Irwin ("Irving")     1  PC 17474  male
# 587               Frolicher-Stehli, Mr. Maxmillian     1     13567  male
# 599   Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")     1  PC 17485  male
# 604                Homer, Mr. Harry ("Mr E Haven")     1    111426  male
# 607                    Daniel, Mr. Robert Williams     1    113804  male
# 621                   Kimball, Mr. Edwin Nelson Jr     1     11753  male
# 630           Barkworth, Mr. Algernon Henry Wilson     1     27042  male
# 632                      Stahelin-Maeglin, Dr. Max     1     13214  male
# 645                      Harper, Mr. Henry Sleeper     1  PC 17572  male
# 647            Simonius-Blumer, Col. Oberst Alfons     1     13213  male
# 660                  Frauenthal, Dr. Henry William     1  PC 17611  male
# 679             Cardeza, Mr. Thomas Drake Martinez     1  PC 17755  male
# 681                             Hassab, Mr. Hammad     1  PC 17572  male
# 690                        Dick, Mr. Albert Adrian     1     17474  male
# 701               Silverthorne, Mr. Spencer Victor     1  PC 17475  male
# 707              Calderhead, Mr. Edward Pennington     1  PC 17476  male
# 712                       Taylor, Mr. Elmer Zebley     1     19996  male
# 724                  Chambers, Mr. Norman Campbell     1    113806  male
# 737                         Lesurer, Mr. Gustave J     1  PC 17755  male
# 740                    Hawksford, Mr. Walter James     1     16988  male
# 802            Carter, Master. William Thornton II     1    113760  male
# 839                           Marechal, Mr. Pierre     1     11774  male
# 857                         Daly, Mr. Peter Denis      1    113055  male
# 889                          Behr, Mr. Karl Howell     1    111369  male
#
#         나이     승차권금액         좌석번호 정박지  생존여부  가족수
# 23   28.00   35.5000           A6   S     1    0
# 55     NaN   35.5000          C52   S     1    0
# 97   23.00   63.3583      D10 D12   C     1    1
# 187  45.00   26.5500          NaN   S     1    0
# 209  40.00   31.0000          A31   C     1    0
# 224  38.00   90.0000          C93   S     1    1
# 248  37.00   52.5542          D35   S     1    2
# 298    NaN   30.5000         C106   S     1    0
# 305   0.92  151.5500      C22 C26   S     1    3
# 370  25.00   55.4417          E50   C     1    1
# 390  36.00  120.0000      B96 B98   S     1    3
# 430  28.00   26.5500          C52   S     1    0
# 445   4.00   81.8583          A34   S     1    2
# 447  34.00   26.5500          NaN   S     1    0
# 449  52.00   30.5000         C104   S     1    0
# 453  49.00   89.1042          C92   C     1    1
# 460  48.00   26.5500          E12   S     1    0
# 484  25.00   91.0792          B49   C     1    1
# 507    NaN   26.5500          NaN   S     1    0
# 512  36.00   26.2875          E25   S     1    0
# 550  17.00  110.8833          C70   C     1    2
# 572  36.00   26.3875          E25   S     1    0
# 587  60.00   79.2000          B41   C     1    2
# 599  49.00   56.9292          A20   C     1    1
# 604  35.00   26.5500          NaN   C     1    0
# 607  27.00   30.5000          NaN   S     1    0
# 621  42.00   52.5542          D19   S     1    1
# 630  80.00   30.0000          A23   S     1    0
# 632  32.00   30.5000          B50   C     1    0
# 645  48.00   76.7292          D33   C     1    1
# 647  56.00   35.5000          A26   C     1    0
# 660  50.00  133.6500          NaN   S     1    2
# 679  36.00  512.3292  B51 B53 B55   C     1    1
# 681  27.00   76.7292          D49   C     1    0
# 690  31.00   57.0000          B20   S     1    1
# 701  35.00   26.2875          E24   S     1    0
# 707  42.00   26.2875          E24   S     1    0
# 712  48.00   52.0000         C126   S     1    1
# 724  27.00   53.1000           E8   S     1    1
# 737  35.00  512.3292         B101   C     1    0
# 740    NaN   30.0000          D45   S     1    0
# 802  11.00  120.0000      B96 B98   S     1    3
# 839    NaN   29.7000          C47   C     1    0
# 857  51.00   26.5500          E17   S     1    0
# 889  26.00   30.0000         C148   C     1    0

# %%
data[data['선실등급'] == 2]['승차권금액'].describe()
# Out:
# count    184.000000
# mean      20.662183
# std       13.417399
# min        0.000000
# 25%       13.000000
# 50%       14.250000
# 75%       26.000000
# max       73.500000
# Name: 승차권금액, dtype: float64

# %% [markdown]
# 승차권 금액이 0원인 사람 찾기

# %%
data[data['승차권금액'] == 0]
# Out:
#                                  승객이름  선실등급   승차권번호    성별    나이  승차권금액  좌석번호  \
# 179               Leonard, Mr. Lionel     3    LINE  male  36.0    0.0   NaN
# 263             Harrison, Mr. William     1  112059  male  40.0    0.0   B94
# 271      Tornquist, Mr. William Henry     3    LINE  male  25.0    0.0   NaN
# 277       Parkes, Mr. Francis "Frank"     2  239853  male   NaN    0.0   NaN
# 302   Johnson, Mr. William Cahoone Jr     3    LINE  male  19.0    0.0   NaN
# 413    Cunningham, Mr. Alfred Fleming     2  239853  male   NaN    0.0   NaN
# 466             Campbell, Mr. William     2  239853  male   NaN    0.0   NaN
# 481  Frost, Mr. Anthony Wood "Archie"     2  239854  male   NaN    0.0   NaN
# 597               Johnson, Mr. Alfred     3    LINE  male  49.0    0.0   NaN
# 633     Parr, Mr. William Henry Marsh     1  112052  male   NaN    0.0   NaN
# 674        Watson, Mr. Ennis Hastings     2  239856  male   NaN    0.0   NaN
# 732              Knight, Mr. Robert J     2  239855  male   NaN    0.0   NaN
# 806            Andrews, Mr. Thomas Jr     1  112050  male  39.0    0.0   A36
# 815                  Fry, Mr. Richard     1  112058  male   NaN    0.0  B102
# 822   Reuchlin, Jonkheer. John George     1   19972  male  38.0    0.0   NaN
#
#     정박지  생존여부  가족수
# 179   S     0    0
# 263   S     0    0
# 271   S     1    0
# 277   S     0    0
# 302   S     0    0
# 413   S     0    0
# 466   S     0    0
# 481   S     0    0
# 597   S     0    0
# 633   S     0    0
# 674   S     0    0
# 732   S     0    0
# 806   S     0    0
# 815   S     0    0
# 822   S     0    0

# %%
data[data['승차권번호'] == '19972']
# Out:
#                                 승객이름  선실등급  승차권번호    성별    나이  승차권금액 좌석번호 정박지  \
# 822  Reuchlin, Jonkheer. John George     1  19972  male  38.0    0.0  NaN   S
#
#      생존여부  가족수
# 822     0    0

# %% [markdown]
# 남자이면서 생존한 사람

# %%
data[(data['성별'] == 'male') & (data['생존여부'] == 1)]
# Out:
#                                 승객이름  선실등급   승차권번호    성별    나이    승차권금액  좌석번호  \
# 17      Williams, Mr. Charles Eugene     2  244373  male   NaN  13.0000   NaN
# 21             Beesley, Mr. Lawrence     2  248698  male  34.0  13.0000   D56
# 23      Sloper, Mr. William Thompson     1  113788  male  28.0  35.5000    A6
# 36                  Mamee, Mr. Hanna     3    2677  male   NaN   7.2292   NaN
# 55                 Woolner, Mr. Hugh     1   19947  male   NaN  35.5000   C52
# ..                               ...   ...     ...   ...   ...      ...   ...
# 838                  Chip, Mr. Chang     3    1601  male  32.0  56.4958   NaN
# 839             Marechal, Mr. Pierre     1   11774  male   NaN  29.7000   C47
# 857           Daly, Mr. Peter Denis      1  113055  male  51.0  26.5500   E17
# 869  Johnson, Master. Harold Theodor     3  347742  male   4.0  11.1333   NaN
# 889            Behr, Mr. Karl Howell     1  111369  male  26.0  30.0000  C148
#
#     정박지  생존여부  가족수
# 17    S     1    0
# 21    S     1    0
# 23    S     1    0
# 36    C     1    0
# 55    S     1    0
# ..   ..   ...  ...
# 838   S     1    0
# 839   C     1    0
# 857   S     1    0
# 869   S     1    2
# 889   C     1    0
#
# [109 rows x 10 columns]

# %% [markdown]
# 선실등급이 1이거나 2이면서 생존한 여성

# %%
data[((data['선실등급'] == 1) | (data['선실등급'] == 2)) & (data['성별'] == 'female') & (data['생존여부']== 1)]
# Out:
#                                                   승객이름  선실등급      승차권번호  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     1   PC 17599
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)     1     113803
# 9                  Nasser, Mrs. Nicholas (Adele Achem)     2     237736
# 11                            Bonnell, Miss. Elizabeth     1     113783
# 15                    Hewlett, Mrs. (Mary D Kingcome)      2     248706
# ..                                                 ...   ...        ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)     1      11751
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)     2  P/PP 3381
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)     1      11767
# 880       Shelley, Mrs. William (Imanita Parrish Hall)     2     230433
# 887                       Graham, Miss. Margaret Edith     1     112053
#
#          성별    나이    승차권금액  좌석번호 정박지  생존여부  가족수
# 1    female  38.0  71.2833   C85   C     1    1
# 3    female  35.0  53.1000  C123   S     1    1
# 9    female  14.0  30.0708   NaN   C     1    1
# 11   female  58.0  26.5500  C103   S     1    0
# 15   female  55.0  16.0000   NaN   S     1    0
# ..      ...   ...      ...   ...  ..   ...  ...
# 871  female  47.0  52.5542   D35   S     1    2
# 874  female  28.0  24.0000   NaN   C     1    1
# 879  female  56.0  83.1583   C50   C     1    1
# 880  female  25.0  26.0000   NaN   S     1    1
# 887  female  19.0  30.0000   B42   S     1    0
#
# [161 rows x 10 columns]

# %% [markdown]
# 선실등급이 1이거나 2이면서 생존한 여성 중에서 이름 컴럼만 보고 싶을 때
# * 데이터프레임.loc[데이터프레임['컬럼명'] 조건, '원하는 컬럼명']  - 공식
# * 데이터프레임[데이터프레임['컬럼명'] 조건]['원하는 컬럼명']  - 편법

# %%
data.loc[((data['선실등급'] == 1) | (data['선실등급'] == 2)) & (data['성별'] == 'female') & (data['생존여부']== 1), '승객이름']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 11                              Bonnell, Miss. Elizabeth
# 15                      Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 874                Abelson, Mrs. Samuel (Hannah Wizosky)
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 887                         Graham, Miss. Margaret Edith
# Name: 승객이름, Length: 161, dtype: object

# %%
data.loc[((data['선실등급'] == 1) | (data['선실등급'] == 2)) & (data['성별'] == 'female') & (data['생존여부']== 1), '승객이름' ]
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 11                              Bonnell, Miss. Elizabeth
# 15                      Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 874                Abelson, Mrs. Samuel (Hannah Wizosky)
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 887                         Graham, Miss. Margaret Edith
# Name: 승객이름, Length: 161, dtype: object

# %% [markdown]
# 선실등급이 1인 사람의 승객이름 출력하기

# %%
data.loc[data['선실등급'] == 1, '승객이름']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
# 23                          Sloper, Mr. William Thompson
#                              ...
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872                             Carlsson, Mr. Frans Olof
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887                         Graham, Miss. Margaret Edith
# 889                                Behr, Mr. Karl Howell
# Name: 승객이름, Length: 216, dtype: object

# %%
선실등급이 1인 사람의 승객이름과 선실등급 같이 출력하기

# %%
data.loc[:20, ['승객이름', '선실등급']]
# Out:
#                                                  승객이름  선실등급
# 0                             Braund, Mr. Owen Harris     3
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 2                              Heikkinen, Miss. Laina     3
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 4                            Allen, Mr. William Henry     3
# 5                                    Moran, Mr. James     3
# 6                             McCarthy, Mr. Timothy J     1
# 7                      Palsson, Master. Gosta Leonard     3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     3
# 9                 Nasser, Mrs. Nicholas (Adele Achem)     2
# 10                    Sandstrom, Miss. Marguerite Rut     3
# 11                           Bonnell, Miss. Elizabeth     1
# 12                     Saundercock, Mr. William Henry     3
# 13                        Andersson, Mr. Anders Johan     3
# 14               Vestrom, Miss. Hulda Amanda Adolfina     3
# 15                   Hewlett, Mrs. (Mary D Kingcome)      2
# 16                               Rice, Master. Eugene     3
# 17                       Williams, Mr. Charles Eugene     2
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...     3
# 19                            Masselmani, Mrs. Fatima     3
# 20                               Fynney, Mr. Joseph J     2

# %%
data.loc[data['선실등급'] == 1, ['승객이름', '선실등급']]
# Out:
#                                                   승객이름  선실등급
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 6                              McCarthy, Mr. Timothy J     1
# 11                            Bonnell, Miss. Elizabeth     1
# 23                        Sloper, Mr. William Thompson     1
# ..                                                 ...   ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)     1
# 872                           Carlsson, Mr. Frans Olof     1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)     1
# 887                       Graham, Miss. Margaret Edith     1
# 889                              Behr, Mr. Karl Howell     1
#
# [216 rows x 2 columns]

# %%
data[data['선실등급'] == 1][['승객이름','선실등급']]
# Out:
#                                                   승객이름  선실등급
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 6                              McCarthy, Mr. Timothy J     1
# 11                            Bonnell, Miss. Elizabeth     1
# 23                        Sloper, Mr. William Thompson     1
# ..                                                 ...   ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)     1
# 872                           Carlsson, Mr. Frans Olof     1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)     1
# 887                       Graham, Miss. Margaret Edith     1
# 889                              Behr, Mr. Karl Howell     1
#
# [216 rows x 2 columns]

# %%
pclass_1 = data[data['선실등급'] == 1]
pclass_1[['승객이름', '선실등급']]
# Out:
#                                                   승객이름  선실등급
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 6                              McCarthy, Mr. Timothy J     1
# 11                            Bonnell, Miss. Elizabeth     1
# 23                        Sloper, Mr. William Thompson     1
# ..                                                 ...   ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)     1
# 872                           Carlsson, Mr. Frans Olof     1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)     1
# 887                       Graham, Miss. Margaret Edith     1
# 889                              Behr, Mr. Karl Howell     1
#
# [216 rows x 2 columns]

# %% [markdown]
# .isin([조건1, 조건2]) or 조건을 여러 번 써야할 때 .isin을 쓰면 간단

# %%
# data[(data['선실등급'] == 1) | (data['선실등급'] == 2)]
data[data['선실등급'].isin([1,2])]
# Out:
#                                                   승객이름  선실등급  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 6                              McCarthy, Mr. Timothy J     1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)     2
# 11                            Bonnell, Miss. Elizabeth     1
# ..                                                 ...   ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)     2
# 883                      Banfield, Mr. Frederick James     2
# 886                              Montvila, Rev. Juozas     2
# 887                       Graham, Miss. Margaret Edith     1
# 889                              Behr, Mr. Karl Howell     1
#
#                 승차권번호      성별    나이    승차권금액  좌석번호 정박지  생존여부  가족수
# 1            PC 17599  female  38.0  71.2833   C85   C     1    1
# 3              113803  female  35.0  53.1000  C123   S     1    1
# 6               17463    male  54.0  51.8625   E46   S     0    0
# 9              237736  female  14.0  30.0708   NaN   C     1    1
# 11             113783  female  58.0  26.5500  C103   S     1    0
# ..                ...     ...   ...      ...   ...  ..   ...  ...
# 880            230433  female  25.0  26.0000   NaN   S     1    1
# 883  C.A./SOTON 34068    male  28.0  10.5000   NaN   S     0    0
# 886            211536    male  27.0  13.0000   NaN   S     0    0
# 887            112053  female  19.0  30.0000   B42   S     1    0
# 889            111369    male  26.0  30.0000  C148   C     1    0
#
# [400 rows x 10 columns]

# %% [markdown]
# # 특정 단어를 포함한 행을 찾기 예 이름에 Joseph이 들어간 사람
# * like %단어%  - sql
# * .str.contains("찾을 단어")

# %%
data[data['승객이름'].str.contains("Joseph")]
# Out:
#                                                   승객이름  선실등급          승차권번호  \
# 20                                Fynney, Mr. Joseph J     2         239865
# 34                             Meyer, Mr. Edgar Joseph     1       PC 17604
# 95                         Shorney, Mr. Charles Joseph     3         374910
# 140                      Boulos, Mrs. Joseph (Sultana)     3           2678
# 145                       Nicholls, Mr. Joseph Charles     2     C.A. 33112
# 194          Brown, Mrs. James Joseph (Margaret Tobin)     1       PC 17610
# 375              Meyer, Mrs. Edgar Joseph (Leila Saks)     1       PC 17604
# 454                                Peduzzi, Mr. Joseph     3       A/5 2817
# 532                               Elias, Mr. Joseph Jr     3           2690
# 559       de Messemaeker, Mrs. Guillaume Joseph (Emma)     3         345572
# 578                   Caram, Mrs. Joseph (Maria Elias)     3           2689
# 589                                Murdlin, Mr. Joseph     3     A./5. 3235
# 608  Laroche, Mrs. Joseph (Juliette Marie Louise La...     2  SC/Paris 2123
# 685             Laroche, Mr. Joseph Philippe Lemercier     2  SC/Paris 2123
# 752                   Vande Velde, Mr. Johannes Joseph     3         345780
# 828                       McCormack, Mr. Thomas Joseph     3         367228
#
#          성별    나이    승차권금액 좌석번호 정박지  생존여부  가족수
# 20     male  35.0  26.0000  NaN   S     0    0
# 34     male  28.0  82.1708  NaN   C     0    1
# 95     male   NaN   8.0500  NaN   S     0    0
# 140  female   NaN  15.2458  NaN   C     0    2
# 145    male  19.0  36.7500  NaN   S     0    2
# 194  female  44.0  27.7208   B4   C     1    0
# 375  female   NaN  82.1708  NaN   C     1    1
# 454    male   NaN   8.0500  NaN   S     0    0
# 532    male  17.0   7.2292  NaN   C     0    2
# 559  female  36.0  17.4000  NaN   S     1    1
# 578  female   NaN  14.4583  NaN   C     0    1
# 589    male   NaN   8.0500  NaN   S     0    0
# 608  female  22.0  41.5792  NaN   C     1    3
# 685    male  25.0  41.5792  NaN   C     0    3
# 752    male  33.0   9.5000  NaN   S     0    0
# 828    male   NaN   7.7500  NaN   Q     1    0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객이름    891 non-null    object
#  1   선실등급    891 non-null    int64
#  2   승차권번호   891 non-null    object
#  3   성별      891 non-null    object
#  4   나이      714 non-null    float64
#  5   승차권금액   891 non-null    float64
#  6   좌석번호    204 non-null    object
#  7   정박지     889 non-null    object
#  8   생존여부    891 non-null    int64
#  9   가족수     891 non-null    int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 69.7+ KB

# %% [markdown]
# 승차권에 PC 가 포함된 승차권 찾기

# %%
data[data['승차권번호'].str.contains("PC")]
# Out:
#                                                   승객이름  선실등급     승차권번호  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     1  PC 17599
# 30                            Uruchurtu, Don. Manuel E     1  PC 17601
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)     1  PC 17569
# 34                             Meyer, Mr. Edgar Joseph     1  PC 17604
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)     1  PC 17572
# 64                               Stewart, Mr. Albert A     1  PC 17605
# 96                           Goldschmidt, Mr. George B     1  PC 17754
# 97                     Greenfield, Mr. William Bertram     1  PC 17759
# 118                           Baxter, Mr. Quigg Edmond     1  PC 17558
# 139                                 Giglio, Mr. Victor     1  PC 17593
# 155                        Williams, Mr. Charles Duane     1  PC 17597
# 168                                Baumann, Mr. John D     1  PC 17318
# 177                         Isham, Miss. Ann Elizabeth     1  PC 17595
# 194          Brown, Mrs. James Joseph (Margaret Tobin)     1  PC 17610
# 195                               Lurette, Miss. Elise     1  PC 17569
# 256                     Thorne, Mrs. Gertrude Maybelle     1  PC 17585
# 258                                   Ward, Miss. Anna     1  PC 17755
# 268      Graham, Mrs. William Thompson (Edith Junkins)     1  PC 17582
# 269                             Bissette, Miss. Amelia     1  PC 17760
# 273                              Natsch, Mr. Charles H     1  PC 17596
# 295                                  Lewy, Mr. Ervin G     1  PC 17612
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)     1  PC 17558
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...     1  PC 17758
# 309                     Francatelli, Miss. Laura Mabel     1  PC 17485
# 311                         Ryerson, Miss. Emily Borie     1  PC 17608
# 325                           Young, Miss. Marie Grice     1  PC 17760
# 332                          Graham, Mr. George Edward     1  PC 17582
# 334  Frauenthal, Mrs. Henry William (Clara Heinshei...     1  PC 17611
# 369                      Aubart, Mme. Leontine Pauline     1  PC 17477
# 373                                Ringhini, Mr. Sante     1  PC 17760
# 375              Meyer, Mrs. Edgar Joseph (Leila Saks)     1  PC 17604
# 380                              Bidois, Miss. Rosalie     1  PC 17757
# 493                            Artagaveytia, Mr. Ramon     1  PC 17609
# 505         Penasco y Castellana, Mr. Victor de Satode     1  PC 17758
# 512                          McGough, Mr. James Robert     1  PC 17473
# 513     Rothschild, Mrs. Martin (Elizabeth L. Barrett)     1  PC 17603
# 527                                 Farthing, Mr. John     1  PC 17483
# 537                                LeRoy, Miss. Bertha     1  PC 17761
# 544                         Douglas, Mr. Walter Donald     1  PC 17761
# 557                                Robbins, Mr. Victor     1  PC 17757
# 572                   Flynn, Mr. John Irwin ("Irving")     1  PC 17474
# 599       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")     1  PC 17485
# 609                          Shutes, Miss. Elizabeth W     1  PC 17582
# 641                               Sagesser, Mlle. Emma     1  PC 17477
# 645                          Harper, Mr. Henry Sleeper     1  PC 17572
# 660                      Frauenthal, Dr. Henry William     1  PC 17611
# 679                 Cardeza, Mr. Thomas Drake Martinez     1  PC 17755
# 681                                 Hassab, Mr. Hammad     1  PC 17572
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)     1  PC 17757
# 701                   Silverthorne, Mr. Spencer Victor     1  PC 17475
# 707                  Calderhead, Mr. Edward Pennington     1  PC 17476
# 710   Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")     1  PC 17482
# 716                      Endres, Miss. Caroline Louise     1  PC 17757
# 737                             Lesurer, Mr. Gustave J     1  PC 17755
# 742              Ryerson, Miss. Susan Parker "Suzette"     1  PC 17608
# 789                           Guggenheim, Mr. Benjamin     1  PC 17593
# 793                           Hoyt, Mr. William Fisher     1  PC 17600
# 835                        Compton, Miss. Sara Rebecca     1  PC 17756
# 853                          Lines, Miss. Mary Conover     1  PC 17592
# 867               Roebling, Mr. Washington Augustus II     1  PC 17590
#
#          성별    나이     승차권금액             좌석번호 정박지  생존여부  가족수
# 1    female  38.0   71.2833              C85   C     1    1
# 30     male  40.0   27.7208              NaN   C     0    0
# 31   female   NaN  146.5208              B78   C     1    1
# 34     male  28.0   82.1708              NaN   C     0    1
# 52   female  49.0   76.7292              D33   C     1    1
# 64     male   NaN   27.7208              NaN   C     0    0
# 96     male  71.0   34.6542               A5   C     0    0
# 97     male  23.0   63.3583          D10 D12   C     1    1
# 118    male  24.0  247.5208          B58 B60   C     0    1
# 139    male  24.0   79.2000              B86   C     0    0
# 155    male  51.0   61.3792              NaN   C     0    1
# 168    male   NaN   25.9250              NaN   S     0    0
# 177  female  50.0   28.7125              C49   C     0    0
# 194  female  44.0   27.7208               B4   C     1    0
# 195  female  58.0  146.5208              B80   C     1    0
# 256  female   NaN   79.2000              NaN   C     1    0
# 258  female  35.0  512.3292              NaN   C     1    0
# 268  female  58.0  153.4625             C125   S     1    1
# 269  female  35.0  135.6333              C99   S     1    0
# 273    male  37.0   29.7000             C118   C     0    1
# 295    male   NaN   27.7208              NaN   C     0    0
# 299  female  50.0  247.5208          B58 B60   C     1    1
# 307  female  17.0  108.9000              C65   C     1    1
# 309  female  30.0   56.9292              E36   C     1    0
# 311  female  18.0  262.3750  B57 B59 B63 B66   C     1    4
# 325  female  36.0  135.6333              C32   C     1    0
# 332    male  38.0  153.4625              C91   S     0    1
# 334  female   NaN  133.6500              NaN   S     1    1
# 369  female  24.0   69.3000              B35   C     1    0
# 373    male  22.0  135.6333              NaN   C     0    0
# 375  female   NaN   82.1708              NaN   C     1    1
# 380  female  42.0  227.5250              NaN   C     1    0
# 493    male  71.0   49.5042              NaN   C     0    0
# 505    male  18.0  108.9000              C65   C     0    1
# 512    male  36.0   26.2875              E25   S     1    0
# 513  female  54.0   59.4000              NaN   C     1    1
# 527    male   NaN  221.7792              C95   S     0    0
# 537  female  30.0  106.4250              NaN   C     1    0
# 544    male  50.0  106.4250              C86   C     0    1
# 557    male   NaN  227.5250              NaN   C     0    0
# 572    male  36.0   26.3875              E25   S     1    0
# 599    male  49.0   56.9292              A20   C     1    1
# 609  female  40.0  153.4625             C125   S     1    0
# 641  female  24.0   69.3000              B35   C     1    0
# 645    male  48.0   76.7292              D33   C     1    1
# 660    male  50.0  133.6500              NaN   S     1    2
# 679    male  36.0  512.3292      B51 B53 B55   C     1    1
# 681    male  27.0   76.7292              D49   C     1    0
# 700  female  18.0  227.5250          C62 C64   C     1    1
# 701    male  35.0   26.2875              E24   S     1    0
# 707    male  42.0   26.2875              E24   S     1    0
# 710  female  24.0   49.5042              C90   C     1    0
# 716  female  38.0  227.5250              C45   C     1    0
# 737    male  35.0  512.3292             B101   C     1    0
# 742  female  21.0  262.3750  B57 B59 B63 B66   C     1    4
# 789    male  46.0   79.2000          B82 B84   C     0    0
# 793    male   NaN   30.6958              NaN   C     0    0
# 835  female  39.0   83.1583              E49   C     1    2
# 853  female  16.0   39.4000              D28   S     1    1
# 867    male  31.0   50.4958              A24   S     0    0

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# 승객이름에서 ( ) 없애기
# * 방법1
# * 방법2
# * 방법3

# %%
for name in data['승객이름']:
    print(name.replce("(", ""))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[135], line 2
#       1 for name in data['승객이름']:
# ----> 2     print(name.replce("(", ""))
#
# AttributeError: 'str' object has no attribute 'replce'
