# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %% [markdown]
# # 간단한 시계열 데이터 만들기

# %% [markdown]
# * 정상시계열(우연 변동 시계열)

# %%
dd = np.array([1342, 1442, 1252, 1343, 1425, 1362, 1256, 1272, 1243, 1359, 1412, 1253, 1201, 1478, 1322, 1406, 1254, 1289, 1497, 1208]).reshape(5,4)
dd
# Out:
# array([[1342, 1442, 1252, 1343],
#        [1425, 1362, 1256, 1272],
#        [1243, 1359, 1412, 1253],
#        [1201, 1478, 1322, 1406],
#        [1254, 1289, 1497, 1208]])

# %%
dd_ts = pd.DataFrame(dd, index=range(2016, 2021), columns=['Qt1', 'Qt2', 'Qt3', 'Qt4'])
dd_ts
# Out:
#        Qt1   Qt2   Qt3   Qt4
# 2016  1342  1442  1252  1343
# 2017  1425  1362  1256  1272
# 2018  1243  1359  1412  1253
# 2019  1201  1478  1322  1406
# 2020  1254  1289  1497  1208

# %% [markdown]
# 데이터프레임 dd_ts의 행과 열을 stack(스택)방식으로 변환하고 인덱스 초기화

# %%
dd_ts = dd_ts.stack().reset_index()
dd_ts
# Out:
#     level_0 level_1     0
# 0      2016     Qt1  1342
# 1      2016     Qt2  1442
# 2      2016     Qt3  1252
# 3      2016     Qt4  1343
# 4      2017     Qt1  1425
# 5      2017     Qt2  1362
# 6      2017     Qt3  1256
# 7      2017     Qt4  1272
# 8      2018     Qt1  1243
# 9      2018     Qt2  1359
# 10     2018     Qt3  1412
# 11     2018     Qt4  1253
# 12     2019     Qt1  1201
# 13     2019     Qt2  1478
# 14     2019     Qt3  1322
# 15     2019     Qt4  1406
# 16     2020     Qt1  1254
# 17     2020     Qt2  1289
# 18     2020     Qt3  1497
# 19     2020     Qt4  1208

# %%
dd_ts.columns = ['year', 'quarter', 'value']
dd_ts
# Out:
#     year quarter  value
# 0   2016     Qt1   1342
# 1   2016     Qt2   1442
# 2   2016     Qt3   1252
# 3   2016     Qt4   1343
# 4   2017     Qt1   1425
# 5   2017     Qt2   1362
# 6   2017     Qt3   1256
# 7   2017     Qt4   1272
# 8   2018     Qt1   1243
# 9   2018     Qt2   1359
# 10  2018     Qt3   1412
# 11  2018     Qt4   1253
# 12  2019     Qt1   1201
# 13  2019     Qt2   1478
# 14  2019     Qt3   1322
# 15  2019     Qt4   1406
# 16  2020     Qt1   1254
# 17  2020     Qt2   1289
# 18  2020     Qt3   1497
# 19  2020     Qt4   1208

# %%
dd_ts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   year     20 non-null     int64
#  1   quarter  20 non-null     object
#  2   value    20 non-null     int32
# dtypes: int32(1), int64(1), object(1)
# memory usage: 528.0+ bytes

# %%
dd_ts['year'] = dd_ts['year'].apply(str)
dd_ts['year'].dtype
# Out:
# dtype('O')

# %%
dd_ts['date'] = dd_ts['year'] + dd_ts['quarter']

# %%
dd_ts['date'] = dd_ts['date'].str.replace("t", "")
dd_ts['date']
# Out:
# 0     2016Q1
# 1     2016Q2
# 2     2016Q3
# 3     2016Q4
# 4     2017Q1
# 5     2017Q2
# 6     2017Q3
# 7     2017Q4
# 8     2018Q1
# 9     2018Q2
# 10    2018Q3
# 11    2018Q4
# 12    2019Q1
# 13    2019Q2
# 14    2019Q3
# 15    2019Q4
# 16    2020Q1
# 17    2020Q2
# 18    2020Q3
# 19    2020Q4
# Name: date, dtype: object

# %% [markdown]
# date 컬럼을 분기(quarter) 주기로 변환후 타임스탬프 형식으로 변경

# %%
dd_ts['date'] = pd.PeriodIndex(dd_ts['date'], freq='Q').to_timestamp()
dd_ts
# Out:
#     year quarter  value       date
# 0   2016     Qt1   1342 2016-01-01
# 1   2016     Qt2   1442 2016-04-01
# 2   2016     Qt3   1252 2016-07-01
# 3   2016     Qt4   1343 2016-10-01
# 4   2017     Qt1   1425 2017-01-01
# 5   2017     Qt2   1362 2017-04-01
# 6   2017     Qt3   1256 2017-07-01
# 7   2017     Qt4   1272 2017-10-01
# 8   2018     Qt1   1243 2018-01-01
# 9   2018     Qt2   1359 2018-04-01
# 10  2018     Qt3   1412 2018-07-01
# 11  2018     Qt4   1253 2018-10-01
# 12  2019     Qt1   1201 2019-01-01
# 13  2019     Qt2   1478 2019-04-01
# 14  2019     Qt3   1322 2019-07-01
# 15  2019     Qt4   1406 2019-10-01
# 16  2020     Qt1   1254 2020-01-01
# 17  2020     Qt2   1289 2020-04-01
# 18  2020     Qt3   1497 2020-07-01
# 19  2020     Qt4   1208 2020-10-01

# %%
dd_ts = dd_ts.set_index('date')
dd_ts
# Out:
#             year quarter  value
# date
# 2016-01-01  2016     Qt1   1342
# 2016-04-01  2016     Qt2   1442
# 2016-07-01  2016     Qt3   1252
# 2016-10-01  2016     Qt4   1343
# 2017-01-01  2017     Qt1   1425
# 2017-04-01  2017     Qt2   1362
# 2017-07-01  2017     Qt3   1256
# 2017-10-01  2017     Qt4   1272
# 2018-01-01  2018     Qt1   1243
# 2018-04-01  2018     Qt2   1359
# 2018-07-01  2018     Qt3   1412
# 2018-10-01  2018     Qt4   1253
# 2019-01-01  2019     Qt1   1201
# 2019-04-01  2019     Qt2   1478
# 2019-07-01  2019     Qt3   1322
# 2019-10-01  2019     Qt4   1406
# 2020-01-01  2020     Qt1   1254
# 2020-04-01  2020     Qt2   1289
# 2020-07-01  2020     Qt3   1497
# 2020-10-01  2020     Qt4   1208

# %%
# 시계열 데이터 시각화
plt.figure(figsize=(10,6))
sns.lineplot(x=dd_ts.index, y=dd_ts['value'], marker='o')
plt.title("Random variation time series (정상시계열)")
plt.xlabel('date')
plt.ylabel('value')
plt.grid(True)
plt.show()

# %% [markdown]
# 주기를 타지 않는 제품의 생산량, 판매량 데이터, 짧은 기간의 주가 데이터, 금리 등이 위와 같은 성향을 갖는다.

# %% [markdown]
# # 계절 변동 시계열 (seasonality)

# %%
season1 = np.array((1142, 1242, 1452, 1543,
                   1125,1262,1456,1572,
                   1143,1269,1462,1553,
                   1121,1258,1472,1546,
                   1154,1249,1477,1548)).reshape(5,4)
season1_ts = pd.DataFrame(season1, index=range(2016, 2021), columns=['Qtr1', 'Qtr2', 'Qtr3', 'Qtr4'])
season1_ts
# Out:
#       Qtr1  Qtr2  Qtr3  Qtr4
# 2016  1142  1242  1452  1543
# 2017  1125  1262  1456  1572
# 2018  1143  1269  1462  1553
# 2019  1121  1258  1472  1546
# 2020  1154  1249  1477  1548

# %%
season1_ts = season1_ts.stack().reset_index()
season1_ts
# Out:
#     level_0 level_1     0
# 0      2016    Qtr1  1142
# 1      2016    Qtr2  1242
# 2      2016    Qtr3  1452
# 3      2016    Qtr4  1543
# 4      2017    Qtr1  1125
# 5      2017    Qtr2  1262
# 6      2017    Qtr3  1456
# 7      2017    Qtr4  1572
# 8      2018    Qtr1  1143
# 9      2018    Qtr2  1269
# 10     2018    Qtr3  1462
# 11     2018    Qtr4  1553
# 12     2019    Qtr1  1121
# 13     2019    Qtr2  1258
# 14     2019    Qtr3  1472
# 15     2019    Qtr4  1546
# 16     2020    Qtr1  1154
# 17     2020    Qtr2  1249
# 18     2020    Qtr3  1477
# 19     2020    Qtr4  1548

# %%
season1_ts.columns = ['year', 'quarter', 'value']
season1_ts
# Out:
#     year quarter  value
# 0   2016    Qtr1   1142
# 1   2016    Qtr2   1242
# 2   2016    Qtr3   1452
# 3   2016    Qtr4   1543
# 4   2017    Qtr1   1125
# 5   2017    Qtr2   1262
# 6   2017    Qtr3   1456
# 7   2017    Qtr4   1572
# 8   2018    Qtr1   1143
# 9   2018    Qtr2   1269
# 10  2018    Qtr3   1462
# 11  2018    Qtr4   1553
# 12  2019    Qtr1   1121
# 13  2019    Qtr2   1258
# 14  2019    Qtr3   1472
# 15  2019    Qtr4   1546
# 16  2020    Qtr1   1154
# 17  2020    Qtr2   1249
# 18  2020    Qtr3   1477
# 19  2020    Qtr4   1548

# %%
season1_ts['year'] = season1_ts['year'].apply(str)
season1_ts['year'].dtype
# Out:
# dtype('O')

# %%
season1_ts['date'] = season1_ts['year'] + season1_ts['quarter']

# %%
season1_ts['date'] = season1_ts['date'].str.replace("tr", "")
season1_ts['date']
# Out:
# 0     2016Q1
# 1     2016Q2
# 2     2016Q3
# 3     2016Q4
# 4     2017Q1
# 5     2017Q2
# 6     2017Q3
# 7     2017Q4
# 8     2018Q1
# 9     2018Q2
# 10    2018Q3
# 11    2018Q4
# 12    2019Q1
# 13    2019Q2
# 14    2019Q3
# 15    2019Q4
# 16    2020Q1
# 17    2020Q2
# 18    2020Q3
# 19    2020Q4
# Name: date, dtype: object

# %%
season1_ts['date'] = pd.PeriodIndex(season1_ts['date'], freq='Q').to_timestamp()
season1_ts
# Out:
#     year quarter  value       date
# 0   2016    Qtr1   1142 2016-01-01
# 1   2016    Qtr2   1242 2016-04-01
# 2   2016    Qtr3   1452 2016-07-01
# 3   2016    Qtr4   1543 2016-10-01
# 4   2017    Qtr1   1125 2017-01-01
# 5   2017    Qtr2   1262 2017-04-01
# 6   2017    Qtr3   1456 2017-07-01
# 7   2017    Qtr4   1572 2017-10-01
# 8   2018    Qtr1   1143 2018-01-01
# 9   2018    Qtr2   1269 2018-04-01
# 10  2018    Qtr3   1462 2018-07-01
# 11  2018    Qtr4   1553 2018-10-01
# 12  2019    Qtr1   1121 2019-01-01
# 13  2019    Qtr2   1258 2019-04-01
# 14  2019    Qtr3   1472 2019-07-01
# 15  2019    Qtr4   1546 2019-10-01
# 16  2020    Qtr1   1154 2020-01-01
# 17  2020    Qtr2   1249 2020-04-01
# 18  2020    Qtr3   1477 2020-07-01
# 19  2020    Qtr4   1548 2020-10-01

# %%
season1_ts = season1_ts.set_index('date')
season1_ts
# Out:
#             year quarter  value
# date
# 2016-01-01  2016    Qtr1   1142
# 2016-04-01  2016    Qtr2   1242
# 2016-07-01  2016    Qtr3   1452
# 2016-10-01  2016    Qtr4   1543
# 2017-01-01  2017    Qtr1   1125
# 2017-04-01  2017    Qtr2   1262
# 2017-07-01  2017    Qtr3   1456
# 2017-10-01  2017    Qtr4   1572
# 2018-01-01  2018    Qtr1   1143
# 2018-04-01  2018    Qtr2   1269
# 2018-07-01  2018    Qtr3   1462
# 2018-10-01  2018    Qtr4   1553
# 2019-01-01  2019    Qtr1   1121
# 2019-04-01  2019    Qtr2   1258
# 2019-07-01  2019    Qtr3   1472
# 2019-10-01  2019    Qtr4   1546
# 2020-01-01  2020    Qtr1   1154
# 2020-04-01  2020    Qtr2   1249
# 2020-07-01  2020    Qtr3   1477
# 2020-10-01  2020    Qtr4   1548

# %%
# 시계열 데이터 시각화
plt.figure(figsize=(10,6))
sns.lineplot(x=season1_ts.index, y=season1_ts['value'], marker='o')
plt.title("seasonal time series (계절변동시계열)")
plt.xlabel('date')
plt.ylabel('value')
plt.grid(True)
plt.show()

# %% [markdown]
# 예시: 강수량, 적설량, 아이스크림 판매 추이, 전력 소비량 등

# %% [markdown]
# # 추세변동 시계열

# %%
## 추세변동 시계열
trend = np.array((1142, 1242, 1252, 1343,
                    1225, 1562, 1356, 1572,
                    1343, 1459, 1412, 1453,
                    1401, 1478, 1322, 1606,
                    1554, 1589, 1597, 1408) ).reshape(5,4)
trend_ts = pd.DataFrame(trend, index=range(2016, 2021), columns=['Qtr1', 'Qtr2','Qtr3','Qtr4'])
trend_ts = trend_ts.stack().reset_index()
display(trend_ts)
# Out:
#     level_0 level_1     0
# 0      2016    Qtr1  1142
# 1      2016    Qtr2  1242
# 2      2016    Qtr3  1252
# 3      2016    Qtr4  1343
# 4      2017    Qtr1  1225
# 5      2017    Qtr2  1562
# 6      2017    Qtr3  1356
# 7      2017    Qtr4  1572
# 8      2018    Qtr1  1343
# 9      2018    Qtr2  1459
# 10     2018    Qtr3  1412
# 11     2018    Qtr4  1453
# 12     2019    Qtr1  1401
# 13     2019    Qtr2  1478
# 14     2019    Qtr3  1322
# 15     2019    Qtr4  1606
# 16     2020    Qtr1  1554
# 17     2020    Qtr2  1589
# 18     2020    Qtr3  1597
# 19     2020    Qtr4  1408

# %%
trend_ts.columns = ['year', 'quarter', 'value']
trend_ts
# Out:
#     year quarter  value
# 0   2016    Qtr1   1142
# 1   2016    Qtr2   1242
# 2   2016    Qtr3   1252
# 3   2016    Qtr4   1343
# 4   2017    Qtr1   1225
# 5   2017    Qtr2   1562
# 6   2017    Qtr3   1356
# 7   2017    Qtr4   1572
# 8   2018    Qtr1   1343
# 9   2018    Qtr2   1459
# 10  2018    Qtr3   1412
# 11  2018    Qtr4   1453
# 12  2019    Qtr1   1401
# 13  2019    Qtr2   1478
# 14  2019    Qtr3   1322
# 15  2019    Qtr4   1606
# 16  2020    Qtr1   1554
# 17  2020    Qtr2   1589
# 18  2020    Qtr3   1597
# 19  2020    Qtr4   1408

# %%
trend_ts['year'] = trend_ts['year'].apply(str)
trend_ts['year'].dtype
# Out:
# dtype('O')

# %%
trend_ts['date'] = trend_ts['year'] + trend_ts['quarter']

# %%
trend_ts['date'] = trend_ts['date'].str.replace("tr", "")
trend_ts['date']
# Out:
# 0     2016Q1
# 1     2016Q2
# 2     2016Q3
# 3     2016Q4
# 4     2017Q1
# 5     2017Q2
# 6     2017Q3
# 7     2017Q4
# 8     2018Q1
# 9     2018Q2
# 10    2018Q3
# 11    2018Q4
# 12    2019Q1
# 13    2019Q2
# 14    2019Q3
# 15    2019Q4
# 16    2020Q1
# 17    2020Q2
# 18    2020Q3
# 19    2020Q4
# Name: date, dtype: object

# %%
trend_ts['date'] = pd.PeriodIndex(trend_ts['date'], freq='Q').to_timestamp()
trend_ts
# Out:
#     year quarter  value       date
# 0   2016    Qtr1   1142 2016-01-01
# 1   2016    Qtr2   1242 2016-04-01
# 2   2016    Qtr3   1252 2016-07-01
# 3   2016    Qtr4   1343 2016-10-01
# 4   2017    Qtr1   1225 2017-01-01
# 5   2017    Qtr2   1562 2017-04-01
# 6   2017    Qtr3   1356 2017-07-01
# 7   2017    Qtr4   1572 2017-10-01
# 8   2018    Qtr1   1343 2018-01-01
# 9   2018    Qtr2   1459 2018-04-01
# 10  2018    Qtr3   1412 2018-07-01
# 11  2018    Qtr4   1453 2018-10-01
# 12  2019    Qtr1   1401 2019-01-01
# 13  2019    Qtr2   1478 2019-04-01
# 14  2019    Qtr3   1322 2019-07-01
# 15  2019    Qtr4   1606 2019-10-01
# 16  2020    Qtr1   1554 2020-01-01
# 17  2020    Qtr2   1589 2020-04-01
# 18  2020    Qtr3   1597 2020-07-01
# 19  2020    Qtr4   1408 2020-10-01

# %%
trend_ts = trend_ts.set_index('date')
trend_ts
# Out:
#             year quarter  value
# date
# 2016-01-01  2016    Qtr1   1142
# 2016-04-01  2016    Qtr2   1242
# 2016-07-01  2016    Qtr3   1252
# 2016-10-01  2016    Qtr4   1343
# 2017-01-01  2017    Qtr1   1225
# 2017-04-01  2017    Qtr2   1562
# 2017-07-01  2017    Qtr3   1356
# 2017-10-01  2017    Qtr4   1572
# 2018-01-01  2018    Qtr1   1343
# 2018-04-01  2018    Qtr2   1459
# 2018-07-01  2018    Qtr3   1412
# 2018-10-01  2018    Qtr4   1453
# 2019-01-01  2019    Qtr1   1401
# 2019-04-01  2019    Qtr2   1478
# 2019-07-01  2019    Qtr3   1322
# 2019-10-01  2019    Qtr4   1606
# 2020-01-01  2020    Qtr1   1554
# 2020-04-01  2020    Qtr2   1589
# 2020-07-01  2020    Qtr3   1597
# 2020-10-01  2020    Qtr4   1408

# %%
# 시계열 데이터 시각화
plt.figure(figsize=(10,6))
sns.lineplot(x=trend_ts.index, y=trend_ts['value'], marker='o')
plt.title("trend time series (추세변동시계열)")
plt.xlabel('date')
plt.ylabel('value')
plt.grid(True)
plt.show()

# %% [markdown]
# 예시: 물가 데이터, 희소 원자재 가격 데이터, 대부분의 주가지수 데이터

# %% [markdown]
# # 계절적 추세변동 시계열 데이터

# %%
# 계절적 추세변동 시계열 데이터 생성
st1 = np.array([1142, 1242, 1452, 1543,
                1225, 1362, 1556, 1672,
                1343, 1459, 1662, 1753,
                1421, 1558, 1772, 1846,
                1554, 1649, 1877, 1948])

# 시계열 데이터의 인덱스를 2016년 1분기부터 시작해 분기별로 생성
index = pd.date_range(start='2016Q1', periods=len(st1), freq='QE')
st1_ts = pd.Series(st1, index=index)
st1_ts
# Out:
# 2016-03-31    1142
# 2016-06-30    1242
# 2016-09-30    1452
# 2016-12-31    1543
# 2017-03-31    1225
# 2017-06-30    1362
# 2017-09-30    1556
# 2017-12-31    1672
# 2018-03-31    1343
# 2018-06-30    1459
# 2018-09-30    1662
# 2018-12-31    1753
# 2019-03-31    1421
# 2019-06-30    1558
# 2019-09-30    1772
# 2019-12-31    1846
# 2020-03-31    1554
# 2020-06-30    1649
# 2020-09-30    1877
# 2020-12-31    1948
# Freq: QE-DEC, dtype: int32

# %%
# 시계열 데이터 시각화
plt.figure(figsize=(10,6))
sns.lineplot(x=st1_ts.index, y=st1_ts.values, marker='o')
plt.title("trend time series (추세변동시계열)")
plt.xlabel('date')
plt.ylabel('value')
plt.grid(True)
plt.show()

# %% [markdown]
# # 여러가지 시계열 데이터 모아 보기

# %%
fig, axs = plt.subplots(2,2, figsize=(12,8))

# 랜덤 변동 시계열
axs[0, 0].plot(dd_ts.index, dd_ts['value'], marker='o')
axs[0, 0].set_title("랜덤 변동 시계열")

# 계절 변동 시계열
axs[0, 1].plot(season1_ts.index, season1_ts['value'], marker='o')
axs[0, 1].set_title("계절 변동 시계열")

# 추세 변동 시계열
axs[1, 0].plot(trend_ts.index, trend_ts['value'], marker='o')
axs[1, 0].set_title("추세 변동 시계열")

# 추세 변동 시계열
axs[1, 1].plot(st1_ts.index, st1_ts.values, marker='o')
axs[1, 1].set_title("계절-추세 변동 시계열")

plt.tight_layout()
plt.show()

# %% [markdown]
# # air passenger 데이터로 시각화 해보기

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.datasets import get_rdataset

# %%
# air passenser 데이터 로드
airpass_data = get_rdataset('AirPassengers', package='datasets')

# %%
airpass_data.data
# Out:
#             time  value
# 0    1949.000000    112
# 1    1949.083333    118
# 2    1949.166667    132
# 3    1949.250000    129
# 4    1949.333333    121
# ..           ...    ...
# 139  1960.583333    606
# 140  1960.666667    508
# 141  1960.750000    461
# 142  1960.833333    390
# 143  1960.916667    432
#
# [144 rows x 2 columns]

# %%
airpass_ts = pd.Series(airpass_data.data['value'].values,
                      index = pd.date_range(start='1949-01', periods=len(airpass_data.data), freq='ME'))
airpass_ts
# Out:
# 1949-01-31    112
# 1949-02-28    118
# 1949-03-31    132
# 1949-04-30    129
# 1949-05-31    121
#              ...
# 1960-08-31    606
# 1960-09-30    508
# 1960-10-31    461
# 1960-11-30    390
# 1960-12-31    432
# Freq: ME, Length: 144, dtype: int64

# %% [markdown]
# air passenger 데이터 그래프 그리기

# %%
plt.figure(figsize=(12,6))
plt.plot(airpass_ts, label="Air passengers", color='blue')
result_airpass=seasonal_decompose(airpass_ts, model='additive')
seasonal_adjusted_airpass = airpass_ts - result_airpass.seasonal
plt.plot(seasonal_adjusted_airpass, label="Seasonally Adjusted", color='red', linewidth=2)
plt.title("Air Passengers -- Seasonal Adjustment")
plt.legend()
plt.show()

# %% [markdown]
# # 차분(Difference): diff
# * 현재값에서 과거값을 빼주는 것
# * 변화량을 보기 위해서

# %%
# Create the DataFrame (assuming 'Date' is the index)
data = {
    'Year': [2016, 2016, 2016, 2016, 2017, 2017, 2017, 2017, 2018, 2018, 2018, 2018, 2019, 2019, 2019, 2019, 2020, 2020, 2020, 2020],
    'Quarter': ['Qtr1', 'Qtr2', 'Qtr3', 'Qtr4', 'Qtr1', 'Qtr2', 'Qtr3', 'Qtr4', 'Qtr1', 'Qtr2', 'Qtr3', 'Qtr4', 'Qtr1', 'Qtr2', 'Qtr3', 'Qtr4', 'Qtr1', 'Qtr2', 'Qtr3', 'Qtr4'],
    'Value': [1342, 1442, 1252, 1343, 1425, 1362, 1256, 1272, 1243, 1359, 1412, 1253, 1201, 1478, 1322, 1406, 1254, 1289, 1497, 1208]
}
index = pd.date_range(start='2016-01-01', periods=len(data['Year']), freq='QE')
dd_ts = pd.DataFrame(data, index=index)

dd_ts
# Out:
#             Year Quarter  Value
# 2016-03-31  2016    Qtr1   1342
# 2016-06-30  2016    Qtr2   1442
# 2016-09-30  2016    Qtr3   1252
# 2016-12-31  2016    Qtr4   1343
# 2017-03-31  2017    Qtr1   1425
# 2017-06-30  2017    Qtr2   1362
# 2017-09-30  2017    Qtr3   1256
# 2017-12-31  2017    Qtr4   1272
# 2018-03-31  2018    Qtr1   1243
# 2018-06-30  2018    Qtr2   1359
# 2018-09-30  2018    Qtr3   1412
# 2018-12-31  2018    Qtr4   1253
# 2019-03-31  2019    Qtr1   1201
# 2019-06-30  2019    Qtr2   1478
# 2019-09-30  2019    Qtr3   1322
# 2019-12-31  2019    Qtr4   1406
# 2020-03-31  2020    Qtr1   1254
# 2017-12-31  2017    Qtr4   1272        16.0        -90.0       -153.0      4
# 2018-03-31  2018    Qtr1   1243       -29.0        -13.0       -119.0      1
# 2018-06-30  2018    Qtr2   1359       116.0         87.0        103.0      2
# 2018-09-30  2018    Qtr3   1412        53.0        169.0        140.0      3
# 2018-12-31  2018    Qtr4   1253      -159.0       -106.0         10.0      4
# 2019-03-31  2019    Qtr1   1201       -52.0       -211.0       -158.0      1
# 2019-06-30  2019    Qtr2   1478       277.0        225.0         66.0      2
# 2019-09-30  2019    Qtr3   1322      -156.0        121.0         69.0      3
# 2019-12-31  2019    Qtr4   1406        84.0        -72.0        205.0      4
# 2020-03-31  2020    Qtr1   1254      -152.0        -68.0       -224.0      1
# 2020-06-30  2020    Qtr2   1289        35.0       -117.0        -33.0      2
# 2020-09-30  2020    Qtr3   1497       208.0        243.0         91.0      3
# 2020-12-31  2020    Qtr4   1208      -289.0        -81.0        -46.0      4
#
#             lagged_value  lagged_cycle
# 2016-03-31           NaN             3
# 2016-06-30           NaN             4
# 2016-09-30        1342.0             1
# 2016-12-31        1442.0             2
# 2017-03-31        1252.0             3
# 2017-06-30        1343.0             4
# 2017-09-30        1425.0             1
# 2017-12-31        1362.0             2
# 2018-03-31        1256.0             3
# 2018-06-30        1272.0             4
# 2018-09-30        1243.0             1
# 2018-12-31        1359.0             2
# 2019-03-31        1412.0             3
# 2019-06-30        1253.0             4
# 2019-09-30        1201.0             1
# 2019-12-31        1478.0             2
# 2020-03-31        1322.0             3
# 2020-06-30        1406.0             4
# 2020-09-30        1254.0             1
# 2020-12-31        1289.0             2

# %%
# 시계열 데이터 시각화
plt.figure(figsize=(10,6))
# value 그래프
sns.lineplot(x=dd_ts.index, y=dd_ts['Value'].values, marker='o')
# value_diff 그래프
sns.lineplot(x=dd_ts.index, y=dd_ts['value_diff'].values, marker='o')
# value_diff2 그래프
sns.lineplot(x=dd_ts.index, y=dd_ts['value_diff2'].values, marker='o')
# # value_diff3 그래프
sns.lineplot(x=dd_ts.index, y=dd_ts['value_diff3'].values, marker='o')

plt.title("diff, shift 그래프")
plt.xlabel('date')
plt.ylabel('value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\5-29\AppData\Local\Temp\ipykernel_14816\4237825108.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # 시계열의 합집합 교집합
# * 2개의 시계열 데이터가 있을 때 1개로 합치는 것
# * 합집합 데이터 1, 데이터 2에 있는 모든 자료를 유지하면서 합침
# * 교집합 데이터 1과 2에 모두 있는 데이터를 합침

# %% [markdown]
# 시계열의 합집합

# %%
data1 = np.arange(1,25).reshape(8,3)
dates1 = pd.date_range(start="2019Q1", periods=8, freq='QE')
prod1 = pd.DataFrame(data1, index=dates1, columns=['web', 'app', 'hyb'])
prod1
# Out:
#             web  app  hyb
# 2019-03-31    1    2    3
# 2019-06-30    4    5    6
# 2019-09-30    7    8    9
# 2019-12-31   10   11   12
# 2020-03-31   13   14   15
# 2020-06-30   16   17   18
# 2020-09-30   19   20   21
# 2020-12-31   22   23   24

# %%
data2 = np.arange(11,23).reshape(4,3)
dates2 = pd.date_range(start="2020Q1", periods=4, freq='QE')
prod2 = pd.DataFrame(data2, index=dates2, columns=['web', 'app', 'hyb'])
prod2
# Out:
#             web  app  hyb
# 2020-03-31   11   12   13
# 2020-06-30   14   15   16
# 2020-09-30   17   18   19
# 2020-12-31   20   21   22

# %%
result1 = pd.concat([prod1, prod2]).sort_index()
result1
# Out:
#             web  app  hyb
# 2019-03-31    1    2    3
# 2019-06-30    4    5    6
# 2019-09-30    7    8    9
# 2019-12-31   10   11   12
# 2020-03-31   13   14   15
# 2020-03-31   11   12   13
# 2020-06-30   16   17   18
# 2020-06-30   14   15   16
# 2020-09-30   19   20   21
# 2020-09-30   17   18   19
# 2020-12-31   22   23   24
# 2020-12-31   20   21   22

# %%
result2 = pd.concat([prod1, prod2], axis=1).sort_index()
result2
# Out:
#             web  app  hyb   web   app   hyb
# 2019-03-31    1    2    3   NaN   NaN   NaN
# 2019-06-30    4    5    6   NaN   NaN   NaN
# 2019-09-30    7    8    9   NaN   NaN   NaN
# 2019-12-31   10   11   12   NaN   NaN   NaN
# 2020-03-31   13   14   15  11.0  12.0  13.0
# 2020-06-30   16   17   18  14.0  15.0  16.0
# 2020-09-30   19   20   21  17.0  18.0  19.0
# 2020-12-31   22   23   24  20.0  21.0  22.0

# %% [markdown]
# 시계열의 교집합

# %%
# 교집합 인덱스 계산
common_index = prod1.index.intersection(prod2.index)
common_index
# Out:
# DatetimeIndex(['2020-03-31', '2020-06-30', '2020-09-30', '2020-12-31'], dtype='datetime64[ns]', freq='QE-DEC')

# %%
prod1
# Out:
#             web  app  hyb
# 2019-03-31    1    2    3
# 2019-06-30    4    5    6
# 2019-09-30    7    8    9
# 2019-12-31   10   11   12
# 2020-03-31   13   14   15
# 2020-06-30   16   17   18
# 2020-09-30   19   20   21
# 2020-12-31   22   23   24

# %%
# 교집합을 기반으로 prod1과 prod2에서 행을 선택
intersect_df1 = prod1.loc[common_index]
intersect_df1
# Out:
#             web  app  hyb
# 2020-03-31   13   14   15
# 2020-06-30   16   17   18
# 2020-09-30   19   20   21
# 2020-12-31   22   23   24

# %%
prod2
# Out:
#             web  app  hyb
# 2020-03-31   11   12   13
# 2020-06-30   14   15   16
# 2020-09-30   17   18   19
# 2020-12-31   20   21   22

# %%
# '2020-03-31', '2020-06-30', '2020-09-30', '2020-12-31'

# %%
# 교집합을 기반으로 prod1과 prod2에서 행을 선택
intersect_df2 = prod2.loc[common_index]
intersect_df2
# Out:
#             web  app  hyb
# 2020-03-31   11   12   13
# 2020-06-30   14   15   16
# 2020-09-30   17   18   19
# 2020-12-31   20   21   22

# %%
intersect_result = pd.merge(intersect_df1, intersect_df2, how='inner', on=intersect_df1.index)
intersect_result
# Out:
#        key_0  web_x  app_x  hyb_x  web_y  app_y  hyb_y
# 0 2020-03-31     13     14     15     11     12     13
# 1 2020-06-30     16     17     18     14     15     16
# 2 2020-09-30     19     20     21     17     18     19
# 3 2020-12-31     22     23     24     20     21     22

# %% [markdown]
# # 시계열 자료의 부분 추출 및 수정

# %%
prod1
# Out:
#             web  app  hyb
# 2019-03-31    1    2    3
# 2019-06-30    4    5    6
# 2019-09-30    7    8    9
# 2019-12-31   10   11   12
# 2020-03-31   13   14   15
# 2020-06-30   16   17   18
# 2020-09-30   19   20   21
# 2020-12-31   22   23   24

# %%
prod1.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
# 특정구간 2019 3분기만 추출
prod1_window = prod1.loc['2019Q2':'2019Q2']
prod1_window
# Out:
#             web  app
# 2019-06-30    4    5

# %%
# 2019년 3분기부터 2020년 2분기까지 데이터 추출
prod1_window = prod1.loc['2019Q3':'2020Q2']
prod1_window
# Out:
#             web  app  hyb
# 2019-09-30    7    8    9
# 2019-12-31   10   11   12
# 2020-03-31   13   14   15
# 2020-06-30   16   17   18

# %%
prod2
# Out:
#             web  app  hyb
# 2020-03-31   11   12   13
# 2020-06-30   14   15   16
# 2020-09-30   17   18   19
# 2020-12-31   20   21   22

# %%
# 2020년 3분기 데이터를 11, 22, 33 수정
prod2.loc['2020Q3'] = [11, 22, 33]
prod2
# Out:
#             web  app  hyb
# 2020-03-31   11   12   13
# 2020-06-30   14   15   16
# 2020-09-30   11   22   33
# 2020-12-31   20   21   22

# %% [markdown]
# # resample 함수:  시계열 데이터를 새로운 빈도로 재구성하는 함수
# * YE: 연말 Year End
# * M: 월별 데이터
# * W: 주별 데이터

# %%
prod1
# Out:
#             web  app  hyb
# 2019-03-31    1    2    3
# 2019-06-30    4    5    6
# 2019-09-30    7    8    9
# 2019-12-31   10   11   12
# 2020-03-31   13   14   15
# 2020-06-30   16   17   18
# 2020-09-30   19   20   21
# 2020-12-31   22   23   24

# %%
annual_prod1 =prod1.resample('YE').sum()
annual_prod1
# Out:
#             web  app  hyb
# 2019-12-31   22   26   30
# 2020-12-31   70   74   78

# %%
# 반기별로 데이터를 집계 (두개의 분기를 하나로 묶어 평균 계산)
semi_annual_prod1 = prod1.resample('2QE').sum()
semi_annual_prod1
# Out:
#             web  app  hyb
# 2019-03-31    1    2    3
# 2019-09-30   11   13   15
# 2020-03-31   23   25   27
# 2020-09-30   35   37   39
# 2021-03-31   22   23   24

# %% [markdown]
# # 시계열 데이터 EDA
# * 상태-공간 모형(state-space model) : 과거 데이터를 이용해서 현재값, 미래값을 추축
# * 필터링(filtering), 스무딩(smoothing)작업을 하게 됨

# %% [markdown]
# ## Smoothing(평활화)
# * 시계열 자료에서 무작위성을 줄이는 기법
# * 평활화에 filtering이 포함되기도 함
# * 이동평균 평활법(Moving Average, MA Smoothing)
# * 지수 평활법(Exponential Smoothing): 단순 지수 평활, 이중 지수 평활

# %% [markdown]
# ### 이동평균 평활법(Moving Average)

# %%
import statsmodels.api as sm

# %%
data = sm.datasets.get_rdataset("AirPassengers", "datasets")
air_passengers = data.data
air_passengers
# Out:
#             time  value
# 0    1949.000000    112
# 1    1949.083333    118
# 2    1949.166667    132
# 3    1949.250000    129
# 4    1949.333333    121
# ..           ...    ...
# 139  1960.583333    606
# 140  1960.666667    508
# 141  1960.750000    461
# 142  1960.833333    390
# 143  1960.916667    432
#
# [144 rows x 2 columns]

# %%
air_passengers.index = pd.date_range(start="1949-01", periods=len(air_passengers), freq='ME')
air_passengers
# Out:
#                    time  value
# 1949-01-31  1949.000000    112
# 1949-02-28  1949.083333    118
# 1949-03-31  1949.166667    132
# 1949-04-30  1949.250000    129
# 1949-05-31  1949.333333    121
# ...                 ...    ...
# 1960-08-31  1960.583333    606
# 1960-09-30  1960.666667    508
# 1960-10-31  1960.750000    461
# 1960-11-30  1960.833333    390
# 1960-12-31  1960.916667    432
#
# [144 rows x 2 columns]

# %%
# 3개월 이동 평균 구하기
ma3 = air_passengers['value'].rolling(window=3).mean()
ma3
# Out:
# 1949-01-31           NaN
# 1949-02-28           NaN
# 1949-03-31    120.666667
# 1949-04-30    126.333333
# 1949-05-31    127.333333
#                  ...
# 1960-08-31    587.666667
# 1960-09-30    578.666667
# 1960-10-31    525.000000
# 1960-11-30    453.000000
# 1960-12-31    427.666667
# Freq: ME, Name: value, Length: 144, dtype: float64

# %%
# 6개월 이동 평균 구하기
ma6 = air_passengers['value'].rolling(window=6).mean()
ma6
# Out:
# 1949-01-31           NaN
# 1949-02-28           NaN
# 1949-03-31           NaN
# 1949-04-30           NaN
# 1949-05-31           NaN
#                  ...
# 1960-08-31    519.166667
# 1960-09-30    534.000000
# 1960-10-31    534.000000
# 1960-11-30    520.333333
# 1960-12-31    503.166667
# Freq: ME, Name: value, Length: 144, dtype: float64

# %%
# 12개월 이동 평균 구하기
ma12 = air_passengers['value'].rolling(window=12).mean()
ma12.head(15)
# Out:
# 1949-01-31           NaN
# 1949-02-28           NaN
# 1949-03-31           NaN
# 1949-04-30           NaN
# 1949-05-31           NaN
# 1949-06-30           NaN
# 1949-07-31           NaN
# 1949-08-31           NaN
# 1949-09-30           NaN
# 1949-10-31           NaN
# 1949-11-30           NaN
# 1949-12-31    126.666667
# 1950-01-31    126.916667
# 1950-02-28    127.583333
# 1950-03-31    128.333333
# Freq: ME, Name: value, dtype: float64

# %%
fig, axs = plt.subplots(4,1,figsize=(10,12))

# 원본 데이터
axs[0].plot(air_passengers.index, air_passengers['value'], label="Original_data")
axs[0].set_title('Air Passengers: Original Data')

# 3개월 이동 평균
axs[1].plot(air_passengers.index, ma3, label="3-points moving average", color='orange')
axs[1].set_title('3-points moving average')

# 6개월 이동 평균
axs[2].plot(air_passengers.index, ma6, label="6-points moving average", color='green')
axs[2].set_title('6-points moving average')

# 12개월 이동 평균
axs[3].plot(air_passengers.index, ma12, label="12-points moving average", color='red')
axs[3].set_title('12-points moving average')
# Out:
# Text(0.5, 1.0, '12-points moving average')
