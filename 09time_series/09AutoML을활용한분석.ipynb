# %%
# !pip install "flaml[catboost]"

# %%
import numpy as np
import pandas as pd
from autogluon.tabular import TabularPredictor

# %%
data = pd.read_csv("https://raw.githubusercontent.com/haram4th/ablearn/main/Taitanic_train.csv")
data.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
data = data.drop(['PassengerId', 'Cabin', 'Ticket', 'Name', 'Fare'], axis=1)

# %%
target_column = 'Survived'

time_limit = 60  # for quick demonstration only, you should set this to longest time you are willing to wait (in seconds)
metric = 'roc_auc'  # specify your evaluation metric here

model = TabularPredictor(label=target_column, eval_metric=metric)
model.fit(data, time_limit=time_limit, presets='best_quality' )
test_data = data.sample(frac=0.3, random_state=10)

pred = model.predict(test_data)
print("Train Score:", model.evaluate(test_data))
print("best model: ", model.get_model_best())
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20241016_070652"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.15
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Fri Mar 29 23:14:13 UTC 2024
# CPU Count:          8
# Memory Avail:       11.91 GB / 14.61 GB (81.5%)
# Disk Space Avail:   21.43 GB / 223.03 GB (9.6%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 15s of the 60s of remaining time (25%).
# 		Context path: "AutogluonModels/ag-20241016_070652/ds_sub_fit/sub_fit_ho"
# Leaderboard on holdout data (DyStack):
#                    model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val  fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0    WeightedEnsemble_L3       0.868637   0.872546     roc_auc        0.693910       0.119989  4.291467                 0.006853                0.000655           0.031582            3       True          6
# 1    WeightedEnsemble_L2       0.868637   0.872546     roc_auc        0.694421       0.120224  4.292920                 0.007365                0.000889           0.033035            2       True          5
# 2        LightGBM_BAG_L1       0.867774   0.864950     roc_auc        0.088287       0.057895  2.268724                 0.088287                0.057895           2.268724            1       True          4
# 3      LightGBMXT_BAG_L1       0.860440   0.857670     roc_auc        0.587960       0.058131  1.987035                 0.587960                0.058131           1.987035            1       True          3
# 4  KNeighborsDist_BAG_L1       0.586281   0.690213     roc_auc        0.010810       0.003308  0.004125                 0.010810                0.003308           0.004125            1       True          2
# 5  KNeighborsUnif_BAG_L1       0.575496   0.687123     roc_auc        0.011046       0.004429  0.191506                 0.011046                0.004429           0.191506            1       True          1
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	22s	 = DyStack   runtime |	38s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 38s
# AutoGluon will save models to "AutogluonModels/ag-20241016_070652"
# Train Data Rows:    891
# Train Data Columns: 6
# Label Column:       Survived
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11821.55 MB
# 	Train Data (Original)  Memory Usage: 0.13 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 1 | ['Age']
# 		('int', [])    : 3 | ['Pclass', 'SibSp', 'Parch']
# 		('object', []) : 2 | ['Sex', 'Embarked']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 1 | ['Embarked']
# 		('float', [])     : 1 | ['Age']
# 		('int', [])       : 3 | ['Pclass', 'SibSp', 'Parch']
# 		('int', ['bool']) : 1 | ['Sex']
# 	0.1s = Fit runtime
# 	6 features in original data used to generate 6 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.03 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.22s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 25.31s of the 37.95s of remaining time.
# 	0.6872	 = Validation score   (roc_auc)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 25.15s of the 37.79s of remaining time.
# 	0.6859	 = Validation score   (roc_auc)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 25.01s of the 37.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8567	 = Validation score   (roc_auc)
# 	3.45s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 16.55s of the 29.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8676	 = Validation score   (roc_auc)
# 	3.3s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 9.27s of the 21.91s of remaining time.
# 	0.8294	 = Validation score   (roc_auc)
# 	1.1s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 7.91s of the 20.55s of remaining time.
# 	0.8266	 = Validation score   (roc_auc)
# 	1.02s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 6.62s of the 19.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.8652	 = Validation score   (roc_auc)
# 	3.55s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 37.98s of the 10.76s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.45, 'LightGBM_BAG_L1': 0.4, 'LightGBMXT_BAG_L1': 0.1, 'KNeighborsDist_BAG_L1': 0.05}
# 	0.8734	 = Validation score   (roc_auc)
# 	0.06s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 10.64s of the 10.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.8985	 = Validation score   (roc_auc)
# 	2.34s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 4.13s of the 4.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.8935	 = Validation score   (roc_auc)
# 	2.26s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 37.98s of the -4.26s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L2': 0.526, 'LightGBM_BAG_L2': 0.421, 'LightGBMXT_BAG_L1': 0.053}
# 	0.9014	 = Validation score   (roc_auc)
# 	0.07s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 42.72s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 307.9 rows/s (112 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20241016_070652")
# Train Score: {'roc_auc': 0.9156470152020765, 'accuracy': 0.8651685393258427, 'balanced_accuracy': 0.8414905450500556, 'mcc': 0.6985212475483001, 'f1': 0.797752808988764, 'precision': 0.8352941176470589, 'recall': 0.7634408602150538}
# best model:  WeightedEnsemble_L3
# /tmp/ipykernel_7302/227806693.py:12: DeprecationWarning: `get_model_best` has been deprecated and will be removed in version 1.2. Please use `model_best` instead. This will raise an error in the future!
#   print("best model: ", model.get_model_best())

# %%
result = model.evaluate(test_data)
pd.DataFrame(result, index=result.keys())
# Out:
#                     roc_auc  accuracy  balanced_accuracy       mcc        f1  \
# roc_auc            0.915647  0.865169           0.841491  0.698521  0.797753
# accuracy           0.915647  0.865169           0.841491  0.698521  0.797753
# balanced_accuracy  0.915647  0.865169           0.841491  0.698521  0.797753
# mcc                0.915647  0.865169           0.841491  0.698521  0.797753
# f1                 0.915647  0.865169           0.841491  0.698521  0.797753
# precision          0.915647  0.865169           0.841491  0.698521  0.797753
# recall             0.915647  0.865169           0.841491  0.698521  0.797753
#
#                    precision    recall
# roc_auc             0.835294  0.763441
# accuracy            0.835294  0.763441
# balanced_accuracy   0.835294  0.763441
# mcc                 0.835294  0.763441
# f1                  0.835294  0.763441
# precision           0.835294  0.763441
# recall              0.835294  0.763441

# %%
model.leaderboard(test_data)
# Out:
#                       model  score_test  score_val eval_metric  \
# 0   RandomForestEntr_BAG_L1    0.979792   0.826609     roc_auc
# 1   RandomForestGini_BAG_L1    0.979669   0.829440     roc_auc
# 2           LightGBM_BAG_L1    0.944506   0.867646     roc_auc
# 3       WeightedEnsemble_L2    0.943456   0.873388     roc_auc
# 4           CatBoost_BAG_L1    0.924793   0.865217     roc_auc
# 5     KNeighborsDist_BAG_L1    0.917285   0.685896     roc_auc
# 6         LightGBMXT_BAG_L1    0.917223   0.856675     roc_auc
# 7       WeightedEnsemble_L3    0.915647   0.901448     roc_auc
# 8         LightGBMXT_BAG_L2    0.914349   0.898486     roc_auc
# 9           LightGBM_BAG_L2    0.910580   0.893496     roc_auc
# 10    KNeighborsUnif_BAG_L1    0.817946   0.687180     roc_auc
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0         0.214490       0.100959   1.024666                 0.214490
# 1         0.217632       0.097103   1.095873                 0.217632
# 2         0.088073       0.054638   3.303162                 0.088073
# 3         0.273934       0.168392  10.371166                 0.006214
# 4         0.067870       0.043397   3.553045                 0.067870
# 5         0.014668       0.005558   0.005856                 0.014668
# 6         0.097110       0.064112   3.452994                 0.097110
# 7         0.930441       0.546713  17.111321                 0.006458
# 8         0.840268       0.483254  14.782022                 0.124690
# 9         0.799293       0.433618  14.704492                 0.083715
# 10        0.015735       0.005034   0.008065                 0.015735
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.100959           1.024666            1       True
# 1                 0.097103           1.095873            1       True
# 2                 0.054638           3.303162            1       True
# 3                 0.000687           0.056108            2       True
# 4                 0.043397           3.553045            1       True
# 5                 0.005558           0.005856            1       True
# 6                 0.064112           3.452994            1       True
# 7                 0.000642           0.068467            3       True
# 8                 0.112453           2.338362            2       True
# 9                 0.062818           2.260832            2       True
# 10                0.005034           0.008065            1       True
#
#     fit_order
# 0           6
# 1           5
# 2           4
# 3           8
# 4           7
# 5           2
# 6           3
# 7          11
# 8           9
# 9          10
# 10          1

# %%
model.feature_importance(test_data)
# Out:
# Computing feature importance via permutation shuffling for 6 features using 267 rows with 5 shuffle sets...
# 	33.28s	= Expected runtime (6.66s per shuffle set)
# 	6.64s	= Actual runtime (Completed 5 of 5 shuffle sets)
#           importance    stddev   p_value  n  p99_high   p99_low
# Sex         0.209702  0.030827  0.000054  5  0.273175  0.146229
# Pclass      0.091175  0.014772  0.000080  5  0.121592  0.060759
# Age         0.090131  0.026158  0.000764  5  0.143991  0.036271
# Parch       0.005327  0.005501  0.048165  5  0.016654 -0.006000
# SibSp       0.003770  0.009033  0.201795  5  0.022370 -0.014830
# Embarked   -0.006921  0.006331  0.964572  5  0.006114 -0.019957

# %%
model.model_best
# Out:
# 'WeightedEnsemble_L3'

# %%
model.model_names()
# Out:
# ['KNeighborsUnif_BAG_L1',
#  'KNeighborsDist_BAG_L1',
#  'LightGBMXT_BAG_L1',
#  'LightGBM_BAG_L1',
#  'RandomForestGini_BAG_L1',
#  'RandomForestEntr_BAG_L1',
#  'CatBoost_BAG_L1',
#  'WeightedEnsemble_L2',
#  'LightGBMXT_BAG_L2',
#  'LightGBM_BAG_L2',
#  'WeightedEnsemble_L3']

# %%
data = pd.read_csv("https://raw.githubusercontent.com/haram4th/ADsP/main/salary2.csv")
data.head()
# Out:
#    age   workclass      education  education-num       marital-status  \
# 0   25     Private           11th              7        Never-married
# 1   38     Private        HS-grad              9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm             12   Married-civ-spouse
# 3   44     Private   Some-college             10   Married-civ-spouse
# 4   18         NaN   Some-college             10        Never-married
#
#            occupation relationship    race      sex  capital-gain  \
# 0   Machine-op-inspct    Own-child   Black     Male             0
# 1     Farming-fishing      Husband   White     Male             0
# 2     Protective-serv      Husband   White     Male             0
# 3   Machine-op-inspct      Husband   Black     Male          7688
# 4                 NaN    Own-child   White   Female             0
#
#    capital-loss  hours-per-week  native-country   class
# 0             0              40   United-States   <=50K
# 1             0              50   United-States   <=50K
# 2             0              40   United-States    >50K
# 3             0              40   United-States    >50K
# 4             0              30   United-States   <=50K

# %%
target_column = 'class'

time_limit = 180  # for quick demonstration only, you should set this to longest time you are willing to wait (in seconds)
metric = 'accuracy'  # specify your evaluation metric here

model = TabularPredictor(label=target_column, eval_metric=metric)
model.fit(data, time_limit=time_limit, presets='best_quality' )
test_data = data.sample(frac=0.3, random_state=10)

pred = model.predict(test_data)

result = model.evaluate(test_data)
result_df = pd.DataFrame(result, index=result.keys())
leader_board = model.leaderboard(test_data)
feature_importance = model.feature_importance(test_data)
best_model_name = model.model_best
best_model = model._trainer.load_model(best_model_name)  # Load the best model
best_model_params = best_model.params


display(result_df)
print()
display(leader_board)
print()
display(feature_importance)
print("best_model",best_model_name)
print("Best model hyperparameters:")
print(best_model_params)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20241016_073132"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.15
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Fri Mar 29 23:14:13 UTC 2024
# CPU Count:          8
# Memory Avail:       11.21 GB / 14.61 GB (76.7%)
# Disk Space Avail:   23.39 GB / 223.03 GB (10.5%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 45s of the 180s of remaining time (25%).
# 		Context path: "AutogluonModels/ag-20241016_073132/ds_sub_fit/sub_fit_ho"
# Leaderboard on holdout data (DyStack):
#                    model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0        LightGBM_BAG_L1       0.872489   0.874099    accuracy        0.275665       0.802135   4.211909                 0.275665                0.802135           4.211909            1       True          4
# 1    WeightedEnsemble_L2       0.872489   0.874099    accuracy        0.283055       0.805225   4.503557                 0.007390                0.003090           0.291649            2       True          5
# 2        LightGBM_BAG_L2       0.871937   0.874467    accuracy        1.709387       4.653563  15.257304                 0.133744                0.275132           3.279784            2       True          7
# 3      LightGBMXT_BAG_L2       0.871568   0.874997    accuracy        1.767489       4.804652  16.482836                 0.191847                0.426221           4.505316            2       True          6
# 4    WeightedEnsemble_L3       0.871568   0.874997    accuracy        1.773843       4.807888  16.977483                 0.006353                0.003236           0.494647            3       True          8
# 5      LightGBMXT_BAG_L1       0.868988   0.869262    accuracy        0.973243       1.763213   7.450284                 0.973243                1.763213           7.450284            1       True          3
# 6  KNeighborsUnif_BAG_L1       0.822922   0.817137    accuracy        0.172982       0.948633   0.274438                 0.172982                0.948633           0.274438            1       True          1
# 7  KNeighborsDist_BAG_L1       0.818869   0.815018    accuracy        0.153754       0.864450   0.040889                 0.153754                0.864450           0.040889            1       True          2
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	58s	 = DyStack   runtime |	122s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# Beginning AutoGluon training ... Time limit = 122s
# AutoGluon will save models to "AutogluonModels/ag-20241016_073132"
# Train Data Rows:    48842
# Train Data Columns: 13
# Label Column:       class
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 =  >50K, class 0 =  <=50K
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive ( >50K) vs negative ( <=50K) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11034.81 MB
# 	Train Data (Original)  Memory Usage: 26.77 MB (0.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 5 | ['age', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
# 		('object', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 7 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 		('int', [])       : 5 | ['age', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
# 		('int', ['bool']) : 1 | ['sex']
# 	0.4s = Fit runtime
# 	13 features in original data used to generate 13 features in processed data.
# 	Train Data (Processed) Memory Usage: 2.24 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.49s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 121.96s of the 121.95s of remaining time.
# 	0.8221	 = Validation score   (accuracy)
# 	0.06s	 = Training   runtime
# 	1.15s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 120.62s of the 120.6s of remaining time.
# 	0.8195	 = Validation score   (accuracy)
# 	0.05s	 = Training   runtime
# 	1.11s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 119.32s of the 119.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# 	0.8698	 = Validation score   (accuracy)
# 	8.5s	 = Training   runtime
# 	2.33s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 105.98s of the 105.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# 	0.8749	 = Validation score   (accuracy)
# 	5.95s	 = Training   runtime
# 	1.31s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 95.93s of the 95.92s of remaining time.
# 	0.8507	 = Validation score   (accuracy)
# 	5.32s	 = Training   runtime
# 	1.63s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 86.28s of the 86.27s of remaining time.
# 	0.851	 = Validation score   (accuracy)
# 	5.0s	 = Training   runtime
# 	1.54s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 77.33s of the 77.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# 	0.8736	 = Validation score   (accuracy)
# 	62.5s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 10.96s of the 10.95s of remaining time.
# 	Not enough time to generate out-of-fold predictions for model. Estimated time required was 16.6s compared to 10s of available time.
# 	Time limit exceeded... Skipping ExtraTreesGini_BAG_L1.
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 5.63s of the 5.62s of remaining time.
# 	Not enough time to generate out-of-fold predictions for model. Estimated time required was 14.26s compared to 10s of available time.
# 	Time limit exceeded... Skipping ExtraTreesEntr_BAG_L1.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 121.97s of the -0.09s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L1': 1.0}
# 	0.8749	 = Validation score   (accuracy)
# 	0.58s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 123.33s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 4644.3 rows/s (6106 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20241016_073132")
# Computing feature importance via permutation shuffling for 13 features using 5000 rows with 5 shuffle sets...
# 	23.68s	= Expected runtime (4.74s per shuffle set)
# 	14.2s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                    accuracy  balanced_accuracy       mcc   roc_auc        f1  \
# accuracy           0.881116           0.809646  0.659851  0.940308  0.731173
# balanced_accuracy  0.881116           0.809646  0.659851  0.940308  0.731173
# mcc                0.881116           0.809646  0.659851  0.940308  0.731173
# roc_auc            0.881116           0.809646  0.659851  0.940308  0.731173
# f1                 0.881116           0.809646  0.659851  0.940308  0.731173
# precision          0.881116           0.809646  0.659851  0.940308  0.731173
# recall             0.881116           0.809646  0.659851  0.940308  0.731173
#
#                    precision    recall
# accuracy            0.801963  0.671866
# balanced_accuracy   0.801963  0.671866
# mcc                 0.801963  0.671866
# roc_auc             0.801963  0.671866
# f1                  0.801963  0.671866
# precision           0.801963  0.671866
# recall              0.801963  0.671866
#                      model  score_test  score_val eval_metric  pred_time_test  \
# 0  RandomForestGini_BAG_L1    0.970450   0.850723    accuracy        2.305634
# 1  RandomForestEntr_BAG_L1    0.970245   0.850989    accuracy        2.246618
# 2          LightGBM_BAG_L1    0.881116   0.874923    accuracy        0.629083
# 3      WeightedEnsemble_L2    0.881116   0.874923    accuracy        0.634336
# 4        LightGBMXT_BAG_L1    0.877363   0.869825    accuracy        1.413354
# 5          CatBoost_BAG_L1    0.876612   0.873551    accuracy        0.153359
# 6    KNeighborsDist_BAG_L1    0.871903   0.819479    accuracy        0.352252
# 7    KNeighborsUnif_BAG_L1    0.850884   0.822120    accuracy        0.351526
#
#    pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0       1.629448   5.324341                 2.305634                1.629448
# 1       1.535965   5.003197                 2.246618                1.535965
# 2       1.314247   5.954430                 0.629083                1.314247
# 3       1.318172   6.529525                 0.005253                0.003925
# 4       2.330040   8.503313                 1.413354                2.330040
# 5       0.362399  62.496770                 0.153359                0.362399
# 6       1.107115   0.047843                 0.352252                1.107115
# 7       1.147373   0.060648                 0.351526                1.147373
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           5.324341            1       True          5
# 1           5.003197            1       True          6
# 2           5.954430            1       True          4
# 3           0.575095            2       True          8
# 4           8.503313            1       True          3
# 5          62.496770            1       True          7
# 6           0.047843            1       True          2
# 7           0.060648            1       True          1
#                 importance    stddev       p_value  n  p99_high   p99_low
# capital-gain       0.05792  0.002741  5.999052e-07  5  0.063563  0.052277
# age                0.02324  0.003064  3.543106e-05  5  0.029549  0.016931
# education-num      0.02216  0.002211  1.173337e-05  5  0.026712  0.017608
# occupation         0.02056  0.002605  3.029219e-05  5  0.025925  0.015195
# relationship       0.01560  0.003857  4.142733e-04  5  0.023543  0.007657
# capital-loss       0.01444  0.000805  1.154157e-06  5  0.016097  0.012783
# marital-status     0.01332  0.003961  8.374646e-04  5  0.021476  0.005164
# hours-per-week     0.01032  0.003754  1.775928e-03  5  0.018049  0.002591
# workclass          0.00400  0.001600  2.511999e-03  5  0.007294  0.000706
# native-country     0.00232  0.001653  1.744778e-02  5  0.005723 -0.001083
# education          0.00092  0.000672  1.883156e-02  5  0.002304 -0.000464
# sex                0.00088  0.000559  1.219397e-02  5  0.002030 -0.000270
# race               0.00072  0.000672  3.739321e-02  5  0.002104 -0.000664
# best_model <autogluon.core.models.ensemble.weighted_ensemble_model.WeightedEnsembleModel object at 0x7f9a3f960dc0>
# Best model hyperparameters:
# {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}

# %%
print("best_model",best_model_name)
# Out:
# best_model WeightedEnsemble_L2

# %% [markdown]
# # 회귀분석

# %%
data = pd.read_csv("https://raw.githubusercontent.com/haram4th/ADsP/main/01%EB%B3%B4%EC%8A%A4%ED%84%B4%EC%A7%91%EA%B0%92%EB%8D%B0%EC%9D%B4%ED%84%B0.csv", encoding='utf-8')
data
# Out:
#          범죄율  25,000평방피트초과  비소매상업지역비율  찰스강경계  농축 일산화질소  가구당평균방수  1940년이전건축비율  \
# 0    0.00632          18.0       2.31      0     0.538    6.575         65.2
# 1    0.02731           0.0       7.07      0     0.469    6.421         78.9
# 2    0.02729           0.0       7.07      0     0.469    7.185         61.1
# 3    0.03237           0.0       2.18      0     0.458    6.998         45.8
# 4    0.06905           0.0       2.18      0     0.458    7.147         54.2
# ..       ...           ...        ...    ...       ...      ...          ...
# 501  0.06263           0.0      11.93      0     0.573    6.593         69.1
# 502  0.04527           0.0      11.93      0     0.573    6.120         76.7
# 503  0.06076           0.0      11.93      0     0.573    6.976         91.0
# 504  0.10959           0.0      11.93      0     0.573    6.794         89.3
# 505  0.04741           0.0      11.93      0     0.573    6.030         80.8
#
#      직업센터접근성  도로접근성   재산세율  학생/교사비율    흑인비율  하위계층비율  주택가격
# 0     4.0900      1  296.0     15.3  396.90    4.98  24.0
# 1     4.9671      2  242.0     17.8  396.90    9.14  21.6
# 2     4.9671      2  242.0     17.8  392.83    4.03  34.7
# 3     6.0622      3  222.0     18.7  394.63    2.94  33.4
# 4     6.0622      3  222.0     18.7  396.90    5.33  36.2
# ..       ...    ...    ...      ...     ...     ...   ...
# 501   2.4786      1  273.0     21.0  391.99    9.67  22.4
# 502   2.2875      1  273.0     21.0  396.90    9.08  20.6
# 503   2.1675      1  273.0     21.0  396.90    5.64  23.9
# 504   2.3889      1  273.0     21.0  393.45    6.48  22.0
# 505   2.5050      1  273.0     21.0  396.90    7.88  11.9
#
# [506 rows x 14 columns]

# %%
target_column = '주택가격'

time_limit = 300  # for quick demonstration only, you should set this to longest time you are willing to wait (in seconds)
metric = 'root_mean_squared_error'  # specify your evaluation metric here

model = TabularPredictor(label=target_column, eval_metric=metric)
model.fit(data, time_limit=time_limit, presets='best_quality' )
test_data = data.sample(frac=0.3, random_state=10)

pred = model.predict(test_data)

result = model.evaluate(test_data)
result_df = pd.DataFrame(result, index=result.keys())
leader_board = model.leaderboard(test_data)
feature_importance = model.feature_importance(test_data)
best_model_name = model.model_best
best_model = model._trainer.load_model(best_model_name)  # Load the best model
best_model_params = best_model.params


display(result_df)
print()
display(leader_board)
print()
display(feature_importance)
print("best_model",best_model_name)
print("Best model hyperparameters:")
print(best_model_params)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20241016_074913"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.15
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Fri Mar 29 23:14:13 UTC 2024
# CPU Count:          8
# Memory Avail:       11.05 GB / 14.61 GB (75.6%)
# Disk Space Avail:   22.85 GB / 223.03 GB (10.2%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 75s of the 300s of remaining time (25%).
# 		Context path: "AutogluonModels/ag-20241016_074913/ds_sub_fit/sub_fit_ho"
# Leaderboard on holdout data (DyStack):
#                      model  score_holdout  score_val              eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L3      -2.160630  -2.868291  root_mean_squared_error        2.219854       0.748950  43.993795                 0.009392                0.000445           0.016804            3       True         11
# 1          LightGBM_BAG_L2      -2.167501  -2.960683  root_mean_squared_error        1.883569       0.517416  38.169971                 0.166191                0.051251           4.003790            2       True         10
# 2        LightGBMXT_BAG_L2      -2.231591  -2.981448  root_mean_squared_error        2.044270       0.697254  39.973200                 0.326892                0.231089           5.807020            2       True          9
# 3          CatBoost_BAG_L1      -2.247964  -3.029770  root_mean_squared_error        0.473249       0.022541  24.167076                 0.473249                0.022541          24.167076            1       True          6
# 4     ExtraTreesMSE_BAG_L1      -2.249066  -3.288110  root_mean_squared_error        0.211326       0.121641   0.833427                 0.211326                0.121641           0.833427            1       True          7
# 5      WeightedEnsemble_L2      -2.292443  -3.001132  root_mean_squared_error        1.487319       0.338870  33.150931                 0.007312                0.000451           0.012977            2       True          8
# 6        LightGBMXT_BAG_L1      -2.434039  -3.259977  root_mean_squared_error        0.591328       0.116399   3.095789                 0.591328                0.116399           3.095789            1       True          3
# 7          LightGBM_BAG_L1      -2.484647  -3.310976  root_mean_squared_error        0.158621       0.074296   5.087197                 0.158621                0.074296           5.087197            1       True          4
# 8   RandomForestMSE_BAG_L1      -2.825798  -3.359171  root_mean_squared_error        0.256809       0.125182   0.787893                 0.256809                0.125182           0.787893            1       True          5
# 9    KNeighborsDist_BAG_L1      -5.113589  -6.151995  root_mean_squared_error        0.013189       0.002907   0.004732                 0.013189                0.002907           0.004732            1       True          2
# 10   KNeighborsUnif_BAG_L1      -5.375645  -6.372194  root_mean_squared_error        0.012856       0.003198   0.190068                 0.012856                0.003198           0.190068            1       True          1
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	95s	 = DyStack   runtime |	205s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 205s
# AutoGluon will save models to "AutogluonModels/ag-20241016_074913"
# Train Data Rows:    506
# Train Data Columns: 13
# Label Column:       주택가격
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    10819.65 MB
# 	Train Data (Original)  Memory Usage: 0.05 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 11 | ['범죄율', '25,000평방피트초과', '비소매상업지역비율', '농축 일산화질소', '가구당평균방수', ...]
# 		('int', [])   :  2 | ['찰스강경계', '도로접근성']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 11 | ['범죄율', '25,000평방피트초과', '비소매상업지역비율', '농축 일산화질소', '가구당평균방수', ...]
# 		('int', [])       :  1 | ['도로접근성']
# 		('int', ['bool']) :  1 | ['찰스강경계']
# 	0.1s = Fit runtime
# 	13 features in original data used to generate 13 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.05 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.16s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 136.4s of the 204.64s of remaining time.
# 	-6.118	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 136.25s of the 204.48s of remaining time.
# 	-5.8997	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 136.1s of the 204.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	-3.002	 = Validation score   (-root_mean_squared_error)
# 	4.42s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 127.32s of the 195.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	-3.1024	 = Validation score   (-root_mean_squared_error)
# 	6.36s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 116.05s of the 184.28s of remaining time.
# 	-3.2218	 = Validation score   (-root_mean_squared_error)
# 	0.74s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 115.02s of the 183.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	-2.8277	 = Validation score   (-root_mean_squared_error)
# 	92.17s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 19.22s of the 87.45s of remaining time.
# 	-3.1109	 = Validation score   (-root_mean_squared_error)
# 	0.72s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 18.21s of the 86.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	-3.7906	 = Validation score   (-root_mean_squared_error)
# 	7.02s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 7.1s of the 75.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.06%)
# 	-3.0356	 = Validation score   (-root_mean_squared_error)
# 	3.49s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 204.66s of the 64.99s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.44, 'XGBoost_BAG_L1': 0.32, 'LightGBMXT_BAG_L1': 0.2, 'KNeighborsDist_BAG_L1': 0.04}
# 	-2.7392	 = Validation score   (-root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 64.84s of the 64.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	-2.8537	 = Validation score   (-root_mean_squared_error)
# 	3.01s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 57.49s of the 57.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	-2.9887	 = Validation score   (-root_mean_squared_error)
# 	3.27s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 49.96s of the 49.83s of remaining time.
# 	-2.9435	 = Validation score   (-root_mean_squared_error)
# 	0.99s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 48.65s of the 48.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.08%)
# 	-2.7837	 = Validation score   (-root_mean_squared_error)
# 	38.97s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 6.03s of the 5.91s of remaining time.
# 	-2.7933	 = Validation score   (-root_mean_squared_error)
# 	0.76s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 4.97s of the 4.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	-3.1252	 = Validation score   (-root_mean_squared_error)
# 	6.82s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 204.66s of the -8.21s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L2': 0.28, 'CatBoost_BAG_L1': 0.24, 'XGBoost_BAG_L1': 0.2, 'ExtraTreesMSE_BAG_L2': 0.16, 'LightGBMXT_BAG_L1': 0.08, 'LightGBMXT_BAG_L2': 0.04}
# 	-2.7118	 = Validation score   (-root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 213.25s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 75.2 rows/s (64 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20241016_074913")
# Computing feature importance via permutation shuffling for 13 features using 152 rows with 5 shuffle sets...
# 	158.33s	= Expected runtime (31.67s per shuffle set)
# 	26.21s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                          root_mean_squared_error  mean_squared_error  \
# root_mean_squared_error                 -1.08121           -1.169015
# mean_squared_error                      -1.08121           -1.169015
# mean_absolute_error                     -1.08121           -1.169015
# r2                                      -1.08121           -1.169015
# pearsonr                                -1.08121           -1.169015
# median_absolute_error                   -1.08121           -1.169015
#
#                          mean_absolute_error        r2  pearsonr  \
# root_mean_squared_error            -0.751914  0.988026  0.994284
# mean_squared_error                 -0.751914  0.988026  0.994284
# mean_absolute_error                -0.751914  0.988026  0.994284
# r2                                 -0.751914  0.988026  0.994284
# pearsonr                           -0.751914  0.988026  0.994284
# median_absolute_error              -0.751914  0.988026  0.994284
#
#                          median_absolute_error
# root_mean_squared_error              -0.481043
# mean_squared_error                   -0.481043
# mean_absolute_error                  -0.481043
# r2                                   -0.481043
# pearsonr                             -0.481043
# median_absolute_error                -0.481043
#                      model    score_test  score_val              eval_metric  \
# 0    KNeighborsDist_BAG_L1 -5.601568e-07  -5.899656  root_mean_squared_error
# 1           XGBoost_BAG_L1 -7.328195e-01  -3.035623  root_mean_squared_error
# 2      WeightedEnsemble_L2 -1.038655e+00  -2.739229  root_mean_squared_error
# 3          CatBoost_BAG_L1 -1.071903e+00  -2.827676  root_mean_squared_error
# 4      WeightedEnsemble_L3 -1.081210e+00  -2.711846  root_mean_squared_error
# 5          CatBoost_BAG_L2 -1.170667e+00  -2.783699  root_mean_squared_error
# 6     ExtraTreesMSE_BAG_L1 -1.242730e+00  -3.110923  root_mean_squared_error
# 7   RandomForestMSE_BAG_L1 -1.332065e+00  -3.221807  root_mean_squared_error
# 8        LightGBMXT_BAG_L2 -1.379469e+00  -2.853690  root_mean_squared_error
# 9   RandomForestMSE_BAG_L2 -1.415651e+00  -2.943494  root_mean_squared_error
# 10         LightGBM_BAG_L1 -1.415916e+00  -3.102383  root_mean_squared_error
# 11    ExtraTreesMSE_BAG_L2 -1.469057e+00  -2.793346  root_mean_squared_error
# 12  NeuralNetFastAI_BAG_L2 -1.499229e+00  -3.125221  root_mean_squared_error
# 13         LightGBM_BAG_L2 -1.552268e+00  -2.988732  root_mean_squared_error
# 14       LightGBMXT_BAG_L1 -1.904277e+00  -3.002044  root_mean_squared_error
# 15  NeuralNetFastAI_BAG_L1 -3.296898e+00  -3.790613  root_mean_squared_error
# 16   KNeighborsUnif_BAG_L1 -5.552740e+00  -6.117969  root_mean_squared_error
#
#     pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 0         0.010998       0.002579    0.005645                 0.010998
# 1         0.315282       0.079022    3.489153                 0.315282
# 2         0.803334       0.285506  100.110054                 0.006584
# 3         0.174125       0.024807   92.172664                 0.174125
# 4         2.242691       1.092900  157.700598                 0.007429
# 5         1.893676       0.962246  153.916228                 0.106791
# 6         0.204609       0.090063    0.720366                 0.204609
# 7         0.212330       0.086604    0.743534                 0.212330
# 8         1.892661       0.982773  117.952201                 0.105776
# 9         2.000137       1.034724  115.940083                 0.213252
# 10        0.344849       0.213362    6.363785                 0.344849
# 11        2.022694       1.034441  115.701737                 0.235809
# 12        2.018080       1.147316  121.769887                 0.231195
# 13        1.864510       0.970994  118.212615                 0.077626
# 14        0.296345       0.178489    4.423339                 0.296345
# 15        0.217107       0.262969    7.020853                 0.217107
# 16        0.011240       0.005671    0.006498                 0.011240
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.002579           0.005645            1       True
# 1                 0.079022           3.489153            1       True
# 2                 0.000609           0.019254            2       True
# 3                 0.024807          92.172664            1       True
# 4                 0.000572           0.022102            3       True
# 5                 0.018680          38.970393            2       True
# 6                 0.090063           0.720366            1       True
# 7                 0.086604           0.743534            1       True
# 8                 0.039207           3.006366            2       True
# 9                 0.091158           0.994247            2       True
# 10                0.213362           6.363785            1       True
# 11                0.090875           0.755902            2       True
# 12                0.203750           6.824051            2       True
# 13                0.027428           3.266780            2       True
# 14                0.178489           4.423339            1       True
# 15                0.262969           7.020853            1       True
# 16                0.005671           0.006498            1       True
#
#     fit_order
# 0           2
# 1           9
# 2          10
# 3           6
# 4          17
# 5          14
# 6           7
# 7           5
# 8          11
# 9          13
# 10          4
# 11         15
# 12         16
# 13         12
# 14          3
# 15          8
# 16          1
#               importance    stddev   p_value  n  p99_high   p99_low
# 하위계층비율          5.694998  0.358093  0.000002  5  6.432317  4.957679
# 가구당평균방수         5.235909  0.333600  0.000002  5  5.922796  4.549023
# 직업센터접근성         1.657212  0.130382  0.000005  5  1.925670  1.388754
# 농축 일산화질소        1.089226  0.101414  0.000009  5  1.298039  0.880413
# 학생/교사비율         0.932375  0.099594  0.000015  5  1.137441  0.727309
# 1940년이전건축비율     0.876111  0.086016  0.000011  5  1.053220  0.699003
# 범죄율             0.871581  0.074228  0.000006  5  1.024418  0.718743
# 재산세율            0.843520  0.058213  0.000003  5  0.963382  0.723659
# 흑인비율            0.551335  0.112002  0.000194  5  0.781950  0.320721
# 비소매상업지역비율       0.265296  0.028726  0.000016  5  0.324442  0.206150
# 도로접근성           0.241143  0.052714  0.000257  5  0.349682  0.132603
# 찰스강경계           0.103582  0.035472  0.001421  5  0.176619  0.030545
# 25,000평방피트초과    0.080442  0.022481  0.000662  5  0.126731  0.034153
# best_model WeightedEnsemble_L3
# Best model hyperparameters:
# {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}

# %%
data = pd.read_csv("https://raw.githubusercontent.com/haram4th/ablearn/main/ratings_train.txt", sep="\t")
data.head()
# Out:
#          id                                                       document  \
# 0   9976970                                            아 더빙.. 진짜 짜증나네요 목소리
# 1   3819312                              흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나
# 2  10265843                                              너무재밓었다그래서보는것을추천한다
# 3   9045019                                  교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 던스트가 너무나도 이뻐보였다
#
#    label
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1

# %%
def auto_predict(data, target_name, eval_metric='accuracy', time_limit=300):
    target_column = target_name

    time_limit = time_limit  # for quick demonstration only, you should set this to longest time you are willing to wait (in seconds)
    metric = 'accuracy'  # specify your evaluation metric here

    model = TabularPredictor(label=target_column, eval_metric=metric)
    model.fit(data, time_limit=time_limit, presets='best_quality' )
    test_data = data.sample(frac=0.3, random_state=10)

    pred = model.predict(test_data)

    result = model.evaluate(test_data)
    result_df = pd.DataFrame(result)
    leader_board = model.leaderboard(test_data)
    feature_importance = model.feature_importance(test_data)
    best_model_name = model.model_best
    best_model = model._trainer.load_model(best_model_name)  # Load the best model
    best_model_params = best_model.params


    display(result_df)
    print()
    display(leader_board)
    print()
    display(feature_importance)
    print("best_model",best_model_name)
    print("Best model hyperparameters:")
    print(best_model_params)

# %%
data = pd.read_csv("../06machine_learning/data/house_train.csv")
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
auto_predict(data, 'SalePrice', eval_metric='root_mean_squared_error', time_limit=600)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20241016_084036"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.15
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Fri Mar 29 23:14:13 UTC 2024
# CPU Count:          8
# Memory Avail:       9.14 GB / 14.61 GB (62.6%)
# Disk Space Avail:   24.51 GB / 223.03 GB (11.0%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 150s of the 600s of remaining time (25%).
# 		Context path: "AutogluonModels/ag-20241016_084036/ds_sub_fit/sub_fit_ho"
# 2024-10-16 17:40:40,374	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=75681, ip=172.17.7.15)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 405, in _ray_fit
#     fold_model, pred_proba = _ray_predict_oof(
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 422, in _ray_predict_oof
#     fold_model.val_score = fold_model.score_with_y_pred_proba(y=y_val_fold, y_pred_proba=y_pred_proba)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1063, in score_with_y_pred_proba
#     return compute_weighted_metric(y, y_pred, metric, sample_weight, quantile_levels=self.quantile_levels)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/utils/utils.py", line 673, in compute_weighted_metric
#     return metric(y, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 96, in __call__
#     return self._score(y_true=y_true, y_pred=y_pred, **k)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 134, in _score
#     return self._sign * self._score_func(y_true, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 213, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# 2024-10-16 17:40:51,381	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=75679, ip=172.17.7.15)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 405, in _ray_fit
#     fold_model, pred_proba = _ray_predict_oof(
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 422, in _ray_predict_oof
#     fold_model.val_score = fold_model.score_with_y_pred_proba(y=y_val_fold, y_pred_proba=y_pred_proba)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1063, in score_with_y_pred_proba
#     return compute_weighted_metric(y, y_pred, metric, sample_weight, quantile_levels=self.quantile_levels)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/utils/utils.py", line 673, in compute_weighted_metric
#     return metric(y, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 96, in __call__
#     return self._score(y_true=y_true, y_pred=y_pred, **k)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 134, in _score
#     return self._sign * self._score_func(y_true, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 213, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# 2024-10-16 17:40:56,384	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=75675, ip=172.17.7.15)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 405, in _ray_fit
#     fold_model, pred_proba = _ray_predict_oof(
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 422, in _ray_predict_oof
#     fold_model.val_score = fold_model.score_with_y_pred_proba(y=y_val_fold, y_pred_proba=y_pred_proba)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1063, in score_with_y_pred_proba
#     return compute_weighted_metric(y, y_pred, metric, sample_weight, quantile_levels=self.quantile_levels)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/utils/utils.py", line 673, in compute_weighted_metric
#     return metric(y, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 96, in __call__
#     return self._score(y_true=y_true, y_pred=y_pred, **k)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 134, in _score
#     return self._sign * self._score_func(y_true, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 213, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# 2024-10-16 17:41:07,392	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=75677, ip=172.17.7.15)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 405, in _ray_fit
#     fold_model, pred_proba = _ray_predict_oof(
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 422, in _ray_predict_oof
#     fold_model.val_score = fold_model.score_with_y_pred_proba(y=y_val_fold, y_pred_proba=y_pred_proba)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1063, in score_with_y_pred_proba
#     return compute_weighted_metric(y, y_pred, metric, sample_weight, quantile_levels=self.quantile_levels)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/utils/utils.py", line 673, in compute_weighted_metric
#     return metric(y, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 96, in __call__
#     return self._score(y_true=y_true, y_pred=y_pred, **k)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 134, in _score
#     return self._sign * self._score_func(y_true, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 213, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# 2024-10-16 17:41:13,395	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=75678, ip=172.17.7.15)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 405, in _ray_fit
#     fold_model, pred_proba = _ray_predict_oof(
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 422, in _ray_predict_oof
#     fold_model.val_score = fold_model.score_with_y_pred_proba(y=y_val_fold, y_pred_proba=y_pred_proba)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1063, in score_with_y_pred_proba
#     return compute_weighted_metric(y, y_pred, metric, sample_weight, quantile_levels=self.quantile_levels)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/utils/utils.py", line 673, in compute_weighted_metric
#     return metric(y, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 96, in __call__
#     return self._score(y_true=y_true, y_pred=y_pred, **k)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 134, in _score
#     return self._sign * self._score_func(y_true, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 213, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# 2024-10-16 17:41:23,400	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=75676, ip=172.17.7.15)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 405, in _ray_fit
#     fold_model, pred_proba = _ray_predict_oof(
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 422, in _ray_predict_oof
#     fold_model.val_score = fold_model.score_with_y_pred_proba(y=y_val_fold, y_pred_proba=y_pred_proba)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1063, in score_with_y_pred_proba
#     return compute_weighted_metric(y, y_pred, metric, sample_weight, quantile_levels=self.quantile_levels)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/utils/utils.py", line 673, in compute_weighted_metric
#     return metric(y, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 96, in __call__
#     return self._score(y_true=y_true, y_pred=y_pred, **k)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 134, in _score
#     return self._sign * self._score_func(y_true, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 213, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# 2024-10-16 17:41:23,404	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=75673, ip=172.17.7.15)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 405, in _ray_fit
#     fold_model, pred_proba = _ray_predict_oof(
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 422, in _ray_predict_oof
#     fold_model.val_score = fold_model.score_with_y_pred_proba(y=y_val_fold, y_pred_proba=y_pred_proba)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1063, in score_with_y_pred_proba
#     return compute_weighted_metric(y, y_pred, metric, sample_weight, quantile_levels=self.quantile_levels)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/utils/utils.py", line 673, in compute_weighted_metric
#     return metric(y, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 96, in __call__
#     return self._score(y_true=y_true, y_pred=y_pred, **k)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 134, in _score
#     return self._sign * self._score_func(y_true, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 213, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	149s	 = DyStack   runtime |	451s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 451s
# AutoGluon will save models to "AutogluonModels/ag-20241016_084036"
# Train Data Rows:    1460
# Train Data Columns: 80
# Label Column:       SalePrice
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    10347.70 MB
# 	Train Data (Original)  Memory Usage: 3.85 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  :  3 | ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
# 		('int', [])    : 34 | ['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', ...]
# 		('object', []) : 43 | ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 40 | ['MSZoning', 'Alley', 'LotShape', 'LandContour', 'LotConfig', ...]
# 		('float', [])     :  3 | ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
# 		('int', [])       : 34 | ['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', ...]
# 		('int', ['bool']) :  3 | ['Street', 'Utilities', 'CentralAir']
# 	0.5s = Fit runtime
# 	80 features in original data used to generate 80 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.49 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.57s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 300.35s of the 450.62s of remaining time.
# 	Warning: Exception caused KNeighborsUnif_BAG_L1 to fail during training... Skipping this model.
# 		Classification metrics can't handle a mix of multiclass and continuous targets
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1904, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1844, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 165, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 263, in _fit
#     self._fit_single(
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 542, in _fit_single
#     model_base.val_score = model_base.score_with_y_pred_proba(y=y, y_pred_proba=self._oof_pred_proba)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1063, in score_with_y_pred_proba
#     return compute_weighted_metric(y, y_pred, metric, sample_weight, quantile_levels=self.quantile_levels)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/utils/utils.py", line 673, in compute_weighted_metric
#     return metric(y, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 96, in __call__
#     return self._score(y_true=y_true, y_pred=y_pred, **k)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 134, in _score
#     return self._sign * self._score_func(y_true, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 213, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 299.92s of the 450.19s of remaining time.
# 	Warning: Exception caused KNeighborsDist_BAG_L1 to fail during training... Skipping this model.
# 		Classification metrics can't handle a mix of multiclass and continuous targets
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1904, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1844, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 165, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 263, in _fit
#     self._fit_single(
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 542, in _fit_single
#     model_base.val_score = model_base.score_with_y_pred_proba(y=y, y_pred_proba=self._oof_pred_proba)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1063, in score_with_y_pred_proba
#     return compute_weighted_metric(y, y_pred, metric, sample_weight, quantile_levels=self.quantile_levels)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/utils/utils.py", line 673, in compute_weighted_metric
#     return metric(y, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 96, in __call__
#     return self._score(y_true=y_true, y_pred=y_pred, **k)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 134, in _score
#     return self._sign * self._score_func(y_true, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 213, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 299.53s of the 449.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# 	Warning: Exception caused LightGBMXT_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=79382, ip=172.17.7.15)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 218, in _fit
#     self.model = train_lgb_model(early_stopping_callback_kwargs=early_stopping_callback_kwargs, **train_params)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 128, in train_lgb_model
#     return lgb.train(**train_params)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/lightgbm/engine.py", line 283, in train
#     evaluation_result_list.extend(booster.eval_valid(feval))
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/lightgbm/basic.py", line 4159, in eval_valid
#     return [item for i in range(1, self.__num_dataset)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/lightgbm/basic.py", line 4160, in <listcomp>
#     for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)]
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/lightgbm/basic.py", line 4868, in __inner_eval
#     feval_ret = eval_function(self.__inner_predict(data_idx), cur_data)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 45, in function_template
#     return metric.name, metric(y_true, y_hat), is_higher_better
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 96, in __call__
#     return self._score(y_true=y_true, y_pred=y_pred, **k)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 134, in _score
#     return self._sign * self._score_func(y_true, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 213, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1904, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1844, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 165, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 288, in _fit
#     self._fit_folds(
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 714, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 668, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 610, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 572, in _process_fold_results
#     raise processed_exception
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 537, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size = self.ray.get(finished)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/ray/_private/worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::_ray_fit() (pid=79382, ip=172.17.7.15)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 218, in _fit
#     self.model = train_lgb_model(early_stopping_callback_kwargs=early_stopping_callback_kwargs, **train_params)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 128, in train_lgb_model
#     return lgb.train(**train_params)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/lightgbm/engine.py", line 283, in train
#     evaluation_result_list.extend(booster.eval_valid(feval))
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/lightgbm/basic.py", line 4159, in eval_valid
#     return [item for i in range(1, self.__num_dataset)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/lightgbm/basic.py", line 4160, in <listcomp>
#     for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)]
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/lightgbm/basic.py", line 4868, in __inner_eval
#     feval_ret = eval_function(self.__inner_predict(data_idx), cur_data)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 45, in function_template
#     return metric.name, metric(y_true, y_hat), is_higher_better
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 96, in __call__
#     return self._score(y_true=y_true, y_pred=y_pred, **k)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 134, in _score
#     return self._sign * self._score_func(y_true, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 213, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 292.93s of the 443.2s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# 2024-10-16 17:43:18,505	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:43:18,508	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:43:18,511	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:43:18,515	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:43:18,519	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:43:18,521	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:43:18,523	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	Warning: Exception caused LightGBM_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=79722, ip=172.17.7.15)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 218, in _fit
#     self.model = train_lgb_model(early_stopping_callback_kwargs=early_stopping_callback_kwargs, **train_params)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 128, in train_lgb_model
#     return lgb.train(**train_params)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/lightgbm/engine.py", line 283, in train
#     evaluation_result_list.extend(booster.eval_valid(feval))
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/lightgbm/basic.py", line 4159, in eval_valid
#     return [item for i in range(1, self.__num_dataset)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/lightgbm/basic.py", line 4160, in <listcomp>
#     for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)]
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/lightgbm/basic.py", line 4868, in __inner_eval
#     feval_ret = eval_function(self.__inner_predict(data_idx), cur_data)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 45, in function_template
#     return metric.name, metric(y_true, y_hat), is_higher_better
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 96, in __call__
#     return self._score(y_true=y_true, y_pred=y_pred, **k)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 134, in _score
#     return self._sign * self._score_func(y_true, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 213, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1904, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1844, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 165, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 288, in _fit
#     self._fit_folds(
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 714, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 668, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 610, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 572, in _process_fold_results
#     raise processed_exception
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 537, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size = self.ray.get(finished)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/ray/_private/worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::_ray_fit() (pid=79722, ip=172.17.7.15)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 218, in _fit
#     self.model = train_lgb_model(early_stopping_callback_kwargs=early_stopping_callback_kwargs, **train_params)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 128, in train_lgb_model
#     return lgb.train(**train_params)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/lightgbm/engine.py", line 283, in train
#     evaluation_result_list.extend(booster.eval_valid(feval))
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/lightgbm/basic.py", line 4159, in eval_valid
#     return [item for i in range(1, self.__num_dataset)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/lightgbm/basic.py", line 4160, in <listcomp>
#     for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)]
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/lightgbm/basic.py", line 4868, in __inner_eval
#     feval_ret = eval_function(self.__inner_predict(data_idx), cur_data)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 45, in function_template
#     return metric.name, metric(y_true, y_hat), is_higher_better
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 96, in __call__
#     return self._score(y_true=y_true, y_pred=y_pred, **k)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 134, in _score
#     return self._sign * self._score_func(y_true, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 213, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 286.49s of the 436.76s of remaining time.
# 	Warning: Exception caused RandomForestMSE_BAG_L1 to fail during training... Skipping this model.
# 		Classification metrics can't handle a mix of multiclass and continuous targets
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1904, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1844, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 165, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 263, in _fit
#     self._fit_single(
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 542, in _fit_single
#     model_base.val_score = model_base.score_with_y_pred_proba(y=y, y_pred_proba=self._oof_pred_proba)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1063, in score_with_y_pred_proba
# ...
#     fold_model.val_score = fold_model.score_with_y_pred_proba(y=y_val_fold, y_pred_proba=y_pred_proba)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1063, in score_with_y_pred_proba
#     return compute_weighted_metric(y, y_pred, metric, sample_weight, quantile_levels=self.quantile_levels)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/utils/utils.py", line 673, in compute_weighted_metric
#     return metric(y, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 96, in __call__
#     return self._score(y_true=y_true, y_pred=y_pred, **k)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 134, in _score
#     return self._sign * self._score_func(y_true, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 213, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 36.11s of the 186.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# 2024-10-16 17:47:34,746	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:47:34,750	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:47:34,752	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:47:34,754	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:47:34,756	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:47:34,760	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:47:34,762	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	Warning: Exception caused NeuralNetFastAI_r102_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=85734, ip=172.17.7.15)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 405, in _ray_fit
#     fold_model, pred_proba = _ray_predict_oof(
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 422, in _ray_predict_oof
#     fold_model.val_score = fold_model.score_with_y_pred_proba(y=y_val_fold, y_pred_proba=y_pred_proba)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1063, in score_with_y_pred_proba
#     return compute_weighted_metric(y, y_pred, metric, sample_weight, quantile_levels=self.quantile_levels)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/utils/utils.py", line 673, in compute_weighted_metric
#     return metric(y, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 96, in __call__
#     return self._score(y_true=y_true, y_pred=y_pred, **k)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 134, in _score
#     return self._sign * self._score_func(y_true, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 213, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1904, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1844, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 165, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 288, in _fit
#     self._fit_folds(
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 714, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 668, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 610, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 572, in _process_fold_results
#     raise processed_exception
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 537, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size = self.ray.get(finished)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/ray/_private/worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::_ray_fit() (pid=85734, ip=172.17.7.15)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 405, in _ray_fit
#     fold_model, pred_proba = _ray_predict_oof(
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 422, in _ray_predict_oof
#     fold_model.val_score = fold_model.score_with_y_pred_proba(y=y_val_fold, y_pred_proba=y_pred_proba)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1063, in score_with_y_pred_proba
#     return compute_weighted_metric(y, y_pred, metric, sample_weight, quantile_levels=self.quantile_levels)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/utils/utils.py", line 673, in compute_weighted_metric
#     return metric(y, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 96, in __call__
#     return self._score(y_true=y_true, y_pred=y_pred, **k)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/metrics/__init__.py", line 134, in _score
#     return self._sign * self._score_func(y_true, y_pred, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 213, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/user/miniforge3/envs/ag/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# No base models to train on, skipping auxiliary stack level 2...
# No base models to train on, skipping stack level 2...
# No base models to train on, skipping auxiliary stack level 3...
# Warning: AutoGluon did not successfully train any models
# AutoGluon training complete, total runtime = 304.5s ... Best model: None
# Warning: No models found, skipping post_fit logic...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20241016_084036")
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 auto_predict(data, 'SalePrice', eval_metric='root_mean_squared_error', time_limit=600)
#
# Cell In[65], line 11, in auto_predict(data, target_name, eval_metric, time_limit)
#       8 model.fit(data, time_limit=time_limit, presets='best_quality' )
#       9 test_data = data.sample(frac=0.3, random_state=10)
# ---> 11 pred = model.predict(test_data)
#      13 result = model.evaluate(test_data)
#      14 result_df = pd.DataFrame(result)
#
# File ~/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/predictor/predictor.py:2117, in TabularPredictor.predict(self, data, model, as_pandas, transform_features, decision_threshold)
#    2115 if decision_threshold is None:
#    2116     decision_threshold = self.decision_threshold
# -> 2117 return self._learner.predict(X=data, model=model, as_pandas=as_pandas, transform_features=transform_features, decision_threshold=decision_threshold)
#
# File ~/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/learner/abstract_learner.py:208, in AbstractTabularLearner.predict(self, X, model, as_pandas, inverse_transform, transform_features, decision_threshold)
#     206     decision_threshold = 0.5
#     207 X_index = copy.deepcopy(X.index) if as_pandas else None
# --> 208 y_pred_proba = self.predict_proba(
#     209     X=X, model=model, as_pandas=False, as_multiclass=False, inverse_transform=False, transform_features=transform_features
#     210 )
#     211 problem_type = self.label_cleaner.problem_type_transform or self.problem_type
#     212 y_pred = get_pred_from_proba(y_pred_proba=y_pred_proba, problem_type=problem_type, decision_threshold=decision_threshold)
#
# File ~/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/learner/abstract_learner.py:189, in AbstractTabularLearner.predict_proba(self, X, model, as_pandas, as_multiclass, inverse_transform, transform_features)
#     187     if transform_features:
#     188         X = self.transform_features(X)
# --> 189     y_pred_proba = self.load_trainer().predict_proba(X, model=model)
#     190 y_pred_proba = self._post_process_predict_proba(
#     191     y_pred_proba=y_pred_proba, as_pandas=as_pandas, index=X_index, as_multiclass=as_multiclass, inverse_transform=inverse_transform
#     192 )
#     193 return y_pred_proba
#
# File ~/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:835, in AbstractTrainer.predict_proba(self, X, model)
#     833 def predict_proba(self, X, model=None):
#     834     if model is None:
# --> 835         model = self._get_best()
#     836     cascade = isinstance(model, list)
#     837     return self._predict_proba_model(X, model, cascade=cascade)
#
# File ~/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:843, in AbstractTrainer._get_best(self)
#     841     return self.model_best
#     842 else:
# --> 843     return self.get_model_best()
#
# File ~/miniforge3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:1517, in AbstractTrainer.get_model_best(self, can_infer, allow_full, infer_limit, infer_limit_as_child)
#    1515 models = self.get_model_names(can_infer=can_infer)
#    1516 if not models:
# -> 1517     raise AssertionError("Trainer has no fit models that can infer.")
#    1518 models_full = self.get_models_attribute_dict(models=models, attribute="refit_full_parent")
#    1519 if not allow_full:
#
# AssertionError: Trainer has no fit models that can infer.
# 2024-10-16 17:48:13,771	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:48:13,773	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:48:13,775	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:48:13,777	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:48:13,779	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:48:13,782	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-16 17:48:13,785	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
