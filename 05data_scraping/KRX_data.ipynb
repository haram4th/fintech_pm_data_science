# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
url = "https://kind.krx.co.kr/corpgeneral/corpList.do"
payload = dict(method='searchCorpList',pageIndex=2,currentPageSize=15,orderMode=3,orderStat='D',searchType=13,fiscalYearEnd='all',location='all')
r = requests.get(url, params=payload)
print(r.url)
print(r.status_code)
soup = bs(r.text, 'html.parser')
soup
# Out:
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=2&currentPageSize=15&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# C:\Users\HSM\anaconda3\envs\mdai\Lib\site-packages\bs4\builder\__init__.py:314: RuntimeWarning: coroutine 'get_html' was never awaited
#   for attr in list(attrs.keys()):
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# <section class="scrarea type-00">
# <table class="list type-00 tmt30" summary="회사명, 업종, 주요제품, 상장일, 결산월, 대표자명, 홈페이지, 지역">
# <caption>목록</caption>
# <colgroup>
# <col width="*"/>
# <col width="15%"/>
# <col width="20%"/>
# <col width="11%"/>
# <col width="8%"/>
# <col width="10%"/>
# <col width="8%"/>
# <col width="12%"/>
# </colgroup>
# <thead>
# <tr class="first" id="title-contents">
# </tr>
# </thead>
# <tbody>
# <tr class="first">
# <td class="first" title="케이비제29호기업인수목적(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47839'); return false;" title="KB제29호스팩"> KB제29호스팩</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수합병">기업인수합병</td>
# <td class="txc">2024-06-21</td>
# <td class="txc">12월</td>
# <td class="txc" title="서영화">서영화</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="미래에셋비전기업인수목적5호 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47747'); return false;" title="미래에셋비전스팩5호"> 미래에셋비전스팩5호</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수합병">기업인수합병</td>
# <td class="txc">2024-06-19</td>
# <td class="txc">12월</td>
# <td class="txc" title="김대호">김대호</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)씨어스테크놀로지"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('45887'); return false;" title="씨어스테크놀로지"> 씨어스테크놀로지</a> </td>
# <td class="textOverflow" title="의료용 기기 제조업">의료용 기기 제조업</td>
# <td class="textOverflow" title="심전도검사솔루션 입원환자모니터링솔루션">심전도검사솔루션 입원환자모니터링솔루션</td>
# <td class="txc">2024-06-19</td>
# <td class="txc">12월</td>
# <td class="txc" title="이영신">이영신</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://seerstech.com" target="_blank" title="http://seerstech.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# <td class="first" title="한국제14호기업인수목적 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47753'); return false;" title="한국제14호스팩"> 한국제14호스팩</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수합병">기업인수합병</td>
# <td class="txc">2024-06-19</td>
# <td class="txc">12월</td>
# <td class="txc" title="변성환">변성환</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="디비금융제12호기업인수목적 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47776'); return false;" title="디비금융스팩12호"> 디비금융스팩12호</a> </td>
# <td class="textOverflow" title="기타 금융업">기타 금융업</td>
# <td class="textOverflow" title="기업인수 및 합병">기업인수 및 합병</td>
# <td class="txc">2024-06-18</td>
# <td class="txc">12월</td>
# <td class="txc" title="김창희">김창희</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)라메디텍"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('46251'); return false;" title="라메디텍"> 라메디텍</a> </td>
# <td class="textOverflow" title="의료용 기기 제조업">의료용 기기 제조업</td>
# <td class="textOverflow" title="초소형 레이저 의료기기  및 미용기기">초소형 레이저 의료기기  및 미용기기</td>
# <td class="txc">2024-06-17</td>
# <td class="txc">12월</td>
# <td class="txc" title="최종석">최종석</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)그리드위즈"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('45345'); return false;" title="그리드위즈"> 그리드위즈</a> </td>
# <td class="textOverflow" title="그외 기타 전문, 과학 및 기술 서비스업">그외 기타 전문, 과학 및 기술 서비스업</td>
# <td class="textOverflow" title="수요관리 서비스, 전기차 충전기 모뎀 등">수요관리 서비스, 전기차 충전기 모뎀 등</td>
# <td class="txc">2024-06-14</td>
# <td class="txc">12월</td>
# <td class="txc" title="김구환">김구환</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.gridwiz.com" target="_blank" title="http://www.gridwiz.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# <td class="first" title="(주)다원넥스뷰"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('32335'); return false;" title="다원넥스뷰"> 다원넥스뷰</a> </td>
# <td class="textOverflow" title="사진장비 및 광학기기 제조업">사진장비 및 광학기기 제조업</td>
# <td class="textOverflow" title="LSMB(Laser Micro Bonding System)">LSMB(Laser Micro Bonding System)</td>
# <td class="txc">2024-06-11</td>
# <td class="txc">12월</td>
# <td class="txc" title="남기중">남기중</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.nexview.co.kr" target="_blank" title="http://www.nexview.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# <td class="first" title="미래에셋비전기업인수목적4호 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47738'); return false;" title="미래에셋비전스팩4호"> 미래에셋비전스팩4호</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수목적회사(기타금융서비스)">기업인수목적회사(기타금융서비스)</td>
# <td class="txc">2024-05-29</td>
# <td class="txc">12월</td>
# <td class="txc" title="김정수">김정수</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)노브랜드"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('14517'); return false;" title="노브랜드"> 노브랜드</a> </td>
# <td class="textOverflow" title="편조의복 제조업">편조의복 제조업</td>
# <td class="textOverflow" title="Knit, Woven 의류">Knit, Woven 의류</td>
# <td class="txc">2024-05-23</td>
# <td class="txc">12월</td>
# <td class="txc" title="이상규">이상규</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.nobland.com" target="_blank" title="http://www.nobland.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="케이비제28호기업인수목적 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47647'); return false;" title="KB제28호스팩"> KB제28호스팩</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수합병">기업인수합병</td>
# <td class="txc">2024-05-17</td>
# <td class="txc">12월</td>
# <td class="txc" title="고광범">고광범</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="아이씨티케이 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('45601'); return false;" title="아이씨티케이"> 아이씨티케이</a> </td>
# <td class="textOverflow" title="반도체 제조업">반도체 제조업</td>
# <td class="textOverflow" title="PUF반도체,보안솔루션(보안반도체,정보통신모듈기기,정보통신용반도체) 제조,개발">PUF반도체,보안솔루션(보안반도체,정보통신모듈기기,정보통신용반도체) 제조,개발</td>
# <td class="txc">2024-05-17</td>
# <td class="txc">12월</td>
# <td class="txc" title="이정원">이정원</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.ictk.com" target="_blank" title="http://www.ictk.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="에이치디현대마린솔루션(주)"><img alt="유가증권" class="vmiddle legend" src="/images/common/icn_t_yu.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('44306'); return false;" title="HD현대마린솔루션"> HD현대마린솔루션</a> </td>
# <td class="textOverflow" title="건축기술, 엔지니어링 및 관련 기술 서비스업">건축기술, 엔지니어링 및 관련 기술 서비스업</td>
# <td class="textOverflow" title="AM(After Market) 솔루션, 친환경 Retrofit, 디지털 제어">AM(After Market) 솔루션, 친환경 Retrofit, 디지털 제어</td>
# <td class="txc">2024-05-08</td>
# <td class="txc">12월</td>
# <td class="txc" title="이기동">이기동</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.hd-marinesolution.com/" target="_blank" title="http://www.hd-marinesolution.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">부산광역시</td>
# </tr>
# <tr>
# <td class="first" title="에스케이증권제12호기업인수목적 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47300'); return false;" title="SK증권제12호스팩"> SK증권제12호스팩</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수목적 주식회사">기업인수목적 주식회사</td>
# <td class="txc">2024-05-07</td>
# <td class="txc">12월</td>
# <td class="txc" title="이재혁">이재혁</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="코칩(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('12673'); return false;" title="코칩"> 코칩</a> </td>
# <td class="textOverflow" title="전자부품 제조업">전자부품 제조업</td>
# <td class="textOverflow" title="소형 및 초소형 슈퍼커패시터">소형 및 초소형 슈퍼커패시터</td>
# <td class="txc">2024-05-07</td>
# <td class="txc">12월</td>
# <td class="txc" title="손진형">손진형</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.korchip.com" target="_blank" title="http://www.korchip.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# </tbody>
# </table>
# </section>
# <!-- 페이징 START -->
# <section class="paging-group">
# <div class="paging type-00"><a class="pprev" href="#prevPage10" onclick="return false;"><span>이전10개 페이지</span></a><a class="prev" href="#prevPage" onclick="fnPageGo('1');return false;"><span>이전 페이지</span></a><a href="#page_link_1" onclick="fnPageGo('1');return false;">1</a><a class="active" href="#page_link_2" onclick="return false;">2</a><a href="#page_link_3" onclick="fnPageGo('3');return false;">3</a><a href="#page_link_4" onclick="fnPageGo('4');return false;">4</a><a href="#page_link_5" onclick="fnPageGo('5');return false;">5</a><a href="#page_link_6" onclick="fnPageGo('6');return false;">6</a><a href="#page_link_7" onclick="fnPageGo('7');return false;">7</a><a href="#page_link_8" onclick="fnPageGo('8');return false;">8</a><a href="#page_link_9" onclick="fnPageGo('9');return false;">9</a><a href="#page_link_10" onclick="fnPageGo('10');return false;">10</a>
# <a class="next" href="#nextPage" onclick="fnPageGo('3');return false;"><span>다음 페이지</span></a><a class="nnext" href="#nextPage10" onclick="fnPageGo('12');return false;"><span>다음10개 페이지</span></a></div><div class="info type-00">
# 전체 <em>2,704</em>건 : <strong>2</strong>/181
# <select id="currentPageSize" name="currentPageSize">
# <option selected="selected" value="15">15건</option>
# <option value="30">30건</option>
# <option value="50">50건</option>
# <option value="100">100건</option>
# </select>  <a class="btn-sprite btn-go vmiddle" href="#" onclick="fnSearch1();return false;" title="GO"><span>GO</span></a>
# </div>
# </section>
# <!-- 페이징 END -->
# <script type="text/JavaScript">
# $(document).ready(function(){
# 	fn_InitTitle("회사명,업종,주요제품,상장일,결산월,대표자명,홈페이지,지역", "true,false,false,true,false,false,false,false");
# });
# </script>

# %%
# Out:
# <section class="scrarea type-00">
# <table class="list type-00 tmt30" summary="회사명, 업종, 주요제품, 상장일, 결산월, 대표자명, 홈페이지, 지역">
# <caption>목록</caption>
# <colgroup>
# <col width="*"/>
# <col width="15%"/>
# <col width="20%"/>
# <col width="11%"/>
# <col width="8%"/>
# <col width="10%"/>
# <col width="8%"/>
# <col width="12%"/>
# </colgroup>
# <thead>
# <tr class="first" id="title-contents">
# </tr>
# </thead>
# <tbody>
# <tr class="first">
# <td class="first" title="(주)엑셀세라퓨틱스"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('37311'); return false;" title="엑셀세라퓨틱스"> 엑셀세라퓨틱스</a> </td>
# <td class="textOverflow" title="기초 의약물질 제조업">기초 의약물질 제조업</td>
# <td class="textOverflow" title="CellCor SFD/CD(세포배양배지)">CellCor SFD/CD(세포배양배지)</td>
# <td class="txc">2024-07-15</td>
# <td class="txc">12월</td>
# <td class="txc" title="이의일">이의일</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="이베스트기업인수목적6호 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47811'); return false;" title="이베스트스팩6호"> 이베스트스팩6호</a> <img alt="투자주의종목" class="vmiddle legend" src="/images/common/icn_t_joo.gif"> </img></td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수목적 주식회사">기업인수목적 주식회사</td>
# <td class="txc">2024-07-12</td>
# <td class="txc">12월</td>
# <td class="txc" title="박용">박용</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)시프트업"><img alt="유가증권" class="vmiddle legend" src="/images/common/icn_t_yu.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('46287'); return false;" title="시프트업"> 시프트업</a> </td>
# <td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# <td class="textOverflow" title="게임 소프트웨어">게임 소프트웨어</td>
# <td class="txc">2024-07-11</td>
# <td class="txc">12월</td>
# <td class="txc" title="김형태">김형태</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://shiftup.co.kr" target="_blank" title="http://shiftup.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)하스"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('45033'); return false;" title="하스"> 하스</a> </td>
# <td class="textOverflow" title="의료용품 및 기타 의약 관련제품 제조업">의료용품 및 기타 의약 관련제품 제조업</td>
# <td class="textOverflow" title="리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관">리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관</td>
# <td class="txc">2024-07-03</td>
# <td class="txc">12월</td>
# <td class="txc" title="김용수">김용수</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.hassbio.com" target="_blank" title="http://www.hassbio.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">강원특별자치도</td>
# </tr>
# <tr>
# <td class="first" title="(주)이노스페이스"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('46235'); return false;" title="이노스페이스"> 이노스페이스</a> </td>
# <td class="textOverflow" title="항공기,우주선 및 부품 제조업">항공기,우주선 및 부품 제조업</td>
# <td class="textOverflow" title="소형발사체, 로켓추진기관, 과학로켓, 시험평가용역">소형발사체, 로켓추진기관, 과학로켓, 시험평가용역</td>
# <td class="txc">2024-07-02</td>
# <td class="txc">12월</td>
# <td class="txc" title="김수종">김수종</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.innospc.com/" target="_blank" title="http://www.innospc.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">세종특별자치시</td>
# </tr>
# <tr>
# <td class="first" title="(주)신한글로벌액티브위탁관리부동산투자회사"><img alt="유가증권" class="vmiddle legend" src="/images/common/icn_t_yu.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('48185'); return false;" title="신한글로벌액티브리츠"> 신한글로벌액티브리츠</a> </td>
# <td class="textOverflow" title="신탁업 및 집합투자업">신탁업 및 집합투자업</td>
# <td class="textOverflow" title="신탁 및 집합투자">신탁 및 집합투자</td>
# <td class="txc">2024-07-01</td>
# <td class="txc">02월</td>
# <td class="txc" title="김선영">김선영</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://shglobalreit.com" target="_blank" title="http://shglobalreit.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)에이치브이엠"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('29531'); return false;" title="에이치브이엠"> 에이치브이엠</a> </td>
# <td class="textOverflow" title="1차 비철금속 제조업">1차 비철금속 제조업</td>
# <td class="textOverflow" title="Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등">Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등</td>
# <td class="txc">2024-06-28</td>
# <td class="txc">12월</td>
# <td class="txc" title="문승호">문승호</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://hvm.co.kr/" target="_blank" title="http://hvm.co.kr/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# <td class="first" title="(주)팡스카이"><img alt="코넥스" class="vmiddle legend" src="/images/common/icn_t_konex.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('26635'); return false;" title="팡스카이"> 팡스카이</a> </td>
# <td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# <td class="textOverflow" title="게임 개발 및 리퍼블리싱">게임 개발 및 리퍼블리싱</td>
# <td class="txc">2024-06-28</td>
# <td class="txc">12월</td>
# <td class="txc" title="조호현, 이병진">조호현..</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.panggame.com/" target="_blank" title="http://www.panggame.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="하이젠알앤엠 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('16019'); return false;" title="하이젠알앤엠"> 하이젠알앤엠</a> </td>
# <td class="textOverflow" title="전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업">전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업</td>
# <td class="textOverflow" title="전동기 및 발전기 (범용모터, 서보모터)">전동기 및 발전기 (범용모터, 서보모터)</td>
# <td class="txc">2024-06-27</td>
# <td class="txc">12월</td>
# <td class="txc" title="김재학">김재학</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://higenrnm.com" target="_blank" title="http://higenrnm.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경상남도</td>
# </tr>
# <tr>
# <td class="first" title="한국제15호기업인수목적 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47988'); return false;" title="한국제15호스팩"> 한국제15호스팩</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수합병">기업인수합병</td>
# <td class="txc">2024-06-26</td>
# <td class="txc">12월</td>
# <td class="txc" title="유한">유한</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)에스오에스랩"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('46408'); return false;" title="에스오에스랩"> 에스오에스랩</a> </td>
# <td class="textOverflow" title="측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외">측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외</td>
# <td class="textOverflow" title="산업용 및 차량용 라이다(LiDAR)">산업용 및 차량용 라이다(LiDAR)</td>
# <td class="txc">2024-06-25</td>
# <td class="txc">12월</td>
# <td class="txc" title="정지성">정지성</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://soslab.co" target="_blank" title="http://soslab.co"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">광주광역시</td>
# </tr>
# <tr>
# <td class="first" title="미래에셋비전기업인수목적6호 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47844'); return false;" title="미래에셋비전스팩6호"> 미래에셋비전스팩6호</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수합병">기업인수합병</td>
# <td class="txc">2024-06-24</td>
# <td class="txc">12월</td>
# <td class="txc" title="정명훈">정명훈</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="에이치엠씨아이비제7호기업인수목적(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47734'); return false;" title="에이치엠씨제7호스팩"> 에이치엠씨제7호스팩</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기타금융">기타금융</td>
# <td class="txc">2024-06-24</td>
# <td class="txc">12월</td>
# <td class="txc" title="강신명">강신명</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)파라다이스"><img alt="유가증권" class="vmiddle legend" src="/images/common/icn_t_yu.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('03423'); return false;" title="파라다이스"> 파라다이스</a> <img alt="KRX300" class="vmiddle legend" src="/images/common/icn_t_x300.gif"/> </td>
# <td class="textOverflow" title="유원지 및 기타 오락관련 서비스업">유원지 및 기타 오락관련 서비스업</td>
# <td class="textOverflow" title="카지노, 호텔, 복합리조트">카지노, 호텔, 복합리조트</td>
# <td class="txc">2024-06-24</td>
# <td class="txc">12월</td>
# <td class="txc" title="최종환, 최성욱">최종환..</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.paradise.co.kr/ko/main" target="_blank" title="http://www.paradise.co.kr/ko/main"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)한중엔시에스"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('10764'); return false;" title="한중엔시에스"> 한중엔시에스</a> </td>
# <td class="textOverflow" title="전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업">전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업</td>
# <td class="textOverflow" title="수냉식 냉각시스템 ESS Parts, 공랭식 ESS Module Parts, EV Module 및 내연기관 Parts">수냉식 냉각시스템 ESS Parts, 공랭식 ESS Module Parts, EV Module 및 내연기관 Parts</td>
# <td class="txc">2024-06-24</td>
# <td class="txc">12월</td>
# <td class="txc" title="김환식">김환식</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.hjncs.com" target="_blank" title="http://www.hjncs.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경상북도</td>
# </tr>
# </tbody>
# </table>
# </section>
# <!-- 페이징 START -->
# <section class="paging-group">
# <div class="paging type-00"><a class="pprev" href="#prevPage10" onclick="return false;"><span>이전10개 페이지</span></a><a class="prev" href="#prevPage" onclick="return false;"><span>이전 페이지</span></a>
# <a class="active" href="#page_link_1" onclick="return false;">1</a><a href="#page_link_2" onclick="fnPageGo('2');return false;">2</a><a href="#page_link_3" onclick="fnPageGo('3');return false;">3</a><a href="#page_link_4" onclick="fnPageGo('4');return false;">4</a><a href="#page_link_5" onclick="fnPageGo('5');return false;">5</a><a href="#page_link_6" onclick="fnPageGo('6');return false;">6</a><a href="#page_link_7" onclick="fnPageGo('7');return false;">7</a><a href="#page_link_8" onclick="fnPageGo('8');return false;">8</a><a href="#page_link_9" onclick="fnPageGo('9');return false;">9</a><a href="#page_link_10" onclick="fnPageGo('10');return false;">10</a>
# <a class="next" href="#nextPage" onclick="fnPageGo('2');return false;"><span>다음 페이지</span></a><a class="nnext" href="#nextPage10" onclick="fnPageGo('11');return false;"><span>다음10개 페이지</span></a></div><div class="info type-00">
# 전체 <em>2,704</em>건 : <strong>1</strong>/181
# <select id="currentPageSize" name="currentPageSize">
# <option selected="selected" value="15">15건</option>
# <option value="30">30건</option>
# <option value="50">50건</option>
# <option value="100">100건</option>
# </select>  <a class="btn-sprite btn-go vmiddle" href="#" onclick="fnSearch1();return false;" title="GO"><span>GO</span></a>
# </div>
# </section>
# <!-- 페이징 END -->
# <script type="text/JavaScript">
# $(document).ready(function(){
# 	fn_InitTitle("회사명,업종,주요제품,상장일,결산월,대표자명,홈페이지,지역", "true,false,false,true,false,false,false,false");
# });
# </script>

# %%
print(type(r.text))
# Out:
# <class 'str'>

# %%
print(type(soup))
# Out:
# <class 'tuple'>
