# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
from datetime import date
today = date.today()
print(today)
print(type(today))
today = str(today).replace("-","")
print(today)
print(type(today))
# Out:
# 2024-07-21
# <class 'datetime.date'>
# 20240721
# <class 'str'>

# %%
url = "https://apis.data.go.kr/1160100/service/GetStockSecuritiesInfoService/getStockPriceInfo"
service_key = "8Ym5dhmVJdr12XzGnyYrQjSBS1QuRBYK8yHfx65JCl4vACM9uLKo8fxCVOFJkPB71llD7F2rOEROZnHgNGoj3A=="
params = dict(serviceKey=service_key, resultType='json')
r = requests.get(url, params=params)
print(r.status_code)
response_data = r.json()
# Out:
# 200

# %%
print(type(response_data))
# Out:
# <class 'dict'>

# %%
data = pd.json_normalize(response_data['response'].get('body', None).get('items', None).get('item', None))

# %%
data
# Out:
#       basDt  srtnCd        isinCd     itmsNm mrktCtg  clpr    vs  fltRt   mkp  \
# 0  20240718  900110  HK0000057197  이스트아시아홀딩스  KOSDAQ    85    -1  -1.16    86
# 1  20240718  900270  HK0000214814       헝셩그룹  KOSDAQ   282     6   2.17   276
# 2  20240718  900260  HK0000295359        로스웰  KOSDAQ   795    12   1.53   773
# 3  20240718  900290  HK0000307485        GRT  KOSDAQ  3195  -105  -3.18  3320
# 4  20240718  900300  HK0000312568   오가닉티코스메틱  KOSDAQ    95     2   2.15    91
# 5  20240718  900310  HK0000341732       컬러레이  KOSDAQ   695   -21  -2.93   709
# 6  20240718  900340  HK0000449303       윙입푸드  KOSDAQ  2140    30   1.42  2085
# 7  20240718  000020  KR7000020008       동화약품   KOSPI  8110   -60   -.73  8130
# 8  20240718  000040  KR7000040006      KR모터스   KOSPI   643   -12  -1.83   651
# 9  20240718  000050  KR7000050005         경방   KOSPI  7630   -20   -.26  7650
#
#    hipr  lopr      trqu       trPrc  lstgStCnt    mrktTotAmt
# ...
