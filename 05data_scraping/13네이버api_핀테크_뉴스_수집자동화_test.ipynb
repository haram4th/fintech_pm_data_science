# %%
import requests
import pandas as pd
from datetime import date
from napi_info import client_id, client_secret

# %%
client_id = client_id # 네이버 api에 접속 가능한 id 
client_secret = client_secret # 네이버 api에 접속 가능한 pw 
url = "https://openapi.naver.com/v1/search/news.json"
payload = {'query': '핀테크', 'display' : 100, 'start' : 1, 'sort': 'date'}
headers = {"X-Naver-Client-Id" : client_id, "X-Naver-Client-Secret" : client_secret}
r = requests.get(url, params=payload, headers=headers)
print(r.url)
if(r.status_code == 200):
    data = r.json()
    print(type(data))
else:
    print("Error Code:", r.status_code)
# Out:
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# <class 'dict'>

# %%
def text_clean(x):
    return x.replace("<","").replace("b", "").replace("/b", "").replace(">", "").replace("‘", "").replace("’", "")

# %%
today = date.today()
# 원하는 형식으로 변환
formatted_date = today.strftime("%d %b %Y")
print(formatted_date)  # 출력 예: 02 Aug 2024
result = {}
for item in data['items']:
    for key, info in item.items():
        if formatted_date in item['pubDate']:
            result.setdefault(key, []).append(text_clean(item[key]))
        else:
            break
# Out:
# 02 Aug 2024

# %%
df = pd.DataFrame(result)
df
# Out:
#                                              title  \
# 0           서비스 오픈 앞둔 롯데 메타버스 '칼리버스', 日 라쿠텐과 사업 협력
# 1                   우리투자증권, 그룹 효자 계열사 될까…우선과제 살펴보니
# 2                     한투파트너스, '핀테크/혁신펀드' 1호 상장 일궜다
# 3                        [금융가 이모저모] 롤 판에 등장한 'BNK'
# 4             카카오페이, 명동 소상공인과 함께하는 써머 페스타 in 명동 후원
# 5                                은행, 동남아에 K-금융 심는다
# 6                      뱅크웨어글로벌, 코스닥 상장…한국투자파트너스 투자
# 7              미쓰비시UFJ은행, 필리핀 디지털 금융 대기업에 633억엔 출자
# 8                롯데 칼리버스, 8월 글로벌 오픈 앞두고 해외시장 적극 공략
# 9                    카카오뱅크, 대학생이 가고픈 금융기업 1위→5위 추락
# 10                 인크루트, 대학생 취업선호도 금융기업 1위는 '토스뱅크'
# 11                         뱅크웨어글로벌, 공모주 마지막날 청약경쟁률
# 12           카카오페이, 명동 관광 활성화 위해 '써머 페스타 in 명동' 후원
# 13                '대출 갈아타기' 온라인 중개수수료 공시…최저는 네이버페이
# 14  [마켓인]코스닥 상장 뱅크웨어글로벌…한투파 &quot;핀테크/ 육성 결실&quot;
# 15                  국내 1000대 기업 중 전북 기업 8개…“역대 최저”
# 16                       대학생이 가장 일하고 싶은 금융기업은 토스뱅크
# 17            대학생이 가장 일하고 싶은 금융기업 2위 'KB국민'...1위는?
# 18                     티몬·위메프 사태 파장 직격탄에 핀테크/업계 울상
# 19                       인뱅 3사, 자금난 겪는 中企·소상공인 돕는다
# 20                  IT기업 혁신금융, 카카오는 리스크…아이티센·더존 직진
# 21                    뱅크웨어글로벌 공모주 청약 시작…공모가는 하단 확정
#
#                                          originallink  \
# 0   https://news.mtn.co.kr/news-detail/20240802103...
# 1       http://news.tf.co.kr/read/economy/2121538.htm
# 2   https://www.newstof.com/news/articleView.html?...
# 3   https://news.einfomax.co.kr/news/articleView.h...
# 4   http://www.segye.com/newsView/20240802508403?O...
# 5   https://www.fetv.co.kr/news/article.html?no=17...
# 6              https://dealsite.co.kr/articles/126324
# 7   http://www.g-enews.com/ko-kr/news/article/news...
# 8   http://www.edaily.co.kr/news/newspath.asp?news...
# 9   https://www.newsis.com/view/NISX20240802_00028...
# 10  https://www.thefairnews.co.kr/news/articleView...
# 11  https://www.yeongnam.com/we/view.php?key=20240...
# 12  https://www.cstimes.com/news/articleView.html?...
# 13  https://www.cstimes.com/news/articleView.html?...
# 14  http://www.edaily.co.kr/news/newspath.asp?news...
# 15  https://news.ks.co.kr/news/pc/view/view.do?ncd...
# 16  https://magazine.hankyung.com/jo-joy/article/2...
# 17  https://www.slist.kr/news/articleView.html?idx...
# 18  https://www.dailian.co.kr/news/view/1391156/?s...
# 19        https://www.sedaily.com/NewsView/2DCUYEJZ8F
# 20  https://www.dnews.co.kr/uhtml/view.jsp?idxno=2...
# 21  https://www.gukjenews.com/news/articleView.htm...
#
#                                                  link  \
# 0   https://news.mtn.co.kr/news-detail/20240802103...
# 1   https://n.news.naver.com/mnews/article/629/000...
# 2   https://www.newstof.com/news/articleView.html?...
# 3   https://news.einfomax.co.kr/news/articleView.h...
# 4   https://n.news.naver.com/mnews/article/022/000...
# 5   https://www.fetv.co.kr/news/article.html?no=17...
# 6              https://dealsite.co.kr/articles/126324
# 7   http://www.g-enews.com/ko-kr/news/article/news...
# 8   https://n.news.naver.com/mnews/article/018/000...
# 9   https://n.news.naver.com/mnews/article/003/001...
# 10  https://www.thefairnews.co.kr/news/articleView...
# 11  https://www.yeongnam.com/we/view.php?key=20240...
# 12  https://www.cstimes.com/news/articleView.html?...
# 13  https://www.cstimes.com/news/articleView.html?...
# 14  https://n.news.naver.com/mnews/article/018/000...
# 15  https://n.news.naver.com/mnews/article/056/001...
# 16  https://magazine.hankyung.com/jo-joy/article/2...
# 17  https://www.slist.kr/news/articleView.html?idx...
# 18  https://n.news.naver.com/mnews/article/119/000...
# 19  https://n.news.naver.com/mnews/article/011/000...
# 20  https://www.dnews.co.kr/uhtml/view.jsp?idxno=2...
# 21  https://www.gukjenews.com/news/articleView.htm...
#
#                                           description  \
# 0   김동규 칼리버스 대표, 고두영 롯데이노베이트 대표, 신유열 롯데지주 미래성장실장, ...
# 1   우리투자증권이 연말까지 자체 MTS를 선보인다는 계획을 내세웠지만, 토스증권 등 핀...
# 2   한국투자금융지주 계열 벤처캐피탈인 한국투자파트너스가 핀테크/혁신펀드 위탁운용사(GP...
# 3   핀테크/·플랫폼 기업이 금융의 영역으로 진입하면서 전통 은행들도 젊은 금융소비자들에...
# 4   카카오페이는 핀테크/사 중 유일하게 외국인 관광객들이 한국에 왔을 때 카카오페이 가...
# 5   웹케시글로벌은 B2B(기업과 기업 간 거래) 핀테크/ 전문기업 웹케시그룹의 글로벌 ...
# 6   회사는 한국투자파트너스가 2020년 결성한 핀테크/혁신펀드의 포트폴리오로 투자 3년...
# 7   일본 금융 대기업 미쓰비시 UFJ 은행이 2일 필리핀의 디지털 금융 서비스 대기업인...
# 8   김동규 칼리버스 대표이사, 고두영 롯데이노베이트 대표이사, 신유열 롯데지주 미래성장...
# 9   5월27일부터 7월3일까지 구직 중인 전국 대학생 962명을 대상으로 조사했으며 대...
# 10  조사 대상 기업은 시중 은행과 국책은행, 증권사, 핀테크/ 기업 등 총 58곳이다....
# 11  지난 2010년 설립된 뱅크웨어글로벌은 14년 간 축적한 코어 시스템 기술을 기반으...
# 12  카카오페이는 핀테크/사 중 유일하게 외국인 관광객들이 한국에 왔을 때 카카오페이 가...
# 13  대환대출 비교 공시 대상 플랫폼은 앞으로 자사 홈페이지에 중개수수료율과 입점한 제휴...
# 14  한국투자파트너스(한투파)가 운용 중인 핀테크/혁신펀드에서 첫 코스닥 상장 사례가 나...
# 15  지역별로는 전주 3곳, 익산 2곳, 군산, 정읍, 부안 소재 기업이 각각 한 곳입니...
# 16  조사 대상 기업은 시중 은행과 국책은행, 증권사, 핀테크/ 기업 등 총 58곳이다....
# 17  조사 대상 기업은 시중 은행과 국책은행, 증권사, 핀테크/ 기업 등 총 58곳이다....
# 18  위메프·티몬(티메프) 판매대금 정산 지연 사태로 인해 핀테크/ 업계에도 긴장감이 맴...
# 19  핀테크/ 기업 핀다의 빅데이터 상권 분석 플랫폼 오픈업에 따르면 지난해 서울시 외식...
# 20  더존비즈온은 핀테크/ 계열사인 테크핀레이팅스를 통해 지난달 신한은행, SGI서울보증...
# 21  2010년 설립된 뱅크웨어글로벌은 14년간 축적된 코어 시스템 기술을 바탕으로 코어...
#
#                             pubDate
# 0   Fri, 02 Aug 2024 11:14:00 +0900
# 1   Fri, 02 Aug 2024 11:08:00 +0900
# 2   Fri, 02 Aug 2024 11:00:00 +0900
# 3   Fri, 02 Aug 2024 10:58:00 +0900
# 4   Fri, 02 Aug 2024 10:49:00 +0900
# 5   Fri, 02 Aug 2024 10:32:00 +0900
# 6   Fri, 02 Aug 2024 10:14:00 +0900
# 7   Fri, 02 Aug 2024 09:44:00 +0900
# 8   Fri, 02 Aug 2024 09:38:00 +0900
# 9   Fri, 02 Aug 2024 09:30:00 +0900
# 10  Fri, 02 Aug 2024 09:26:00 +0900
# 11  Fri, 02 Aug 2024 08:56:00 +0900
# 12  Fri, 02 Aug 2024 08:32:00 +0900
# 13  Fri, 02 Aug 2024 08:28:00 +0900
# 14  Fri, 02 Aug 2024 08:21:00 +0900
# 15  Fri, 02 Aug 2024 07:45:00 +0900
# 16  Fri, 02 Aug 2024 07:44:00 +0900
# 17  Fri, 02 Aug 2024 07:28:00 +0900
# 18  Fri, 02 Aug 2024 06:00:00 +0900
# 19  Fri, 02 Aug 2024 05:31:00 +0900
# 20  Fri, 02 Aug 2024 05:20:00 +0900
# 21  Fri, 02 Aug 2024 00:20:00 +0900

# %%
import requests
import pandas as pd
import time
import os
from dotenv import load_dotenv

# %%
print(os.getcwd())
# Out:
# C:\fintech_service\05data_scraping

# %%
def naver_search():
    
    service = input('''검색 서비스 번호를 입력하세요:
    1 블로그
    2 책
    3 뉴스
    4 전문자료
    ''')
    query = input("검색어를 입력하세요: ")
    
    if service == '1':
        service = 'blog'
        sort='sim'
    elif service =='2':
        service = 'book'
        sort='sim'
    elif service =='3':
        service = 'news'
        sort='sim'
    elif service =='4':
        service = 'doc'
        
    
    
    book_lists = []
    page = 1
    start = 1
    load_dotenv()
    
    while True:
        client_id = os.getenv('client_id') # 네이버 api에 접속 가능한 id 
        client_secret = os.getenv('client_secret') # 네이버 api에 접속 가능한 pw 
        url = f"https://openapi.naver.com/v1/search/{service}.json"
        payload = dict(query=query, display=10, start=start, sort=sort)
        headers = {"X-Naver-Client-Id" : client_id, "X-Naver-Client-Secret" : client_secret}

        try:
            r = requests.get(url, params=payload, headers=headers)
            if(r.status_code==200):
                data = r.json()
                book_lists.append(data)
                total_page = data['total'] // 10 + 1
                if total_page > 100:
                    total_page = 100
            else:
                print("Error Code:" + rescode)
                break

            if page < total_page:
                page += 1
                if start != 991:
                    start += 10
                elif start == 991:
                    start += 9
                print(f"{page:03d}/{total_page:03d}, start: {start} 추출중", end="\r")
            else:
                break
            time.sleep(0.5)
        except Exception as e:
            print(e)
            break


    print(len(book_lists))
    result = pd.DataFrame()
    for book_list in book_lists:
        temp = pd.json_normalize(book_list['items'])
        result = pd.concat([result, temp])
    return result
#     result.to_csv(f"naver_{service}_api_fintech_{query}_result.csv", encoding="utf-8")

# %%
result = naver_search()
# Out:
# 검색 서비스 번호를 입력하세요:
#     1 블로그
#     2 책
#     3 뉴스
#     4 전문자료
#     3
# 검색어를 입력하세요: 핀테크
# 100/100, start: 991 추출중

# %%
result
# Out:
#                                                 title  \
# 0                       <b>핀테크</b>산업협회, 전자금융업자 협의회 출범
# 1                   한국<b>핀테크</b>산업협회, '전자금융업자 협의회' 출범
# 2              신한은행, 서울시 손잡고 혁신 <b>핀테크</b> 스타트업 6곳 육성
# 3            광동제약, <b>핀테크</b> 기업과 손잡고 전자증권 발행 공동사업 진행
# 4                    신한금융, 서울시와 혁신 <b>핀테크</b> 스타트업 발굴
# ..                                                ...
# 5                핀산협, JB인베스트·DEFI <b>핀테크</b> 성장 지원 맞손
# 6   &quot;<b>핀테크</b> 투자·육성&quot;...핀산협, JB인베스트먼트·디...
# 7   <b>핀테크</b>산업협회·JB인베스트먼트·DEFI, 유망 <b>핀테크</b> 발굴...
# 8        핀산협, JB인베스트먼트·DEFI와 <b>핀테크</b>스타트업 투자·육성 MOU
# 9   한국<b>핀테크</b>지원센터-카카오뱅크-전북창조경제혁신센터, '<b>핀테크</b>...
#
#                                          originallink  \
# 0   https://biz.chosun.com/stock/finance/2024/07/2...
# 1   http://www.edaily.co.kr/news/newspath.asp?news...
# 2     https://isplus.com/article/view/isp202407230170
# 3       http://news.tf.co.kr/read/economy/2118706.htm
# 4           https://www.news1.kr/finance/bank/5488024
# ..                                                ...
# 5   http://www.wowtv.co.kr/NewsCenter/News/Read?ar...
# 6       http://www.fnnews.com/news/202406041355211404
# 7   https://www.epnc.co.kr/news/articleView.html?i...
# 8               https://www.etnews.com/20240604000330
# 9   https://www.dailysecu.com/news/articleView.htm...
#
#                                                  link  \
# 0   https://n.news.naver.com/mnews/article/366/000...
# 1   https://n.news.naver.com/mnews/article/018/000...
# 2   https://n.news.naver.com/mnews/article/241/000...
# 3   https://n.news.naver.com/mnews/article/629/000...
# 4   https://n.news.naver.com/mnews/article/421/000...
# ..                                                ...
# 5   https://n.news.naver.com/mnews/article/215/000...
# 6   https://n.news.naver.com/mnews/article/014/000...
# 7   https://www.epnc.co.kr/news/articleView.html?i...
# 8   https://n.news.naver.com/mnews/article/030/000...
# 9   https://www.dailysecu.com/news/articleView.htm...
#
#                                           description  \
# 0   한국<b>핀테크</b>산업협회(핀산협)는 오는 8월 6일, 전자금융업 관련 정책과 ...
# 1   한국<b>핀테크</b>산업협회는 내달 6일 전자금융업 관련 정책, 제도 및 입법 등...
# 2   신한은행은 신한카드, 신한투자증권, 서울시와 공동으로 <b>핀테크</b> 혁신 스타...
# 3   광동제약은 금융IT·<b>핀테크</b> 기업 핑거와 자사 제품에 투자할 수 있는 전...
# 4   신한은행과 신한카드, 신한투자증권은 서울시와 공동으로 <b>핀테크</b> 혁신 스타...
# ..                                                ...
# 5   한국<b>핀테크</b>산업협회는 4일 <b>핀테크</b>스타트업 투자·육성을 위해 ...
# 6   한국<b>핀테크</b>산업협회가 <b>핀테크</b>스타트업 투자·육성을 위해 JB인...
# 7   한국<b>핀테크</b>산업협회가 4일 <b>핀테크</b>스타트업 투자·육성을 위해 ...
# 8   한국<b>핀테크</b>산업협회(회장·이근주 한패스 대표)는JB인베스트먼트, 디지털경...
# 9   한국<b>핀테크</b>지원센터와 카카오뱅크는 전북창조경제혁신센터와 함께 '<b>핀테...
#
#                             pubDate
# 0   Wed, 24 Jul 2024 15:11:00 +0900
# 1   Wed, 24 Jul 2024 10:32:00 +0900
# 2   Tue, 23 Jul 2024 15:58:00 +0900
# 3   Wed, 24 Jul 2024 14:08:00 +0900
# 4   Tue, 23 Jul 2024 10:26:00 +0900
# ..                              ...
# 5   Tue, 04 Jun 2024 17:00:00 +0900
# 6   Tue, 04 Jun 2024 16:01:00 +0900
# 7   Tue, 04 Jun 2024 15:46:00 +0900
# 8   Tue, 04 Jun 2024 15:40:00 +0900
# 9   Tue, 04 Jun 2024 11:22:00 +0900
#
# [1000 rows x 5 columns]

# %%
result['pubDate'] = pd.to_datetime(result['pubDate'])

# %%
result = result.reset_index(drop=True)

# %%
result['pubDate'][0].date()
# Out:
# datetime.date(2024, 7, 24)
