# %%
import pandas as pd

# 한국 주식 목록 가져오기 (KRX)
def get_kr_stock_list():
    url = 'http://kind.krx.co.kr/corpgeneral/corpList.do?method=download'
    
    # 인코딩을 'euc-kr'로 설정하여 읽기
    kr_stock_list = pd.read_html(url, header=0, encoding='euc-kr')[0]
    
    # 종목코드를 6자리로 맞춤
    kr_stock_list['종목코드'] = kr_stock_list['종목코드'].apply(lambda x: f'{x:06d}')
    
    return kr_stock_list

# 사용 예시
kr_stocks = get_kr_stock_list()

print("한국 주식 목록:")
print(kr_stocks.head())
# Out:
# /home/user/miniforge3/envs/ag/lib/python3.10/site-packages/bs4/__init__.py:228: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# 한국 주식 목록:
#          회사명    종목코드                        업종  \
# 0     BGF리테일  282330                    종합 소매업
# 1      DRB동일  004840                  고무제품 제조업
# 2         E1  017940                 기타 전문 도매업
# 3  HDC현대산업개발  294870                    건물 건설업
# 4  HD현대마린솔루션  443060  건축기술, 엔지니어링 및 관련 기술 서비스업
#
#                                          주요제품         상장일  결산월  \
# 0                                     체인화 편의점  2017-12-08  12월
# 1           고무벨트(V벨트,콘베이어벨트,평벨트),프라스틱제품 제조,판매  1976-05-21  12월
# 2                        LPG(프로판,부탄가스),가스기기판매  1997-08-27  12월
# 3                      외주주택, 자체공사, 일반건축, 토목 등  2018-06-12  12월
# 4  AM(After Market) 솔루션, 친환경 Retrofit, 디지털 제어  2024-05-08  12월
#
#                       대표자명                               홈페이지     지역
# 0                      민승배           http://www.bgfretail.com  서울특별시
# 1                      류영식            http://www.drbworld.com  부산광역시
# 2       구자용, 천정식 (각자 대표이사)                http://www.e1.co.kr  서울특별시
# 3  최익훈, 김회언, 조태제 (각자 대표이사)             http://www.hdc-dvp.com  서울특별시
# 4                      이기동  http://www.hd-marinesolution.com/  부산광역시

# %%
kr_stocks
# Out:
#             회사명    종목코드                        업종  \
# 0        BGF리테일  282330                    종합 소매업
# 1         DRB동일  004840                  고무제품 제조업
# 2            E1  017940                 기타 전문 도매업
# 3     HDC현대산업개발  294870                    건물 건설업
# 4     HD현대마린솔루션  443060  건축기술, 엔지니어링 및 관련 기술 서비스업
# ...         ...     ...                       ...
# 2715        큐러블  086460           자연과학 및 공학 연구개발업
# 2716        타스컴  336040                의료용 기기 제조업
# 2717        테크엔  308700             전구 및 조명장치 제조업
# 2718      파워풀엑스  266870               기타 화학제품 제조업
# 2719    펨토바이오메드  327610                의료용 기기 제조업
#
#                                                    주요제품         상장일  결산월  \
# 0                                               체인화 편의점  2017-12-08  12월
# 1                     고무벨트(V벨트,콘베이어벨트,평벨트),프라스틱제품 제조,판매  1976-05-21  12월
# 2                                  LPG(프로판,부탄가스),가스기기판매  1997-08-27  12월
# 3                                외주주택, 자체공사, 일반건축, 토목 등  2018-06-12  12월
# 4            AM(After Market) 솔루션, 친환경 Retrofit, 디지털 제어  2024-05-08  12월
# ...                                                 ...         ...  ...
# 2715                                         유전체 분석 서비스  2013-07-01  12월
# 2716                             당뇨질환 세포치료제 / 당뇨관리 의료기기  2019-12-02  12월
# 2717                                            LED조명장치  2018-12-21  12월
# 2718                                       플렉스파워 리커버리크림  2017-04-24  12월
# 2719  CellShot 플랫폼 / CellShot 기반 항암백신치료 제품군 / CellSh...  2019-07-10  12월
#
#                          대표자명                               홈페이지     지역
# 0                         민승배           http://www.bgfretail.com  서울특별시
# 1                         류영식            http://www.drbworld.com  부산광역시
# 2          구자용, 천정식 (각자 대표이사)                http://www.e1.co.kr  서울특별시
# 3     최익훈, 김회언, 조태제 (각자 대표이사)             http://www.hdc-dvp.com  서울특별시
# 4                         이기동  http://www.hd-marinesolution.com/  부산광역시
# ...                       ...                                ...    ...
# 2715                      김승일        http://www.snp-genetics.com    경기도
# 2716                      이인근             http://www.yidobio.com    경기도
# 2717                       박철            http://www.techen.co.kr  대구광역시
# 2718                      박인철         http://www.flexpower.co.kr  서울특별시
# 2719           이상현, 최주현(각자대표)         http://www.femtobiomed.com    경기도
#
# [2720 rows x 9 columns]

# %%
kr_stock_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 kr_stock_list
#
# NameError: name 'kr_stock_list' is not defined
